# %% [markdown]
# # <font color=green>1. MEU PRIMEIRO SCRAPING

# %% [markdown]
# # 1.1. Introdução

# %% [markdown]
# ## *Web Scraping* é o termo utilizado para definir a prática de coletar automaticamente informações na Internet. Isto é feito, geralmente, por meio de programas que simulam a navegação humana na Web.

# %% [markdown]
# # 1.2. Ambiente e bibliotecas
# ### Utilizaremos em nosso treinamento o navegador Google Chrome

# %%
import bs4
import urllib.request as urllib_request
import pandas

print("BeautifulSoup ->", bs4.__version__)
print("urllib ->", urllib_request.__version__)
print("pandas ->", pandas.__version__)
# Out:
# BeautifulSoup -> 4.7.1
# urllib -> 3.7
# pandas -> 0.24.2

# %% [markdown]
# # 1.3. Meu primeiro scraping

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

url = 'https://alura-site-scraping.herokuapp.com/hello-world.php'

response = urlopen(url)
html = response.read()

soup = BeautifulSoup(html, 'html.parser')

print(soup.find('h1', id="hello-world").get_text())
print(soup.find('p').get_text())
# Out:
# Hello World!!!
# Web Scraping é o termo utilizado para definir a prática de coletar automaticamente informações na Internet. Isto é feito, geralmente, por meio de programas que simulam a navegação humana na Web.

# %% [markdown]
# ---
# # <font color=green>2. OBTENDO E TRATANDO O CONTEÚDO DE UM HTML

# %% [markdown]
# # 2.1. Entendendo a web

# %% [markdown]
# <img src="./web/web.png" width="700">

# %% [markdown]
# # 2.2. Obtendo o conteúdo HTML de um site

# %% [markdown]
# # urllib.request
# ## https://docs.python.org/3/library/urllib.html

# %%
from urllib.request import urlopen

url = 'https://alura-site-scraping.herokuapp.com/index.php'

response = urlopen(url)
html = response.read()
html
# Out:
# b'<!DOCTYPE html>\r\n<html lang="pt-br">\r\n<head>\r\n    <meta charset="utf-8">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\r\n\r\n    <title>Alura Motors</title>\r\n\r\n\t<style>\r\n\t\t/*Regra para a animacao*/\r\n\t\t@keyframes spin {\r\n\t\t\t0% { transform: rotate(0deg); }\r\n\t\t\t100% { transform: rotate(360deg); }\r\n\t\t}\r\n\t\t/*Mudando o tamanho do icone de resposta*/\r\n\t\tdiv.glyphicon {\r\n\t\t\tcolor:#6B8E23;\r\n\t\t\tfont-size: 38px;\r\n\t\t}\r\n\t\t/*Classe que mostra a animacao \'spin\'*/\r\n\t\t.loader {\r\n\t\t\tborder: 16px solid #f3f3f3;\r\n\t\t\tborder-radius: 50%;\r\n\t\t\tborder-top: 16px solid #3498db;\r\n\t\t\twidth: 80px;\r\n\t\t\theight: 80px;\r\n\t\t\t-webkit-animation: spin 2s linear infinite;\r\n\t\t\tanimation: spin 2s linear infinite;\r\n\t\t}\r\n\t</style>\r\n\t<link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" crossorigin="anonymous">\r\n\t<link rel="stylesheet" href="css/styles.css" media="all">\r\n\r\n\t<script src="https://code.jquery.com/jquery-1.12.4.js"></script>\r\n\t<script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js" integrity="sha384-Tc5IQib027qvyjSMfHjOMaLkfuWVxZxUPnCJA7l2mCWNIpG9mGCD8wGNIcPD7Txa" crossorigin="anonymous"></script>\r\n\t<script type="text/javascript" src="js/index.js"></script>\r\n\t<script>\r\n\t\trequisitar("https://alura-scraping.herokuapp.com/produtos?_page="+1+"&_limit=10")\r\n\t</script>\r\n\r\n</head>\r\n<body cz-shortcut-listen="true">\r\n    <noscript>You need to enable JavaScript to run this app.</noscript>\r\n\r\n\t<div class="modal fade" data-backdrop="static" id="loadingModal" tabindex="-1" role="dialog" aria-labelledby="loadingModal_label">\r\n\t\t<div class="modal-dialog" role="document">\r\n\t\t\t<div class="modal-content">\r\n\t\t\t\t<div class="modal-header">\r\n\t\t\t\t\t<h5 class="modal-title" id="loadingModal_label">\r\n\t\t\t\t\t\t<span class="glyphicon glyphicon-refresh"></span>Aguarde...\r\n\t\t\t\t\t</h5>\r\n\t\t\t\t</div>\r\n\t\t\t\t<div class="modal-body">\r\n\t\t\t\t\t<div class=\'alert\' role=\'alert\'>\r\n\t\t\t\t\t\t<center>\r\n\t\t\t\t\t\t\t<div class="loader" id="loader"></div><br>\r\n\t\t\t\t\t\t\t<h4><b id="loadingModal_content"></b></h4>\r\n\t\t\t\t\t\t</center>\r\n\t\t\t\t\t</div>\r\n\t\t\t\t</div>\r\n\t\t\t</div>\r\n\t\t</div>\r\n\t</div>\r\n\r\n    <div id="root">\r\n\t\t<header>\r\n\t\t\t<nav class="navbar navbar-inverse" style="margin-bottom: 0;">\r\n\t\t\t\t<div class="container" style="margin-bottom: -20px;">\r\n\t\t\t\t\t<div class="navbar">\r\n\t\t\t\t\t\t<a href="./index.php" class="navbar-brand" title="Alura Motors">\r\n\t\t\t\t\t\t\t<img src="img/alura-logo.svg" class="d-inline-block align-top" alt="Alura">Motors\r\n\t\t\t\t\t\t</a>\r\n\t\t\t\t\t\t<ul class="nav navbar-nav" style="margin-top: 35px;">\r\n\t\t\t\t\t\t\t<li><a href="./hello-world.php">Hello World</a></li>\r\n\t\t\t\t\t\t\t<li><a href="./index.php">An\xc3\xbancios</a></li>\r\n\t\t\t\t\t\t</ul>\r\n\t\t\t\t\t</div>\r\n\t\t\t\t</div>\r\n\t\t\t</nav>\r\n\t\t</header>\r\n\r\n\t\t<div class="container">\r\n\t\t\t<h1 class="sub-header">Ve\xc3\xadculos de Luxo Novos e Usados - Todas as Marcas</h1>\r\n\t\t\t<div class="row">\r\n\t\t\t\t<div class="col-md-12">\r\n\t\t\t\t\t<div class="container" style="width: 100%">\r\n\t\t\t\t\t\t<div class="type-select">246 ve\xc3\xadculos encontrados</div>\r\n\t\t\t\t\t\t\t<div class="container-pagination" style="float: right">\r\n\t\t\t\t\t\t\t\t<span class="info-pages">P\xc3\xa1gina 1 de 25</span>\r\n\t\t\t\t\t\t\t</div>\r\n\t\t\t\t\t\t</div>\r\n\t\t\t\t\t\t<div id="container-cards" style="height: 100%">\r\n\t\t\t\t\t\t\t\r\n                <div class="well card">\r\n                    <div class="col-md-3 image-card">\r\n                        <img width="220" height="155" alt="Foto" src="https://caelum-online-pu ...

# %% [markdown]
# ## https://docs.python.org/3/library/urllib.request.html#urllib.request.Request

# %%
from urllib.request import Request, urlopen
from urllib.error import URLError, HTTPError

url = 'https://www.alura.com.br'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36'}

try:
    req = Request(url, headers = headers)
    response = urlopen(req)
    print(response.read())
    
except HTTPError as e:
    print(e.status, e.reason)
    
except URLError as e:
    print(e.reason)
# Out:
# b'<!DOCTYPE html><html\nlang="pt-BR" ><head> <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n            new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n            j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n            \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n        })(window,document,\'script\',\'dataLayer\',\'GTM-TN542JN\');</script> <link\nrel="canonical" href="https://www.alura.com.br"><meta\ncharset="UTF-8"><meta\nname="viewport" content="width=device-width,initial-scale=1,minimum-scale=1.0"><title>Alura | Cursos online de tecnologia</title><meta\nname="description" content="Aprenda Programa\xc3\xa7\xc3\xa3o, Mobile, Front-end, Design, UX, Infraestrutura, Marketing Digital e Data &amp; BI com did\xc3\xa1tica inovadora."><meta\nproperty="og:locale" content="pt_BR"><meta\nproperty="og:description" content="Aprenda Programa\xc3\xa7\xc3\xa3o, Mobile, Front-end, Design, UX, Infraestrutura, Marketing Digital e Data &amp; BI com did\xc3\xa1tica inovadora." ><meta\nproperty="og:title" content="Alura | Cursos online de tecnologia"><meta\nproperty="og:site_name" content="Alura"><meta\nproperty="og:url" content="https://www.alura.com.br/"><meta\nproperty="og:image" content="https://www.alura.com.br/assets/api/share/alura.jpg"><meta\nproperty="og:image:alt" content="Alura logo"><meta\nproperty="fb:app_id" content="140078819399376"><meta\nproperty="og:type" content="website"><meta\nname="twitter:card" content="summary_large_image"><meta\nname="theme-color" content="#fbcf36"><link\nrel="stylesheet" href="/bundle,reset,base,colors,block/buttons,block/cardCurso,block/careers,block/categoriaBannerTarjeta,block/categoriaCard,block/categories,block/categoriesHome,block/colaboradores,block/conteudo,block/coresHomeEPlanos,block/cursoCard,block/degree-colors,block/degree,block/depoimentos,block/depoimentosAlunos,block/destaqueAlunos,block/detalhes,block/elasticMedia,block/footer-listaCarreiras,block/footer,block/form-erro,block/formContatoEmpresas,block/formacao-carreiras,block/formacoesCta,block/header,block/headerHome,block/highlighted,block/instrutores,block/listaCardCurso,block/listaCursos,block/listaGuides,block/materialEducacional,block/novosLancamentos,block/pagination,block/painelPlanos,block/parceriaBanner,block/planosEmpresas,block/planosPagamento,block/planosPagamentoOld,block/titulo-destaque,block/titulos,block/whitepaperCard.1566826582.css"><link\nrel="stylesheet" href="/bundle,home/homeNova/career-colors,home/homeNova/companies,home/homeNova/features,home/homeNova/home,home/homeNova/mobile,home/homeNova/testimonies.1566826582.css"><link\nhref="https://fonts.googleapis.com/css?family=Open+Sans:300,400,400i,600,700,800" rel="stylesheet" crossorigin> <script src="/assets/js/facebookpixel.1566826582.js" async></script> </head><body\nclass="">\n<noscript>\n<img\nheight="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=1067810189950610&ev=PageView&noscript=1"/>\n</noscript>\n<noscript>\n<iframe\nsrc="https://www.googletagmanager.com/ns.html?id=GTM-TN542JN"\nheight="0" width="0" style="display:none;visibility:hidden"></iframe>\n</noscript>\n <script type="application/ld+json">{\n      "@context": "http://schema.org",\n      "@type": "BreadcrumbList",\n\n      "itemListElement": [{\n        "@type": "ListItem",\n        "position": 1,\n        "item": {\n          "@id": "https://www.alura.com.br",\n          "name": "Alura"\n        }\n      }   \n            ]\n    }</script> <div\nclass="home"><div\nclass="home__header"><style>@media (min-width: 1100px) {\n\t\t\t\t.header-navegacao-cursos-lista {\n\t\t\t\t\tdisplay: none;\n\t\t\t\t}\n\t\t\t\t.header__nav {\n\t\t\t\t\tborder: none;\n\t\t\t\t\tmargin-top:10px;\n\t\t\t\t}\n\t\t\t\t.header {\n\t\t\t\t\tpadding-bottom: 0;\n\t\t\t\t}\n\t\t\t}</style><header\nclass="header--home"><div\nclass="container"><nav\nclass="header__nav--home">\n<a\n ...

# %% [markdown]
# # 2.3. Tratamento de string

# %%
from urllib.request import urlopen

url = 'https://alura-site-scraping.herokuapp.com/index.php'

response = urlopen(url)
html = response.read()
html
# Out:
# b'<!DOCTYPE html>\r\n<html lang="pt-br">\r\n<head>\r\n    <meta charset="utf-8">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\r\n\r\n    <title>Alura Motors</title>\r\n\r\n\t<style>\r\n\t\t/*Regra para a animacao*/\r\n\t\t@keyframes spin {\r\n\t\t\t0% { transform: rotate(0deg); }\r\n\t\t\t100% { transform: rotate(360deg); }\r\n\t\t}\r\n\t\t/*Mudando o tamanho do icone de resposta*/\r\n\t\tdiv.glyphicon {\r\n\t\t\tcolor:#6B8E23;\r\n\t\t\tfont-size: 38px;\r\n\t\t}\r\n\t\t/*Classe que mostra a animacao \'spin\'*/\r\n\t\t.loader {\r\n\t\t\tborder: 16px solid #f3f3f3;\r\n\t\t\tborder-radius: 50%;\r\n\t\t\tborder-top: 16px solid #3498db;\r\n\t\t\twidth: 80px;\r\n\t\t\theight: 80px;\r\n\t\t\t-webkit-animation: spin 2s linear infinite;\r\n\t\t\tanimation: spin 2s linear infinite;\r\n\t\t}\r\n\t</style>\r\n\t<link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" crossorigin="anonymous">\r\n\t<link rel="stylesheet" href="css/styles.css" media="all">\r\n\r\n\t<script src="https://code.jquery.com/jquery-1.12.4.js"></script>\r\n\t<script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js" integrity="sha384-Tc5IQib027qvyjSMfHjOMaLkfuWVxZxUPnCJA7l2mCWNIpG9mGCD8wGNIcPD7Txa" crossorigin="anonymous"></script>\r\n\t<script type="text/javascript" src="js/index.js"></script>\r\n\t<script>\r\n\t\trequisitar("https://alura-scraping.herokuapp.com/produtos?_page="+1+"&_limit=10")\r\n\t</script>\r\n\r\n</head>\r\n<body cz-shortcut-listen="true">\r\n    <noscript>You need to enable JavaScript to run this app.</noscript>\r\n\r\n\t<div class="modal fade" data-backdrop="static" id="loadingModal" tabindex="-1" role="dialog" aria-labelledby="loadingModal_label">\r\n\t\t<div class="modal-dialog" role="document">\r\n\t\t\t<div class="modal-content">\r\n\t\t\t\t<div class="modal-header">\r\n\t\t\t\t\t<h5 class="modal-title" id="loadingModal_label">\r\n\t\t\t\t\t\t<span class="glyphicon glyphicon-refresh"></span>Aguarde...\r\n\t\t\t\t\t</h5>\r\n\t\t\t\t</div>\r\n\t\t\t\t<div class="modal-body">\r\n\t\t\t\t\t<div class=\'alert\' role=\'alert\'>\r\n\t\t\t\t\t\t<center>\r\n\t\t\t\t\t\t\t<div class="loader" id="loader"></div><br>\r\n\t\t\t\t\t\t\t<h4><b id="loadingModal_content"></b></h4>\r\n\t\t\t\t\t\t</center>\r\n\t\t\t\t\t</div>\r\n\t\t\t\t</div>\r\n\t\t\t</div>\r\n\t\t</div>\r\n\t</div>\r\n\r\n    <div id="root">\r\n\t\t<header>\r\n\t\t\t<nav class="navbar navbar-inverse" style="margin-bottom: 0;">\r\n\t\t\t\t<div class="container" style="margin-bottom: -20px;">\r\n\t\t\t\t\t<div class="navbar">\r\n\t\t\t\t\t\t<a href="./index.php" class="navbar-brand" title="Alura Motors">\r\n\t\t\t\t\t\t\t<img src="img/alura-logo.svg" class="d-inline-block align-top" alt="Alura">Motors\r\n\t\t\t\t\t\t</a>\r\n\t\t\t\t\t\t<ul class="nav navbar-nav" style="margin-top: 35px;">\r\n\t\t\t\t\t\t\t<li><a href="./hello-world.php">Hello World</a></li>\r\n\t\t\t\t\t\t\t<li><a href="./index.php">An\xc3\xbancios</a></li>\r\n\t\t\t\t\t\t</ul>\r\n\t\t\t\t\t</div>\r\n\t\t\t\t</div>\r\n\t\t\t</nav>\r\n\t\t</header>\r\n\r\n\t\t<div class="container">\r\n\t\t\t<h1 class="sub-header">Ve\xc3\xadculos de Luxo Novos e Usados - Todas as Marcas</h1>\r\n\t\t\t<div class="row">\r\n\t\t\t\t<div class="col-md-12">\r\n\t\t\t\t\t<div class="container" style="width: 100%">\r\n\t\t\t\t\t\t<div class="type-select">246 ve\xc3\xadculos encontrados</div>\r\n\t\t\t\t\t\t\t<div class="container-pagination" style="float: right">\r\n\t\t\t\t\t\t\t\t<span class="info-pages">P\xc3\xa1gina 1 de 25</span>\r\n\t\t\t\t\t\t\t</div>\r\n\t\t\t\t\t\t</div>\r\n\t\t\t\t\t\t<div id="container-cards" style="height: 100%">\r\n\t\t\t\t\t\t\t\r\n                <div class="well card">\r\n                    <div class="col-md-3 image-card">\r\n                        <img width="220" height="155" alt="Foto" src="https://caelum-online-pu ...

# %% [markdown]
# ### Convertando o tipo bytes para string

# %%
type(html)
# Out:
# bytes

# %%
html = html.decode('utf-8')

# %%
type(html)
# Out:
# str

# %%
html
# Out:
# '<!DOCTYPE html>\r\n<html lang="pt-br">\r\n<head>\r\n    <meta charset="utf-8">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\r\n\r\n    <title>Alura Motors</title>\r\n\r\n\t<style>\r\n\t\t/*Regra para a animacao*/\r\n\t\t@keyframes spin {\r\n\t\t\t0% { transform: rotate(0deg); }\r\n\t\t\t100% { transform: rotate(360deg); }\r\n\t\t}\r\n\t\t/*Mudando o tamanho do icone de resposta*/\r\n\t\tdiv.glyphicon {\r\n\t\t\tcolor:#6B8E23;\r\n\t\t\tfont-size: 38px;\r\n\t\t}\r\n\t\t/*Classe que mostra a animacao \'spin\'*/\r\n\t\t.loader {\r\n\t\t\tborder: 16px solid #f3f3f3;\r\n\t\t\tborder-radius: 50%;\r\n\t\t\tborder-top: 16px solid #3498db;\r\n\t\t\twidth: 80px;\r\n\t\t\theight: 80px;\r\n\t\t\t-webkit-animation: spin 2s linear infinite;\r\n\t\t\tanimation: spin 2s linear infinite;\r\n\t\t}\r\n\t</style>\r\n\t<link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" crossorigin="anonymous">\r\n\t<link rel="stylesheet" href="css/styles.css" media="all">\r\n\r\n\t<script src="https://code.jquery.com/jquery-1.12.4.js"></script>\r\n\t<script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js" integrity="sha384-Tc5IQib027qvyjSMfHjOMaLkfuWVxZxUPnCJA7l2mCWNIpG9mGCD8wGNIcPD7Txa" crossorigin="anonymous"></script>\r\n\t<script type="text/javascript" src="js/index.js"></script>\r\n\t<script>\r\n\t\trequisitar("https://alura-scraping.herokuapp.com/produtos?_page="+1+"&_limit=10")\r\n\t</script>\r\n\r\n</head>\r\n<body cz-shortcut-listen="true">\r\n    <noscript>You need to enable JavaScript to run this app.</noscript>\r\n\r\n\t<div class="modal fade" data-backdrop="static" id="loadingModal" tabindex="-1" role="dialog" aria-labelledby="loadingModal_label">\r\n\t\t<div class="modal-dialog" role="document">\r\n\t\t\t<div class="modal-content">\r\n\t\t\t\t<div class="modal-header">\r\n\t\t\t\t\t<h5 class="modal-title" id="loadingModal_label">\r\n\t\t\t\t\t\t<span class="glyphicon glyphicon-refresh"></span>Aguarde...\r\n\t\t\t\t\t</h5>\r\n\t\t\t\t</div>\r\n\t\t\t\t<div class="modal-body">\r\n\t\t\t\t\t<div class=\'alert\' role=\'alert\'>\r\n\t\t\t\t\t\t<center>\r\n\t\t\t\t\t\t\t<div class="loader" id="loader"></div><br>\r\n\t\t\t\t\t\t\t<h4><b id="loadingModal_content"></b></h4>\r\n\t\t\t\t\t\t</center>\r\n\t\t\t\t\t</div>\r\n\t\t\t\t</div>\r\n\t\t\t</div>\r\n\t\t</div>\r\n\t</div>\r\n\r\n    <div id="root">\r\n\t\t<header>\r\n\t\t\t<nav class="navbar navbar-inverse" style="margin-bottom: 0;">\r\n\t\t\t\t<div class="container" style="margin-bottom: -20px;">\r\n\t\t\t\t\t<div class="navbar">\r\n\t\t\t\t\t\t<a href="./index.php" class="navbar-brand" title="Alura Motors">\r\n\t\t\t\t\t\t\t<img src="img/alura-logo.svg" class="d-inline-block align-top" alt="Alura">Motors\r\n\t\t\t\t\t\t</a>\r\n\t\t\t\t\t\t<ul class="nav navbar-nav" style="margin-top: 35px;">\r\n\t\t\t\t\t\t\t<li><a href="./hello-world.php">Hello World</a></li>\r\n\t\t\t\t\t\t\t<li><a href="./index.php">Anúncios</a></li>\r\n\t\t\t\t\t\t</ul>\r\n\t\t\t\t\t</div>\r\n\t\t\t\t</div>\r\n\t\t\t</nav>\r\n\t\t</header>\r\n\r\n\t\t<div class="container">\r\n\t\t\t<h1 class="sub-header">Veículos de Luxo Novos e Usados - Todas as Marcas</h1>\r\n\t\t\t<div class="row">\r\n\t\t\t\t<div class="col-md-12">\r\n\t\t\t\t\t<div class="container" style="width: 100%">\r\n\t\t\t\t\t\t<div class="type-select">246 veículos encontrados</div>\r\n\t\t\t\t\t\t\t<div class="container-pagination" style="float: right">\r\n\t\t\t\t\t\t\t\t<span class="info-pages">Página 1 de 25</span>\r\n\t\t\t\t\t\t\t</div>\r\n\t\t\t\t\t\t</div>\r\n\t\t\t\t\t\t<div id="container-cards" style="height: 100%">\r\n\t\t\t\t\t\t\t\r\n                <div class="well card">\r\n                    <div class="col-md-3 image-card">\r\n                        <img width="220" height="155" alt="Foto" src="https://caelum-online-public.s3.amazonaws.com/1381-sc ...

# %% [markdown]
# ### Eliminando os caracteres de tabulação, quebra de linha etc.

# %%
html.split()
# Out:
# ['<!DOCTYPE',
#  'html>',
#  '<html',
#  'lang="pt-br">',
#  '<head>',
#  '<meta',
#  'charset="utf-8">',
#  '<meta',
#  'name="viewport"',
#  'content="width=device-width,',
#  'initial-scale=1,',
#  'shrink-to-fit=no">',
#  '<title>Alura',
#  'Motors</title>',
#  '<style>',
#  '/*Regra',
#  'para',
#  'a',
#  'animacao*/',
#  '@keyframes',
#  'spin',
#  '{',
#  '0%',
#  '{',
#  'transform:',
#  'rotate(0deg);',
#  '}',
#  '100%',
#  '{',
#  'transform:',
#  'rotate(360deg);',
#  '}',
#  '}',
#  '/*Mudando',
#  'o',
#  'tamanho',
#  'do',
#  'icone',
#  'de',
#  'resposta*/',
#  'div.glyphicon',
#  '{',
#  'color:#6B8E23;',
#  'font-size:',
#  '38px;',
#  '}',
#  '/*Classe',
#  'que',
#  'mostra',
#  'a',
#  'animacao',
#  "'spin'*/",
#  '.loader',
#  '{',
#  'border:',
#  '16px',
#  'solid',
#  '#f3f3f3;',
#  'border-radius:',
#  '50%;',
#  'border-top:',
#  '16px',
#  'solid',
#  '#3498db;',
#  'width:',
#  '80px;',
#  'height:',
#  '80px;',
#  '-webkit-animation:',
#  'spin',
#  '2s',
#  'linear',
#  'infinite;',
#  'animation:',
#  'spin',
#  '2s',
#  'linear',
#  'infinite;',
#  '}',
#  '</style>',
#  '<link',
#  'rel="stylesheet"',
#  'href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css"',
#  'integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u"',
#  'crossorigin="anonymous">',
#  '<link',
#  'rel="stylesheet"',
#  'href="css/styles.css"',
#  'media="all">',
#  '<script',
#  'src="https://code.jquery.com/jquery-1.12.4.js"></script>',
#  '<script',
#  'src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js"',
#  'integrity="sha384-Tc5IQib027qvyjSMfHjOMaLkfuWVxZxUPnCJA7l2mCWNIpG9mGCD8wGNIcPD7Txa"',
#  'crossorigin="anonymous"></script>',
#  '<script',
#  'type="text/javascript"',
#  'src="js/index.js"></script>',
#  '<script>',
#  'requisitar("https://alura-scraping.herokuapp.com/produtos?_page="+1+"&_limit=10")',
#  '</script>',
#  '</head>',
#  '<body',
#  'cz-shortcut-listen="true">',
#  '<noscript>You',
#  'need',
#  'to',
#  'enable',
#  'JavaScript',
#  'to',
#  'run',
#  'this',
#  'app.</noscript>',
#  '<div',
#  'class="modal',
#  'fade"',
#  'data-backdrop="static"',
#  'id="loadingModal"',
#  'tabindex="-1"',
#  'role="dialog"',
#  'aria-labelledby="loadingModal_label">',
#  '<div',
#  'class="modal-dialog"',
#  'role="document">',
#  '<div',
#  'class="modal-content">',
#  '<div',
#  'class="modal-header">',
#  '<h5',
#  'class="modal-title"',
#  'id="loadingModal_label">',
#  '<span',
#  'class="glyphicon',
#  'glyphicon-refresh"></span>Aguarde...',
#  '</h5>',
#  '</div>',
#  '<div',
#  'class="modal-body">',
#  '<div',
#  "class='alert'",
#  "role='alert'>",
#  '<center>',
#  '<div',
#  'class="loader"',
#  'id="loader"></div><br>',
#  '<h4><b',
#  'id="loadingModal_content"></b></h4>',
#  '</center>',
#  '</div>',
#  '</div>',
#  '</div>',
#  '</div>',
#  '</div>',
#  '<div',
#  'id="root">',
#  '<header>',
#  '<nav',
#  'class="navbar',
#  'navbar-inverse"',
#  'style="margin-bottom:',
#  '0;">',
#  '<div',
#  'class="container"',
#  'style="margin-bottom:',
#  '-20px;">',
#  '<div',
#  'class="navbar">',
#  '<a',
#  'href="./index.php"',
#  'class="navbar-brand"',
#  'title="Alura',
#  'Motors">',
#  '<img',
#  'src="img/alura-logo.svg"',
#  'class="d-inline-block',
#  'align-top"',
#  'alt="Alura">Motors',
#  '</a>',
#  '<ul',
#  'class="nav',
#  'navbar-nav"',
#  'style="margin-top:',
#  '35px;">',
#  '<li><a',
#  'href="./hello-world.php">Hello',
#  'World</a></li>',
#  '<li><a',
#  'href="./index.php">Anúncios</a></li>',
#  '</ul>',
#  '</div>',
#  '</div>',
#  '</nav>',
#  '</header>',
#  '<div',
#  'class="container">',
#  '<h1',
#  'class="sub-header">Veículos',
#  'de',
#  'Luxo',
#  'Novos',
#  'e',
#  'Usados',
#  '-',
#  'Todas',
#  'as',
#  'Marcas</h1>',
#  '<div',
#  'class="row">',
#  '<div',
#  'class="col-md-12">',
#  '<div',
#  'class="container"',
#  'style="width:',
#  '100%">',
#  '<div',
#  'class="type-select">246',
#  'veículos',
#  'encontrados</div>',
#  '<div',
#  'class="container-pagination"',
#  'style="float:',
#  'right">',
#  '<span',
#  'class="info-pages">Página',
#  '1',
#  'de',
#  '25</span>',
#  '</div>',
#  '</div>',
#  '<div',
#  'id="container-cards"',
#  'style="height:',
#  '100%">',
#  '<div',
#  'class="well',
#  'card">',
#  '<div',
#  'class="col-md-3',
#  'image-card">',
#  '<img',
#  'width="220"',
#  'height="155"',
#  'alt="Foto"',
#  'src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg">',
#  '</div>',
#  '<div',
#  'class="col-md-6',
#  'body-card">',
#  '<p',
#  'class="txt-name',
#  'inline">LAMBORGHINI',
#  'AVENTADOR</p>',
#  '<p',
#  'class="txt-category',
#  'badge',
#  'badge-secondary',
#  'inline">USADO</p>',
#  '<p',
#  'class="txt-motor">Motor',
#  '1.8',
#  '16v</p>',
#  '<p',
#  'class="txt-description">Ano',
#  '1993',
#  '-',
#  '55.286',
#  'km</p>',
#  '<ul',
#  'class="lst-items">',
#  '<li',
#  'class="txt-items">►',
#  '4',
#  'X',
#  '4</li>',
#  '<li',
#  'class="txt-items">►',
#  'Câmera',
#  'de',
#  'estacionamento</li>',
#  '<li',
#  'class="txt-items">►',
#  'Controle',
#  'de',
#  'tração</li>',
#  '<li',
#  'class="txt-items">►',
#  'Sensor',
#  'de',
#  'estacionamento</li>',
#  '<li',
#  'class="txt-items">...</li>',
#  '</ul>',
#  '<p',
#  'class="txt-location">Belo',
#  'Horizonte',
#  '-',
#  'MG</p>',
#  '</div>',
#  '<div',
#  'class="col-md-3',
#  'value-card">',
#  '<div',
#  'class="value">',
#  '<p',
#  'class="txt-value">R$',
#  '338.000</p>',
#  '</div>',
#  '</div>',
#  '</div>',
#  '<div',
#  'class="well',
#  'card">',
#  '<div',
#  'class="col-md-3',
#  'image-card">',
#  '<img',
#  'width="220"',
#  'height="155"',
#  'alt="Foto"',
#  'src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/bmw-m2/bmw-m2-2970882__340.jpg">',
#  '</div>',
#  '<div',
#  'class="col-md-6',
#  'body-card">',
#  '<p',
#  'class="txt-name',
#  'inline">BMW',
#  'M2</p>',
#  '<p',
#  'class="txt-category',
#  'badge',
#  'badge-secondary',
#  'inline">USADO</p>',
#  '<p',
#  'class="txt-motor">Motor',
#  '3.0',
#  '32v</p>',
#  '<p',
#  'class="txt-description">Ano',
#  '2018',
#  '-',
#  '83.447',
#  'km</p>',
#  '<ul',
#  'class="lst-items">',
#  '<li',
#  'class="txt-items">►',
#  'Câmera',
#  'de',
#  'estacionamento</li>',
#  '<li',
#  'class="txt-items">►',
#  'Controle',
#  'de',
#  'estabilidade</li>',
#  '<li',
#  'class="txt-items">►',
#  'Travas',
#  'elétricas</li>',
#  '<li',
#  'class="txt-items">►',
#  'Freios',
#  'ABS</li>',
#  '<li',
#  'class="txt-items">...</li>',
#  '</ul>',
#  '<p',
#  'class="txt-location">Belo',
#  'Horizonte',
#  '-',
#  'MG</p>',
#  '</div>',
#  '<div',
#  'class="col-md-3',
#  'value-card">',
#  '<div',
#  'class="value">',
#  '<p',
#  'class="txt-value">R$',
#  '346.000</p>',
#  '</div>',
#  '</div>',
#  '</div>',
#  '<div',
#  'class="well',
#  'card">',
#  '<div',
#  'class="col-md-3',
#  'image-card">',
#  '<img',
#  'width="220"',
#  'height="155"',
#  'alt="Foto"',
#  'src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/alfa/alfa-1823056__340.jpg">',
#  '</div>',
#  '<div',
#  'class="col-md-6',
#  'body-card">',
#  '<p',
#  'class="txt-name',
#  'inline">ALFA</p>',
#  '<p',
#  'class="txt-category',
#  'badge',
#  'badge-secondary',
#  'inline">USADO</p>',
#  '<p',
#  'class="txt-motor">Motor',
#  '1.8',
#  '16v</p>',
#  '<p',
#  'class="txt-description">Ano',
#  '2004',
#  '-',
#  '19.722',
#  'km</p>',
#  '<ul',
#  'class="lst-items">',
#  '<li',
#  'class="txt-items">►',
#  'Central',
#  'multimídia</li>',
#  '<li',
#  'class="txt-items">►',
#  'Bancos',
#  'de',
#  'couro</li>',
#  '<li',
#  'class="txt-items">►',
#  'Rodas',
#  'de',
#  'liga</li>',
#  '<li',
#  'class="txt-items">►',
#  'Câmera',
#  'de',
#  'estacionamento</li>',
#  '<li',
#  'class="txt-items">...</li>',
#  '</ul>',
#  '<p',
#  'class="txt-location">Rio',
#  'de',
#  'Janeiro',
#  '-',
#  'RJ</p>',
#  '</div>',
#  '<div',
#  'class="col-md-3',
#  'value-card">',
#  '<div',
#  'class="value">',
#  '<p',
#  'class="txt-value">R$',
#  '480.000</p>',
#  '</div>',
#  '</div>',
#  '</div>',
#  '<div',
#  'class="well',
#  'card">',
#  '<div',
#  'class="col-md-3',
#  'image-card">',
#  '<img',
#  'width="220"',
#  'height="155"',
#  'alt="Foto"',
#  'src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/puech/puech-4055386__340.jpg">',
#  '</div>',
#  '<div',
#  'class="col-md-6',
#  'body-card">',
#  '<p',
#  'class="txt-name',
#  'inline">PUECH</p>',
#  '<p',
#  'class="txt-category',
#  'badge',
#  'badge-secondary',
#  'inline">USADO</p>',
#  '<p',
#  'class="txt-motor">Motor',
#  'Diesel',
#  'V8</p>',
#  '<p',
#  'class="txt-description">Ano',
#  '1992',
#  '-',
#  '34.335',
#  'km</p>',
#  '<ul',
#  'class="lst-items">',
#  '<li',
#  'class="txt-items">►',
#  'Bancos',
#  'de',
#  'couro</li>',
#  '<li',
#  'class="txt-items">►',
#  'Freios',
#  'ABS</li>',
#  '<li',
#  'class="txt-items">►',
#  'Rodas',
#  'de',
#  'liga</li>',
#  '<li',
#  'class="txt-items">►',
#  'Câmbio',
#  'automático</li>',
#  '<li',
#  'class="txt-items">...</li>',
#  '</ul>',
#  '<p',
#  'class="txt-location">São',
#  'Paulo',
#  '-',
#  'SP</p>',
#  '</div>',
#  '<div',
#  'class="col-md-3',
#  'value-card">',
#  '<div',
#  'class="value">',
#  '<p',
#  'class="txt-value">R$',
#  '133.000</p>',
#  '</div>',
#  '</div>',
#  '</div>',
#  '<div',
#  'class="well',
#  'card">',
#  '<div',
#  'class="col-md-3',
#  'image-card">',
#  '<img',
#  'width="220"',
#  'height="155"',
#  'alt="Foto"',
#  'src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-murcielago/lamborghini-murcielago-2872974__340.jpg">',
#  '</div>',
#  '<div',
#  'class="col-md-6',
#  'body-card">',
#  '<p',
#  'class="txt-name',
#  'inline">LAMBORGHINI',
#  'MURCIELAGO</p>',
#  '<p',
#  'class="txt-category',
#  'badge',
#  'badge-secondary',
#  'inline">USADO</p>',
#  '<p',
#  'class="txt-motor">Motor',
#  '1.0',
#  '8v</p>',
#  '<p',
#  'class="txt-description">Ano',
#  '1991',
#  '-',
#  '464',
#  'km</p>',
#  '<ul',
#  'class="lst-items">',
#  '<li',
#  'class="txt-items">►',
#  'Central',
#  'multimídia</li>',
#  '<li',
#  'class="txt-items">►',
#  'Teto',
#  'panorâmico</li>',
#  '<li',
#  'class="txt-items">►',
#  'Sensor',
#  'crepuscular</li>',
#  '<li',
#  'class="txt-items">►',
#  'Piloto',
#  'automático</li>',
#  '<li',
#  'class="txt-items">...</li>',
#  '</ul>',
#  '<p',
#  'class="txt-location">Belo',
#  'Horizonte',
#  '-',
#  'MG</p>',
#  '</div>',
#  '<div',
#  'class="col-md-3',
#  'value-card">',
#  '<div',
#  'class="value">',
#  '<p',
#  'class="txt-value">R$',
#  '175.000</p>',
#  '</div>',
#  '</div>',
#  '</div>',
#  '<div',
#  'class="well',
#  'card">',
#  '<div',
#  'class="col-md-3',
#  'image-card">',
#  '<img',
#  'width="220"',
#  'height="155"',
#  'alt="Foto"',
#  'src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/aston-martin/aston-martin-2977916__340.jpg">',
#  '</div>',
#  '<div',
#  'class="col-md-6',
#  'body-card">',
#  '<p',
#  'class="txt-name',
#  'inline">ASTON',
#  'MARTIN</p>',
#  '<p',
#  'class="txt-category',
#  'badge',
#  'badge-secondary',
#  'inline">USADO</p>',
#  '<p',
#  'class="txt-opportunity',
#  'badge',
#  'badge-danger',
#  'inline">OPORTUNIDADE</p>',
#  '<p',
#  'class="txt-motor">Motor',
#  'Diesel',
#  'V6</p>',
#  '<p',
#  'class="txt-description">Ano',
#  '2004',
#  '-',
#  '50.189',
#  'km</p>',
#  '<ul',
#  'class="lst-items">',
#  '<li',
#  'class="txt-items">►',
#  'Painel',
#  'digital</li>',
#  '<li',
#  'class="txt-items">►',
#  'Controle',
#  'de',
#  'tração</li>',
#  '<li',
#  'class="txt-items">►',
#  'Teto',
#  'panorâmico</li>',
#  '<li',
#  'class="txt-items">►',
#  'Central',
#  'multimídia</li>',
#  '<li',
#  'class="txt-items">...</li>',
#  '</ul>',
#  '<p',
#  'class="txt-location">Belo',
#  'Horizonte',
#  '-',
#  'MG</p>',
#  '</div>',
#  '<div',
#  'class="col-md-3',
#  'value-card">',
#  '<div',
#  'class="value">',
#  '<p',
#  'class="txt-value">R$',
#  '239.000</p>',
#  '</div>',
#  '</div>',
#  '</div>',
#  '<div',
#  'class="well',
#  'card">',
#  '<div',
#  'class="col-md-3',
#  'image-card">',
#  '<img',
#  'width="220"',
#  'height="155"',
#  'alt="Foto"',
#  'src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/tvr/tvr-2943925__340.jpg">',
#  '</div>',
#  '<div',
#  'class="col-md-6',
#  'body-card">',
#  '<p',
#  'class="txt-name',
#  'inline">TVR</p>',
#  '<p',
#  'class="txt-category',
#  'badge',
#  'badge-secondary',
#  'inline">USADO</p>',
#  '<p',
#  'class="txt-motor">Motor',
#  '4.0',
#  'Turbo</p>',
#  '<p',
#  'class="txt-description">Ano',
#  '2014',
#  '-',
#  '17.778',
#  'km</p>',
#  '<ul',
#  'class="lst-items">',
#  '<li',
#  'class="txt-items">►',
#  '4',
#  'X',
#  '4</li>',
#  '<li',
#  'class="txt-items">►',
#  'Teto',
#  'panorâmico</li>',
#  '<li',
#  'class="txt-items">►',
#  'Central',
#  'multimídia</li>',
#  '<li',
#  'class="txt-items">►',
#  'Controle',
#  'de',
#  'estabilidade</li>',
#  '<li',
#  'class="txt-items">...</li>',
#  '</ul>',
#  '<p',
#  'class="txt-location">Belo',
#  'Horizonte',
#  '-',
#  'MG</p>',
#  '</div>',
#  '<div',
#  'class="col-md-3',
#  'value-card">',
#  '<div',
#  'class="value">',
#  '<p',
#  'class="txt-value">R$',
#  '115.000</p>',
#  '</div>',
#  '</div>',
#  '</div>',
#  '<div',
#  'class="well',
#  'card">',
#  '<div',
#  'class="col-md-3',
#  'image-card">',
#  '<img',
#  'width="220"',
#  'height="155"',
#  'alt="Foto"',
#  'src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/excalibur/excalibur-2916730__340.jpg">',
#  '</div>',
#  '<div',
#  'class="col-md-6',
#  'body-card">',
#  '<p',
#  'class="txt-name',
#  'inline">EXCALIBUR</p>',
#  '<p',
#  'class="txt-category',
#  'badge',
#  'badge-secondary',
#  'inline">USADO</p>',
#  '<p',
#  'class="txt-motor">Motor',
#  '3.0',
#  '32v</p>',
#  '<p',
#  'class="txt-description">Ano',
#  '2009',
#  '-',
#  '81.251',
#  'km</p>',
#  '<ul',
#  'class="lst-items">',
#  '<li',
#  'class="txt-items">►',
#  'Painel',
#  'digital</li>',
#  '<li',
#  'class="txt-items">►',
#  'Câmbio',
#  'automático</li>',
#  '<li',
#  'class="txt-items">►',
#  'Sensor',
#  'de',
#  'chuva</li>',
#  '<li',
#  'class="txt-items">►',
#  'Travas',
#  'elétricas</li>',
#  '<li',
#  'class="txt-items">...</li>',
#  '</ul>',
#  '<p',
#  'class="txt-location">Rio',
#  'de',
#  'Janeiro',
#  '-',
#  'RJ</p>',
#  '</div>',
#  '<div',
#  'class="col-md-3',
#  'value-card">',
#  '<div',
#  'class="value">',
#  '<p',
#  'class="txt-value">R$',
#  '114.000</p>',
#  '</div>',
#  '</div>',
#  '</div>',
#  '<div',
#  'class="well',
#  'card">',
#  '<div',
#  'class="col-md-3',
#  'image-card">',
#  '<img',
#  'width="220"',
#  'height="155"',
#  'alt="Foto"',
#  'src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/mclaren/mclaren-2855240__340.jpg">',
#  '</div>',
#  '<div',
#  'class="col-md-6',
#  'body-card">',
#  '<p',
#  'class="txt-name',
#  'inline">MCLAREN</p>',
#  '<p',
#  'class="txt-category',
#  'badge',
#  'badge-secondary',
#  'inline">NOVO</p>',
#  '<p',
#  'class="txt-motor">Motor',
#  'Diesel</p>',
#  '<p',
#  'class="txt-description">Ano',
#  '2019',
#  '-',
#  '0',
#  'km</p>',
#  '<ul',
#  'class="lst-items">',
#  '<li',
#  'class="txt-items">►',
#  'Central',
#  'multimídia</li>',
#  '<li',
#  'class="txt-items">►',
#  'Câmera',
#  'de',
#  'estacionamento</li>',
#  '<li',
#  'class="txt-items">►',
#  'Câmbio',
#  'automático</li>',
#  '<li',
#  'class="txt-items">►',
#  'Ar',
#  'condicionado</li>',
#  '<li',
#  'class="txt-items">...</li>',
#  '</ul>',
#  '<p',
#  'class="txt-location">São',
#  'Paulo',
#  '-',
#  'SP</p>',
#  '</div>',
#  '<div',
#  'class="col-md-3',
#  'value-card">',
#  '<div',
#  'class="value">',
#  '<p',
#  'class="txt-value">R$',
#  '75.000</p>',
#  '</div>',
#  '</div>',
#  '</div>',
#  '<div',
#  'class="well',
#  'card">',
#  '<div',
#  'class="col-md-3',
#  'image-card">',
#  '<img',
#  'width="220"',
#  'height="155"',
#  'alt="Foto"',
#  'src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/toyota/toyota-3245397__340.jpg">',
#  '</div>',
#  '<div',
#  'class="col-md-6',
#  'body-card">',
#  '<p',
#  'class="txt-name',
#  'inline">TOYOTA</p>',
#  '<p',
#  'class="txt-category',
#  'badge',
#  'badge-secondary',
#  'inline">USADO</p>',
#  '<p',
#  'class="txt-opportunity',
#  'badge',
#  'badge-danger',
#  'inline">OPORTUNIDADE</p>',
#  '<p',
#  'class="txt-motor">Motor',
#  '4.0',
#  'Turbo</p>',
#  '<p',
#  'class="txt-description">Ano',
#  '1999',
#  '-',
#  '12.536',
#  'km</p>',
#  '<ul',
#  'class="lst-items">',
#  '<li',
#  'class="txt-items">►',
#  'Bancos',
#  'de',
#  'couro</li>',
#  '<li',
#  'class="txt-items">►',
#  'Freios',
#  'ABS</li>',
#  '<li',
#  'class="txt-items">►',
#  'Piloto',
#  'automático</li>',
#  '<li',
#  'class="txt-items">►',
#  'Controle',
#  'de',
#  'estabilidade</li>',
#  '<li',
#  'class="txt-items">...</li>',
#  '</ul>',
#  '<p',
#  'class="txt-location">São',
#  'Paulo',
#  '-',
#  'SP</p>',
#  '</div>',
#  '<div',
#  'class="col-md-3',
#  'value-card">',
#  '<div',
#  'class="value">',
#  '<p',
#  'class="txt-value">R$',
#  '117.000</p>',
#  '</div>',
#  '</div>',
#  '</div>',
#  '</div>',
#  '<div',
#  'class="type-select">246',
#  'veículos',
#  'encontrados</div>',
#  '<div',
#  'class="container-pagination"',
#  'style="float:',
#  'right">',
#  '<span',
#  'class="info-pages">Página',
#  '1',
#  'de',
#  '25</span>',
#  '</div>',
#  '</div>',
#  '</div>',
#  '</div>',
#  '</div>',
#  '</div>',
#  '<footer>',
#  '<nav',
#  'class="navbar',
#  'navbar-inverse">',
#  ...]

# %%
" ".join(html.split())
# Out:
# '<!DOCTYPE html> <html lang="pt-br"> <head> <meta charset="utf-8"> <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"> <title>Alura Motors</title> <style> /*Regra para a animacao*/ @keyframes spin { 0% { transform: rotate(0deg); } 100% { transform: rotate(360deg); } } /*Mudando o tamanho do icone de resposta*/ div.glyphicon { color:#6B8E23; font-size: 38px; } /*Classe que mostra a animacao \'spin\'*/ .loader { border: 16px solid #f3f3f3; border-radius: 50%; border-top: 16px solid #3498db; width: 80px; height: 80px; -webkit-animation: spin 2s linear infinite; animation: spin 2s linear infinite; } </style> <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" crossorigin="anonymous"> <link rel="stylesheet" href="css/styles.css" media="all"> <script src="https://code.jquery.com/jquery-1.12.4.js"></script> <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js" integrity="sha384-Tc5IQib027qvyjSMfHjOMaLkfuWVxZxUPnCJA7l2mCWNIpG9mGCD8wGNIcPD7Txa" crossorigin="anonymous"></script> <script type="text/javascript" src="js/index.js"></script> <script> requisitar("https://alura-scraping.herokuapp.com/produtos?_page="+1+"&_limit=10") </script> </head> <body cz-shortcut-listen="true"> <noscript>You need to enable JavaScript to run this app.</noscript> <div class="modal fade" data-backdrop="static" id="loadingModal" tabindex="-1" role="dialog" aria-labelledby="loadingModal_label"> <div class="modal-dialog" role="document"> <div class="modal-content"> <div class="modal-header"> <h5 class="modal-title" id="loadingModal_label"> <span class="glyphicon glyphicon-refresh"></span>Aguarde... </h5> </div> <div class="modal-body"> <div class=\'alert\' role=\'alert\'> <center> <div class="loader" id="loader"></div><br> <h4><b id="loadingModal_content"></b></h4> </center> </div> </div> </div> </div> </div> <div id="root"> <header> <nav class="navbar navbar-inverse" style="margin-bottom: 0;"> <div class="container" style="margin-bottom: -20px;"> <div class="navbar"> <a href="./index.php" class="navbar-brand" title="Alura Motors"> <img src="img/alura-logo.svg" class="d-inline-block align-top" alt="Alura">Motors </a> <ul class="nav navbar-nav" style="margin-top: 35px;"> <li><a href="./hello-world.php">Hello World</a></li> <li><a href="./index.php">Anúncios</a></li> </ul> </div> </div> </nav> </header> <div class="container"> <h1 class="sub-header">Veículos de Luxo Novos e Usados - Todas as Marcas</h1> <div class="row"> <div class="col-md-12"> <div class="container" style="width: 100%"> <div class="type-select">246 veículos encontrados</div> <div class="container-pagination" style="float: right"> <span class="info-pages">Página 1 de 25</span> </div> </div> <div id="container-cards" style="height: 100%"> <div class="well card"> <div class="col-md-3 image-card"> <img width="220" height="155" alt="Foto" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg"> </div> <div class="col-md-6 body-card"> <p class="txt-name inline">LAMBORGHINI AVENTADOR</p> <p class="txt-category badge badge-secondary inline">USADO</p> <p class="txt-motor">Motor 1.8 16v</p> <p class="txt-description">Ano 1993 - 55.286 km</p> <ul class="lst-items"> <li class="txt-items">► 4 X 4</li> <li class="txt-items">► Câmera de estacionamento</li> <li class="txt-items">► Controle de tração</li> <li class="txt-items">► Sensor de estacionamento</li> <li class="txt-items">...</li> </ul> <p class="txt-location">Belo Horizonte - MG</p> </div> <div class="col-md-3 value-card"> <div class="value"> <p class="txt-value">R$ 338.000</p> </div> </div> </div> <div class="well card"> <div class="col-md-3 image-card"> <img width="220" height="155" alt="Foto" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/bmw-m2/bm ...

# %% [markdown]
# ### Eliminando os espaços em branco entre as TAGS

# %%
" ".join(html.split()).replace('> <', '><')
# Out:
# '<!DOCTYPE html><html lang="pt-br"><head><meta charset="utf-8"><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><title>Alura Motors</title><style> /*Regra para a animacao*/ @keyframes spin { 0% { transform: rotate(0deg); } 100% { transform: rotate(360deg); } } /*Mudando o tamanho do icone de resposta*/ div.glyphicon { color:#6B8E23; font-size: 38px; } /*Classe que mostra a animacao \'spin\'*/ .loader { border: 16px solid #f3f3f3; border-radius: 50%; border-top: 16px solid #3498db; width: 80px; height: 80px; -webkit-animation: spin 2s linear infinite; animation: spin 2s linear infinite; } </style><link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" crossorigin="anonymous"><link rel="stylesheet" href="css/styles.css" media="all"><script src="https://code.jquery.com/jquery-1.12.4.js"></script><script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js" integrity="sha384-Tc5IQib027qvyjSMfHjOMaLkfuWVxZxUPnCJA7l2mCWNIpG9mGCD8wGNIcPD7Txa" crossorigin="anonymous"></script><script type="text/javascript" src="js/index.js"></script><script> requisitar("https://alura-scraping.herokuapp.com/produtos?_page="+1+"&_limit=10") </script></head><body cz-shortcut-listen="true"><noscript>You need to enable JavaScript to run this app.</noscript><div class="modal fade" data-backdrop="static" id="loadingModal" tabindex="-1" role="dialog" aria-labelledby="loadingModal_label"><div class="modal-dialog" role="document"><div class="modal-content"><div class="modal-header"><h5 class="modal-title" id="loadingModal_label"><span class="glyphicon glyphicon-refresh"></span>Aguarde... </h5></div><div class="modal-body"><div class=\'alert\' role=\'alert\'><center><div class="loader" id="loader"></div><br><h4><b id="loadingModal_content"></b></h4></center></div></div></div></div></div><div id="root"><header><nav class="navbar navbar-inverse" style="margin-bottom: 0;"><div class="container" style="margin-bottom: -20px;"><div class="navbar"><a href="./index.php" class="navbar-brand" title="Alura Motors"><img src="img/alura-logo.svg" class="d-inline-block align-top" alt="Alura">Motors </a><ul class="nav navbar-nav" style="margin-top: 35px;"><li><a href="./hello-world.php">Hello World</a></li><li><a href="./index.php">Anúncios</a></li></ul></div></div></nav></header><div class="container"><h1 class="sub-header">Veículos de Luxo Novos e Usados - Todas as Marcas</h1><div class="row"><div class="col-md-12"><div class="container" style="width: 100%"><div class="type-select">246 veículos encontrados</div><div class="container-pagination" style="float: right"><span class="info-pages">Página 1 de 25</span></div></div><div id="container-cards" style="height: 100%"><div class="well card"><div class="col-md-3 image-card"><img width="220" height="155" alt="Foto" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg"></div><div class="col-md-6 body-card"><p class="txt-name inline">LAMBORGHINI AVENTADOR</p><p class="txt-category badge badge-secondary inline">USADO</p><p class="txt-motor">Motor 1.8 16v</p><p class="txt-description">Ano 1993 - 55.286 km</p><ul class="lst-items"><li class="txt-items">► 4 X 4</li><li class="txt-items">► Câmera de estacionamento</li><li class="txt-items">► Controle de tração</li><li class="txt-items">► Sensor de estacionamento</li><li class="txt-items">...</li></ul><p class="txt-location">Belo Horizonte - MG</p></div><div class="col-md-3 value-card"><div class="value"><p class="txt-value">R$ 338.000</p></div></div></div><div class="well card"><div class="col-md-3 image-card"><img width="220" height="155" alt="Foto" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/bmw-m2/bmw-m2-2970882__340.jpg"></div><div class="col-md-6 body-card"><p class="txt-name inline ...

# %% [markdown]
# ### Função de tratamento de strings

# %%
def trata_html(input):
    return " ".join(input.split()).replace('> <', '><')

# %%
html
# Out:
# '<!DOCTYPE html>\r\n<html lang="pt-br">\r\n<head>\r\n    <meta charset="utf-8">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\r\n\r\n    <title>Alura Motors</title>\r\n\r\n\t<style>\r\n\t\t/*Regra para a animacao*/\r\n\t\t@keyframes spin {\r\n\t\t\t0% { transform: rotate(0deg); }\r\n\t\t\t100% { transform: rotate(360deg); }\r\n\t\t}\r\n\t\t/*Mudando o tamanho do icone de resposta*/\r\n\t\tdiv.glyphicon {\r\n\t\t\tcolor:#6B8E23;\r\n\t\t\tfont-size: 38px;\r\n\t\t}\r\n\t\t/*Classe que mostra a animacao \'spin\'*/\r\n\t\t.loader {\r\n\t\t\tborder: 16px solid #f3f3f3;\r\n\t\t\tborder-radius: 50%;\r\n\t\t\tborder-top: 16px solid #3498db;\r\n\t\t\twidth: 80px;\r\n\t\t\theight: 80px;\r\n\t\t\t-webkit-animation: spin 2s linear infinite;\r\n\t\t\tanimation: spin 2s linear infinite;\r\n\t\t}\r\n\t</style>\r\n\t<link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" crossorigin="anonymous">\r\n\t<link rel="stylesheet" href="css/styles.css" media="all">\r\n\r\n\t<script src="https://code.jquery.com/jquery-1.12.4.js"></script>\r\n\t<script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js" integrity="sha384-Tc5IQib027qvyjSMfHjOMaLkfuWVxZxUPnCJA7l2mCWNIpG9mGCD8wGNIcPD7Txa" crossorigin="anonymous"></script>\r\n\t<script type="text/javascript" src="js/index.js"></script>\r\n\t<script>\r\n\t\trequisitar("https://alura-scraping.herokuapp.com/produtos?_page="+1+"&_limit=10")\r\n\t</script>\r\n\r\n</head>\r\n<body cz-shortcut-listen="true">\r\n    <noscript>You need to enable JavaScript to run this app.</noscript>\r\n\r\n\t<div class="modal fade" data-backdrop="static" id="loadingModal" tabindex="-1" role="dialog" aria-labelledby="loadingModal_label">\r\n\t\t<div class="modal-dialog" role="document">\r\n\t\t\t<div class="modal-content">\r\n\t\t\t\t<div class="modal-header">\r\n\t\t\t\t\t<h5 class="modal-title" id="loadingModal_label">\r\n\t\t\t\t\t\t<span class="glyphicon glyphicon-refresh"></span>Aguarde...\r\n\t\t\t\t\t</h5>\r\n\t\t\t\t</div>\r\n\t\t\t\t<div class="modal-body">\r\n\t\t\t\t\t<div class=\'alert\' role=\'alert\'>\r\n\t\t\t\t\t\t<center>\r\n\t\t\t\t\t\t\t<div class="loader" id="loader"></div><br>\r\n\t\t\t\t\t\t\t<h4><b id="loadingModal_content"></b></h4>\r\n\t\t\t\t\t\t</center>\r\n\t\t\t\t\t</div>\r\n\t\t\t\t</div>\r\n\t\t\t</div>\r\n\t\t</div>\r\n\t</div>\r\n\r\n    <div id="root">\r\n\t\t<header>\r\n\t\t\t<nav class="navbar navbar-inverse" style="margin-bottom: 0;">\r\n\t\t\t\t<div class="container" style="margin-bottom: -20px;">\r\n\t\t\t\t\t<div class="navbar">\r\n\t\t\t\t\t\t<a href="./index.php" class="navbar-brand" title="Alura Motors">\r\n\t\t\t\t\t\t\t<img src="img/alura-logo.svg" class="d-inline-block align-top" alt="Alura">Motors\r\n\t\t\t\t\t\t</a>\r\n\t\t\t\t\t\t<ul class="nav navbar-nav" style="margin-top: 35px;">\r\n\t\t\t\t\t\t\t<li><a href="./hello-world.php">Hello World</a></li>\r\n\t\t\t\t\t\t\t<li><a href="./index.php">Anúncios</a></li>\r\n\t\t\t\t\t\t</ul>\r\n\t\t\t\t\t</div>\r\n\t\t\t\t</div>\r\n\t\t\t</nav>\r\n\t\t</header>\r\n\r\n\t\t<div class="container">\r\n\t\t\t<h1 class="sub-header">Veículos de Luxo Novos e Usados - Todas as Marcas</h1>\r\n\t\t\t<div class="row">\r\n\t\t\t\t<div class="col-md-12">\r\n\t\t\t\t\t<div class="container" style="width: 100%">\r\n\t\t\t\t\t\t<div class="type-select">246 veículos encontrados</div>\r\n\t\t\t\t\t\t\t<div class="container-pagination" style="float: right">\r\n\t\t\t\t\t\t\t\t<span class="info-pages">Página 1 de 25</span>\r\n\t\t\t\t\t\t\t</div>\r\n\t\t\t\t\t\t</div>\r\n\t\t\t\t\t\t<div id="container-cards" style="height: 100%">\r\n\t\t\t\t\t\t\t\r\n                <div class="well card">\r\n                    <div class="col-md-3 image-card">\r\n                        <img width="220" height="155" alt="Foto" src="https://caelum-online-public.s3.amazonaws.com/1381-sc ...

# %%
html = trata_html(html)
html
# Out:
# '<!DOCTYPE html><html lang="pt-br"><head><meta charset="utf-8"><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><title>Alura Motors</title><style> /*Regra para a animacao*/ @keyframes spin { 0% { transform: rotate(0deg); } 100% { transform: rotate(360deg); } } /*Mudando o tamanho do icone de resposta*/ div.glyphicon { color:#6B8E23; font-size: 38px; } /*Classe que mostra a animacao \'spin\'*/ .loader { border: 16px solid #f3f3f3; border-radius: 50%; border-top: 16px solid #3498db; width: 80px; height: 80px; -webkit-animation: spin 2s linear infinite; animation: spin 2s linear infinite; } </style><link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" crossorigin="anonymous"><link rel="stylesheet" href="css/styles.css" media="all"><script src="https://code.jquery.com/jquery-1.12.4.js"></script><script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js" integrity="sha384-Tc5IQib027qvyjSMfHjOMaLkfuWVxZxUPnCJA7l2mCWNIpG9mGCD8wGNIcPD7Txa" crossorigin="anonymous"></script><script type="text/javascript" src="js/index.js"></script><script> requisitar("https://alura-scraping.herokuapp.com/produtos?_page="+1+"&_limit=10") </script></head><body cz-shortcut-listen="true"><noscript>You need to enable JavaScript to run this app.</noscript><div class="modal fade" data-backdrop="static" id="loadingModal" tabindex="-1" role="dialog" aria-labelledby="loadingModal_label"><div class="modal-dialog" role="document"><div class="modal-content"><div class="modal-header"><h5 class="modal-title" id="loadingModal_label"><span class="glyphicon glyphicon-refresh"></span>Aguarde... </h5></div><div class="modal-body"><div class=\'alert\' role=\'alert\'><center><div class="loader" id="loader"></div><br><h4><b id="loadingModal_content"></b></h4></center></div></div></div></div></div><div id="root"><header><nav class="navbar navbar-inverse" style="margin-bottom: 0;"><div class="container" style="margin-bottom: -20px;"><div class="navbar"><a href="./index.php" class="navbar-brand" title="Alura Motors"><img src="img/alura-logo.svg" class="d-inline-block align-top" alt="Alura">Motors </a><ul class="nav navbar-nav" style="margin-top: 35px;"><li><a href="./hello-world.php">Hello World</a></li><li><a href="./index.php">Anúncios</a></li></ul></div></div></nav></header><div class="container"><h1 class="sub-header">Veículos de Luxo Novos e Usados - Todas as Marcas</h1><div class="row"><div class="col-md-12"><div class="container" style="width: 100%"><div class="type-select">246 veículos encontrados</div><div class="container-pagination" style="float: right"><span class="info-pages">Página 1 de 25</span></div></div><div id="container-cards" style="height: 100%"><div class="well card"><div class="col-md-3 image-card"><img width="220" height="155" alt="Foto" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg"></div><div class="col-md-6 body-card"><p class="txt-name inline">LAMBORGHINI AVENTADOR</p><p class="txt-category badge badge-secondary inline">USADO</p><p class="txt-motor">Motor 1.8 16v</p><p class="txt-description">Ano 1993 - 55.286 km</p><ul class="lst-items"><li class="txt-items">► 4 X 4</li><li class="txt-items">► Câmera de estacionamento</li><li class="txt-items">► Controle de tração</li><li class="txt-items">► Sensor de estacionamento</li><li class="txt-items">...</li></ul><p class="txt-location">Belo Horizonte - MG</p></div><div class="col-md-3 value-card"><div class="value"><p class="txt-value">R$ 338.000</p></div></div></div><div class="well card"><div class="col-md-3 image-card"><img width="220" height="155" alt="Foto" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/bmw-m2/bmw-m2-2970882__340.jpg"></div><div class="col-md-6 body-card"><p class="txt-name inline ...

# %% [markdown]
# ---
# # <font color=green>3. INTRODUÇÃO AO BEAUTIFULSOUP

# %% [markdown]
# # 3.1. HTML da nossa página

# %% [markdown]
# **HTML** (*HyperText Markup Language*) é uma linguagem de marcação composta por **tags** que deteminam o papel que cada parte do documento vai assumir. As **tags** são formadas pelo seu nome e atributos. Os atributos servem para configurar e também modificar as características padrões de uma **tag**.
#
# ## Estrutura básica
#
# ```html
# <html>
#     <head>
#         <meta charset="utf-8" />
#         <title>Alura Motors</title>
#     </head>
#     <body>
#         <div id="container">
#             <h1>Alura</h1>
#             <h2 class="formato">Cursos de Tecnologia</h2>
#             <p>Você vai estudar, praticar, discutir e aprender.</p>
#             <a href="https://www.alura.com.br/">Clique aqui</a>
#         </div>
#     </body>
# </html>
# ```
#
# ```<html>``` - determina o início do documento.
#
# ```<head>``` - cabeçalho. Contém informações e configurações do documento.
#
# ```<body>``` - é o corpo do documento, onde todo o conteúdo é colocado. Esta é a parte visível em um navegador.
#
# ## Tags mais comuns
#
# ```<div>``` - define uma divisão da página. Pode ser formatada de diversas maneiras.
#
# ```<h1>, <h2>, <h3>, <h4>, <h5>, <h6>``` - marcadores de títulos.
#
# ```<p>``` - marcador de parágrafo.
#
# ```<a>``` - hiperlink.
#
# ```<img>``` - exibição de imagens.
#
# ```<table>``` - definição de tabelas.
#
# ```<ul>, <li>``` - definição de listas.

# %% [markdown]
# <html>
#     <head>
#         <meta charset="utf-8" />
#         <title>Alura Motors</title>
#     </head>
#     <body>
#         <div id="container">
#             <h1>Alura</h1>
#             <h2 class="formato">Cursos de Tecnologia</h2>
#             <p>Você vai estudar, praticar, discutir e aprender.</p>
#             <a href="https://www.alura.com.br/">Clique aqui</a>
#         </div>
#     </body>
# </html>

# %% [markdown]
# # 3.2. Criando um objeto BeautifulSoup

# %% [markdown]
# ## https://www.crummy.com/software/BeautifulSoup/
#
# ### Sobre parser ver: https://www.crummy.com/software/BeautifulSoup/bs4/doc/#parser-installation

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html, 'html.parser')

soup
# Out:
# <!DOCTYPE html>
# <html lang="pt-br"><head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/><title>Alura Motors</title><style> /*Regra para a animacao*/ @keyframes spin { 0% { transform: rotate(0deg); } 100% { transform: rotate(360deg); } } /*Mudando o tamanho do icone de resposta*/ div.glyphicon { color:#6B8E23; font-size: 38px; } /*Classe que mostra a animacao 'spin'*/ .loader { border: 16px solid #f3f3f3; border-radius: 50%; border-top: 16px solid #3498db; width: 80px; height: 80px; -webkit-animation: spin 2s linear infinite; animation: spin 2s linear infinite; } </style><link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" rel="stylesheet"/><link href="css/styles.css" media="all" rel="stylesheet"/><script src="https://code.jquery.com/jquery-1.12.4.js"></script><script crossorigin="anonymous" integrity="sha384-Tc5IQib027qvyjSMfHjOMaLkfuWVxZxUPnCJA7l2mCWNIpG9mGCD8wGNIcPD7Txa" src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js"></script><script src="js/index.js" type="text/javascript"></script><script> requisitar("https://alura-scraping.herokuapp.com/produtos?_page="+1+"&_limit=10") </script></head><body cz-shortcut-listen="true"><noscript>You need to enable JavaScript to run this app.</noscript><div aria-labelledby="loadingModal_label" class="modal fade" data-backdrop="static" id="loadingModal" role="dialog" tabindex="-1"><div class="modal-dialog" role="document"><div class="modal-content"><div class="modal-header"><h5 class="modal-title" id="loadingModal_label"><span class="glyphicon glyphicon-refresh"></span>Aguarde... </h5></div><div class="modal-body"><div class="alert" role="alert"><center><div class="loader" id="loader"></div><br/><h4><b id="loadingModal_content"></b></h4></center></div></div></div></div></div><div id="root"><header><nav class="navbar navbar-inverse" style="margin-bottom: 0;"><div class="container" style="margin-bottom: -20px;"><div class="navbar"><a class="navbar-brand" href="./index.php" title="Alura Motors"><img alt="Alura" class="d-inline-block align-top" src="img/alura-logo.svg"/>Motors </a><ul class="nav navbar-nav" style="margin-top: 35px;"><li><a href="./hello-world.php">Hello World</a></li><li><a href="./index.php">Anúncios</a></li></ul></div></div></nav></header><div class="container"><h1 class="sub-header">Veículos de Luxo Novos e Usados - Todas as Marcas</h1><div class="row"><div class="col-md-12"><div class="container" style="width: 100%"><div class="type-select">246 veículos encontrados</div><div class="container-pagination" style="float: right"><span class="info-pages">Página 1 de 25</span></div></div><div id="container-cards" style="height: 100%"><div class="well card"><div class="col-md-3 image-card"><img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg" width="220"/></div><div class="col-md-6 body-card"><p class="txt-name inline">LAMBORGHINI AVENTADOR</p><p class="txt-category badge badge-secondary inline">USADO</p><p class="txt-motor">Motor 1.8 16v</p><p class="txt-description">Ano 1993 - 55.286 km</p><ul class="lst-items"><li class="txt-items">► 4 X 4</li><li class="txt-items">► Câmera de estacionamento</li><li class="txt-items">► Controle de tração</li><li class="txt-items">► Sensor de estacionamento</li><li class="txt-items">...</li></ul><p class="txt-location">Belo Horizonte - MG</p></div><div class="col-md-3 value-card"><div class="value"><p class="txt-value">R$ 338.000</p></div></div></div><div class="well card"><div class="col-md-3 image-card"><img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/bmw-m2/bmw-m2-2970882__340.jpg" width="220"/></div><div class="col-md-6 body-card"><p class="txt-name inline">BMW M2</p><p ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="pt-br">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <title>
#    Alura Motors
#   </title>
#   <style>
#    /*Regra para a animacao*/ @keyframes spin { 0% { transform: rotate(0deg); } 100% { transform: rotate(360deg); } } /*Mudando o tamanho do icone de resposta*/ div.glyphicon { color:#6B8E23; font-size: 38px; } /*Classe que mostra a animacao 'spin'*/ .loader { border: 16px solid #f3f3f3; border-radius: 50%; border-top: 16px solid #3498db; width: 80px; height: 80px; -webkit-animation: spin 2s linear infinite; animation: spin 2s linear infinite; }
#   </style>
#   <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" rel="stylesheet"/>
#   <link href="css/styles.css" media="all" rel="stylesheet"/>
#   <script src="https://code.jquery.com/jquery-1.12.4.js">
#   </script>
#   <script crossorigin="anonymous" integrity="sha384-Tc5IQib027qvyjSMfHjOMaLkfuWVxZxUPnCJA7l2mCWNIpG9mGCD8wGNIcPD7Txa" src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js">
#   </script>
#   <script src="js/index.js" type="text/javascript">
#   </script>
#   <script>
#    requisitar("https://alura-scraping.herokuapp.com/produtos?_page="+1+"&_limit=10")
#   </script>
#  </head>
#  <body cz-shortcut-listen="true">
#   <noscript>
#    You need to enable JavaScript to run this app.
#   </noscript>
#   <div aria-labelledby="loadingModal_label" class="modal fade" data-backdrop="static" id="loadingModal" role="dialog" tabindex="-1">
#    <div class="modal-dialog" role="document">
#     <div class="modal-content">
#      <div class="modal-header">
#       <h5 class="modal-title" id="loadingModal_label">
#        <span class="glyphicon glyphicon-refresh">
#        </span>
#        Aguarde...
#       </h5>
#      </div>
#      <div class="modal-body">
#       <div class="alert" role="alert">
#        <center>
#         <div class="loader" id="loader">
#         </div>
#         <br/>
#         <h4>
#          <b id="loadingModal_content">
#          </b>
#         </h4>
#        </center>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="root">
#    <header>
#     <nav class="navbar navbar-inverse" style="margin-bottom: 0;">
#      <div class="container" style="margin-bottom: -20px;">
#       <div class="navbar">
#        <a class="navbar-brand" href="./index.php" title="Alura Motors">
#         <img alt="Alura" class="d-inline-block align-top" src="img/alura-logo.svg"/>
#         Motors
#        </a>
#        <ul class="nav navbar-nav" style="margin-top: 35px;">
#         <li>
#          <a href="./hello-world.php">
#           Hello World
#          </a>
#         </li>
#         <li>
#          <a href="./index.php">
#           Anúncios
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </nav>
#    </header>
#    <div class="container">
#     <h1 class="sub-header">
#      Veículos de Luxo Novos e Usados - Todas as Marcas
#     </h1>
#     <div class="row">
#      <div class="col-md-12">
#       <div class="container" style="width: 100%">
#        <div class="type-select">
#         246 veículos encontrados
#        </div>
#        <div class="container-pagination" style="float: right">
#         <span class="info-pages">
#          Página 1 de 25
#         </span>
#        </div>
#       </div>
#       <div id="container-cards" style="height: 100%">
#        <div class="well card">
#         <div class="col-md-3 image-card">
#          <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg" width="220"/>
#         </div>
#         <div class="col-md-6 body-card">
#          <p class="txt-name inline">
#           LAMBORGHINI AVENTADOR
#          </p>
#          <p class="txt-category badge badge-secondary inline">
#           USADO
#          </p>
#          <p class="txt-motor">
#           Motor 1.8 16v
#          </p>
#          <p class="txt-description">
#           Ano 1993 - 55.286 km
#          </p>
#          <ul class="lst-items">
#           <li class="txt-items">
#            ► 4 X 4
#           </li>
#           <li class="txt-items">
#            ► Câmera de estacionamento
#           </li>
#           <li class="txt-items">
#            ► Controle de tração
#           </li>
#           <li class="txt-items">
#            ► Sensor de estacionamento
#           </li>
#           <li class="txt-items">
#            ...
#           </li>
#          </ul>
#          <p class="txt-location">
#           Belo Horizonte - MG
#          </p>
#         </div>
#         <div class="col-md-3 value-card">
#          <div class="value">
#           <p class="txt-value">
#            R$ 338.000
#           </p>
#          </div>
#         </div>
#        </div>
#        <div class="well card">
#         <div class="col-md-3 image-card">
#          <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/bmw-m2/bmw-m2-2970882__340.jpg" width="220"/>
#         </div>
#         <div class="col-md-6 body-card">
#          <p class="txt-name inline">
#           BMW M2
#          </p>
#          <p class="txt-category badge badge-secondary inline">
#           USADO
#          </p>
#          <p class="txt-motor">
#           Motor 3.0 32v
#          </p>
#          <p class="txt-description">
#           Ano 2018 - 83.447 km
#          </p>
#          <ul class="lst-items">
#           <li class="txt-items">
#            ► Câmera de estacionamento
#           </li>
#           <li class="txt-items">
#            ► Controle de estabilidade
#           </li>
#           <li class="txt-items">
#            ► Travas elétricas
#           </li>
#           <li class="txt-items">
#            ► Freios ABS
#           </li>
#           <li class="txt-items">
#            ...
#           </li>
#          </ul>
#          <p class="txt-location">
#           Belo Horizonte - MG
#          </p>
#         </div>
#         <div class="col-md-3 value-card">
#          <div class="value">
#           <p class="txt-value">
#            R$ 346.000
#           </p>
#          </div>
#         </div>
#        </div>
#        <div class="well card">
#         <div class="col-md-3 image-card">
#          <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/alfa/alfa-1823056__340.jpg" width="220"/>
#         </div>
#         <div class="col-md-6 body-card">
#          <p class="txt-name inline">
#           ALFA
#          </p>
#          <p class="txt-category badge badge-secondary inline">
#           USADO
#          </p>
#          <p class="txt-motor">
#           Motor 1.8 16v
#          </p>
#          <p class="txt-description">
#           Ano 2004 - 19.722 km
#          </p>
#          <ul class="lst-items">
#           <li class="txt-items">
#            ► Central multimídia
#           </li>
#           <li class="txt-items">
#            ► Bancos de couro
#           </li>
#           <li class="txt-items">
#            ► Rodas de liga
#           </li>
#           <li class="txt-items">
#            ► Câmera de estacionamento
#           </li>
#           <li class="txt-items">
#            ...
#           </li>
#          </ul>
#          <p class="txt-location">
#           Rio de Janeiro - RJ
#          </p>
#         </div>
#         <div class="col-md-3 value-card">
#          <div class="value">
#           <p class="txt-value">
#            R$ 480.000
#           </p>
#          </div>
#         </div>
#        </div>
#        <div class="well card">
#         <div class="col-md-3 image-card">
#          <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/puech/puech-4055386__340.jpg" width="220"/>
#         </div>
#         <div class="col-md-6 body-card">
#          <p class="txt-name inline">
#           PUECH
#          </p>
#          <p class="txt-category badge badge-secondary inline">
#           USADO
#          </p>
#          <p class="txt-motor">
#           Motor Diesel V8
#          </p>
#          <p class="txt-description">
#           Ano 1992 - 34.335 km
#          </p>
#          <ul class="lst-items">
#           <li class="txt-items">
#            ► Bancos de couro
#           </li>
#           <li class="txt-items">
#            ► Freios ABS
#           </li>
#           <li class="txt-items">
#            ► Rodas de liga
#           </li>
#           <li class="txt-items">
#            ► Câmbio automático
#           </li>
#           <li class="txt-items">
#            ...
#           </li>
#          </ul>
#          <p class="txt-location">
#           São Paulo - SP
#          </p>
#         </div>
#         <div class="col-md-3 value-card">
#          <div class="value">
#           <p class="txt-value">
#            R$ 133.000
#           </p>
#          </div>
#         </div>
#        </div>
#        <div class="well card">
#         <div class="col-md-3 image-card">
#          <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-murcielago/lamborghini-murcielago-2872974__340.jpg" width="220"/>
#         </div>
#         <div class="col-md-6 body-card">
#          <p class="txt-name inline">
#           LAMBORGHINI MURCIELAGO
#          </p>
#          <p class="txt-category badge badge-secondary inline">
#           USADO
#          </p>
#          <p class="txt-motor">
#           Motor 1.0 8v
#          </p>
#          <p class="txt-description">
#           Ano 1991 - 464 km
#          </p>
#          <ul class="lst-items">
#           <li class="txt-items">
#            ► Central multimídia
#           </li>
#           <li class="txt-items">
#            ► Teto panorâmico
#           </li>
#           <li class="txt-items">
#            ► Sensor crepuscular
#           </li>
#           <li class="txt-items">
#            ► Piloto automático
#           </li>
#           <li class="txt-items">
#            ...
#           </li>
#          </ul>
#          <p class="txt-location">
#           Belo Horizonte - MG
#          </p>
#         </div>
#         <div class="col-md-3 value-card">
#          <div class="value">
#           <p class="txt-value">
#            R$ 175.000
#           </p>
#          </div>
#         </div>
#        </div>
#        <div class="well card">
#         <div class="col-md-3 image-card">
#          <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/aston-martin/aston-martin-2977916__340.jpg" width="220"/>
#         </div>
#         <div class="col-md-6 body-card">
#          <p class="txt-name inline">
#           ASTON MARTIN
#          </p>
#          <p class="txt-category badge badge-secondary inline">
#           USADO
#          </p>
#          <p class="txt-opportunity badge badge-danger inline">
#           OPORTUNIDADE
#          </p>
#          <p class="txt-motor">
#           Motor Diesel V6
#          </p>
#          <p class="txt-description">
#           Ano 2004 - 50.189 km
#          </p>
#          <ul class="lst-items">
#           <li class="txt-items">
#            ► Painel digital
#           </li>
#           <li class="txt-items">
#            ► Controle de tração
#           </li>
#           <li class="txt-items">
#            ► Teto panorâmico
#           </li>
#           <li class="txt-items">
#            ► Central multimídia
#           </li>
#           <li class="txt-items">
#            ...
#           </li>
#          </ul>
#          <p class="txt-location">
#           Belo Horizonte - MG
#          </p>
#         </div>
#         <div class="col-md-3 value-card">
#          <div class="value">
#           <p class="txt-value">
#            R$ 239.000
#           </p>
#          </div>
#         </div>
#        </div>
#        <div class="well card">
#         <div class="col-md-3 image-card">
#          <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/tvr/tvr-2943925__340.jpg" width="220"/>
#         </div>
#         <div class="col-md-6 body-card">
#          <p class="txt-name inline">
#           TVR
#          </p>
#          <p class="txt-category badge badge-secondary inline">
#           USADO
#          </p>
#          <p class="txt-motor">
#           Motor 4.0 Turbo
#          </p>
#          <p class="txt-description">
#           Ano 2014 - 17.778 km
#          </p>
#          <ul class="lst-items">
#           <li class="txt-items">
#            ► 4 X 4
#           </li>
#           <li class="txt-items">
#            ► Teto panorâmico
#           </li>
#           <li class="txt-items">
#            ► Central multimídia
#           </li>
#           <li class="txt-items">
#            ► Controle de estabilidade
#           </li>
#           <li class="txt-items">
#            ...
#           </li>
#          </ul>
#          <p class="txt-location">
#           Belo Horizonte - MG
#          </p>
#         </div>
#         <div class="col-md-3 value-card">
#          <div class="value">
#           <p class="txt-value">
#            R$ 115.000
#           </p>
#          </div>
#         </div>
#        </div>
#        <div class="well card">
#         <div class="col-md-3 image-card">
#          <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/excalibur/excalibur-2916730__340.jpg" width="220"/>
#         </div>
#         <div class="col-md-6 body-card">
#          <p class="txt-name inline">
#           EXCALIBUR
#          </p>
#          <p class="txt-category badge badge-secondary inline">
#           USADO
#          </p>
#          <p class="txt-motor">
#           Motor 3.0 32v
#          </p>
#          <p class="txt-description">
#           Ano 2009 - 81.251 km
#          </p>
#          <ul class="lst-items">
#           <li class="txt-items">
#            ► Painel digital
#           </li>
#           <li class="txt-items">
#            ► Câmbio automático
#           </li>
#           <li class="txt-items">
#            ► Sensor de chuva
#           </li>
#           <li class="txt-items">
#            ► Travas elétricas
#           </li>
#           <li class="txt-items">
#            ...
#           </li>
#          </ul>
#          <p class="txt-location">
#           Rio de Janeiro - RJ
#          </p>
#         </div>
#         <div class="col-md-3 value-card">
#          <div class="value">
#           <p class="txt-value">
#            R$ 114.000
#           </p>
#          </div>
#         </div>
#        </div>
#        <div class="well card">
#         <div class="col-md-3 image-card">
#          <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/mclaren/mclaren-2855240__340.jpg" width="220"/>
#         </div>
#         <div class="col-md-6 body-card">
#          <p class="txt-name inline">
#           MCLAREN
#          </p>
#          <p class="txt-category badge badge-secondary inline">
#           NOVO
#          </p>
#          <p class="txt-motor">
#           Motor Diesel
#          </p>
#          <p class="txt-description">
#           Ano 2019 - 0 km
#          </p>
#          <ul class="lst-items">
#           <li class="txt-items">
#            ► Central multimídia
#           </li>
#           <li class="txt-items">
#            ► Câmera de estacionamento
#           </li>
#           <li class="txt-items">
#            ► Câmbio automático
#           </li>
#           <li class="txt-items">
#            ► Ar condicionado
#           </li>
#           <li class="txt-items">
#            ...
#           </li>
#          </ul>
#          <p class="txt-location">
#           São Paulo - SP
#          </p>
#         </div>
#         <div class="col-md-3 value-card">
#          <div class="value">
#           <p class="txt-value">
#            R$ 75.000
#           </p>
#          </div>
#         </div>
#        </div>
#        <div class="well card">
#         <div class="col-md-3 image-card">
#          <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/toyota/toyota-3245397__340.jpg" width="220"/>
#         </div>
#         <div class="col-md-6 body-card">
#          <p class="txt-name inline">
#           TOYOTA
#          </p>
#          <p class="txt-category badge badge-secondary inline">
#           USADO
#          </p>
#          <p class="txt-opportunity badge badge-danger inline">
#           OPORTUNIDADE
#          </p>
#          <p class="txt-motor">
#           Motor 4.0 Turbo
#          </p>
#          <p class="txt-description">
#           Ano 1999 - 12.536 km
#          </p>
#          <ul class="lst-items">
#           <li class="txt-items">
#            ► Bancos de couro
#           </li>
#           <li class="txt-items">
#            ► Freios ABS
#           </li>
#           <li class="txt-items">
#            ► Piloto automático
#           </li>
#           <li class="txt-items">
#            ► Controle de estabilidade
#           </li>
#           <li class="txt-items">
#            ...
#           </li>
#          </ul>
#          <p class="txt-location">
#           São Paulo - SP
#          </p>
#         </div>
#         <div class="col-md-3 value-card">
#          <div class="value">
#           <p class="txt-value">
#            R$ 117.000
#           </p>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="type-select">
#        246 veículos encontrados
#       </div>
#       <div class="container-pagination" style="float: right">
#        <span class="info-pages">
#         Página 1 de 25
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>
# <footer>
#  <nav class="navbar navbar-inverse">
#   <div class="container" style="margin-bottom: 10px;">
#    <div class="navbar">
#     <a class="navbar-brand" href="./index.php" title="Alura Motors">
#      <img alt="Alura" class="d-inline-block align-top" src="img/alura-logo.svg"/>
#      Motors
#     </a>
#     <p style="color: #fff; text-align: center; margin-top: 40px;">
#      Aplicação para treinamento de web scraping
#     </p>
#    </div>
#   </div>
#  </nav>
# </footer>

# %% [markdown]
# # 3.3. Acessando tags

# %%
soup.html
# Out:
# <html lang="pt-br"><head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/><title>Alura Motors</title><style> /*Regra para a animacao*/ @keyframes spin { 0% { transform: rotate(0deg); } 100% { transform: rotate(360deg); } } /*Mudando o tamanho do icone de resposta*/ div.glyphicon { color:#6B8E23; font-size: 38px; } /*Classe que mostra a animacao 'spin'*/ .loader { border: 16px solid #f3f3f3; border-radius: 50%; border-top: 16px solid #3498db; width: 80px; height: 80px; -webkit-animation: spin 2s linear infinite; animation: spin 2s linear infinite; } </style><link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" rel="stylesheet"/><link href="css/styles.css" media="all" rel="stylesheet"/><script src="https://code.jquery.com/jquery-1.12.4.js"></script><script crossorigin="anonymous" integrity="sha384-Tc5IQib027qvyjSMfHjOMaLkfuWVxZxUPnCJA7l2mCWNIpG9mGCD8wGNIcPD7Txa" src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js"></script><script src="js/index.js" type="text/javascript"></script><script> requisitar("https://alura-scraping.herokuapp.com/produtos?_page="+1+"&_limit=10") </script></head><body cz-shortcut-listen="true"><noscript>You need to enable JavaScript to run this app.</noscript><div aria-labelledby="loadingModal_label" class="modal fade" data-backdrop="static" id="loadingModal" role="dialog" tabindex="-1"><div class="modal-dialog" role="document"><div class="modal-content"><div class="modal-header"><h5 class="modal-title" id="loadingModal_label"><span class="glyphicon glyphicon-refresh"></span>Aguarde... </h5></div><div class="modal-body"><div class="alert" role="alert"><center><div class="loader" id="loader"></div><br/><h4><b id="loadingModal_content"></b></h4></center></div></div></div></div></div><div id="root"><header><nav class="navbar navbar-inverse" style="margin-bottom: 0;"><div class="container" style="margin-bottom: -20px;"><div class="navbar"><a class="navbar-brand" href="./index.php" title="Alura Motors"><img alt="Alura" class="d-inline-block align-top" src="img/alura-logo.svg"/>Motors </a><ul class="nav navbar-nav" style="margin-top: 35px;"><li><a href="./hello-world.php">Hello World</a></li><li><a href="./index.php">Anúncios</a></li></ul></div></div></nav></header><div class="container"><h1 class="sub-header">Veículos de Luxo Novos e Usados - Todas as Marcas</h1><div class="row"><div class="col-md-12"><div class="container" style="width: 100%"><div class="type-select">246 veículos encontrados</div><div class="container-pagination" style="float: right"><span class="info-pages">Página 1 de 25</span></div></div><div id="container-cards" style="height: 100%"><div class="well card"><div class="col-md-3 image-card"><img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg" width="220"/></div><div class="col-md-6 body-card"><p class="txt-name inline">LAMBORGHINI AVENTADOR</p><p class="txt-category badge badge-secondary inline">USADO</p><p class="txt-motor">Motor 1.8 16v</p><p class="txt-description">Ano 1993 - 55.286 km</p><ul class="lst-items"><li class="txt-items">► 4 X 4</li><li class="txt-items">► Câmera de estacionamento</li><li class="txt-items">► Controle de tração</li><li class="txt-items">► Sensor de estacionamento</li><li class="txt-items">...</li></ul><p class="txt-location">Belo Horizonte - MG</p></div><div class="col-md-3 value-card"><div class="value"><p class="txt-value">R$ 338.000</p></div></div></div><div class="well card"><div class="col-md-3 image-card"><img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/bmw-m2/bmw-m2-2970882__340.jpg" width="220"/></div><div class="col-md-6 body-card"><p class="txt-name inline">BMW M2</p><p ...

# %%
soup.html.head.title
# Out:
# <title>Alura Motors</title>

# %%
soup.title
# Out:
# <title>Alura Motors</title>

# %%
soup.div.div.div.div.h5
# Out:
# <h5 class="modal-title" id="loadingModal_label"><span class="glyphicon glyphicon-refresh"></span>Aguarde... </h5>

# %%
soup.h5
# Out:
# <h5 class="modal-title" id="loadingModal_label"><span class="glyphicon glyphicon-refresh"></span>Aguarde... </h5>

# %% [markdown]
# # 3.4. Acessando o conteúdo das tags

# %%
soup.html.head.title
# Out:
# <title>Alura Motors</title>

# %%
soup.title
# Out:
# <title>Alura Motors</title>

# %%
soup.title.get_text()
# Out:
# 'Alura Motors'

# %%
soup.h5.getText()
# Out:
# 'Aguarde... '

# %%
soup.get_text()
# Out:
# 'Alura Motors /*Regra para a animacao*/ @keyframes spin { 0% { transform: rotate(0deg); } 100% { transform: rotate(360deg); } } /*Mudando o tamanho do icone de resposta*/ div.glyphicon { color:#6B8E23; font-size: 38px; } /*Classe que mostra a animacao \'spin\'*/ .loader { border: 16px solid #f3f3f3; border-radius: 50%; border-top: 16px solid #3498db; width: 80px; height: 80px; -webkit-animation: spin 2s linear infinite; animation: spin 2s linear infinite; }  requisitar("https://alura-scraping.herokuapp.com/produtos?_page="+1+"&_limit=10") You need to enable JavaScript to run this app.Aguarde... Motors Hello WorldAnúnciosVeículos de Luxo Novos e Usados - Todas as Marcas246 veículos encontradosPágina 1 de 25LAMBORGHINI AVENTADORUSADOMotor 1.8 16vAno 1993 - 55.286 km► 4 X 4► Câmera de estacionamento► Controle de tração► Sensor de estacionamento...Belo Horizonte - MGR$ 338.000BMW M2USADOMotor 3.0 32vAno 2018 - 83.447 km► Câmera de estacionamento► Controle de estabilidade► Travas elétricas► Freios ABS...Belo Horizonte - MGR$ 346.000ALFAUSADOMotor 1.8 16vAno 2004 - 19.722 km► Central multimídia► Bancos de couro► Rodas de liga► Câmera de estacionamento...Rio de Janeiro - RJR$ 480.000PUECHUSADOMotor Diesel V8Ano 1992 - 34.335 km► Bancos de couro► Freios ABS► Rodas de liga► Câmbio automático...São Paulo - SPR$ 133.000LAMBORGHINI MURCIELAGOUSADOMotor 1.0 8vAno 1991 - 464 km► Central multimídia► Teto panorâmico► Sensor crepuscular► Piloto automático...Belo Horizonte - MGR$ 175.000ASTON MARTINUSADOOPORTUNIDADEMotor Diesel V6Ano 2004 - 50.189 km► Painel digital► Controle de tração► Teto panorâmico► Central multimídia...Belo Horizonte - MGR$ 239.000TVRUSADOMotor 4.0 TurboAno 2014 - 17.778 km► 4 X 4► Teto panorâmico► Central multimídia► Controle de estabilidade...Belo Horizonte - MGR$ 115.000EXCALIBURUSADOMotor 3.0 32vAno 2009 - 81.251 km► Painel digital► Câmbio automático► Sensor de chuva► Travas elétricas...Rio de Janeiro - RJR$ 114.000MCLARENNOVOMotor DieselAno 2019 - 0 km► Central multimídia► Câmera de estacionamento► Câmbio automático► Ar condicionado...São Paulo - SPR$ 75.000TOYOTAUSADOOPORTUNIDADEMotor 4.0 TurboAno 1999 - 12.536 km► Bancos de couro► Freios ABS► Piloto automático► Controle de estabilidade...São Paulo - SPR$ 117.000246 veículos encontradosPágina 1 de 25Motors Aplicação para treinamento de web scraping'

# %% [markdown]
# # 3.5. Acessando os atributos de uma tag

# %%
soup.img
# Out:
# <img alt="Alura" class="d-inline-block align-top" src="img/alura-logo.svg"/>

# %%
soup.img.attrs
# Out:
# {'src': 'img/alura-logo.svg',
#  'class': ['d-inline-block', 'align-top'],
#  'alt': 'Alura'}

# %%
soup.img.attrs.keys()
# Out:
# dict_keys(['src', 'class', 'alt'])

# %%
soup.img.attrs.values()
# Out:
# dict_values(['img/alura-logo.svg', ['d-inline-block', 'align-top'], 'Alura'])

# %%
soup.img['class']
# Out:
# ['d-inline-block', 'align-top']

# %%
soup.img.get('src')
# Out:
# 'img/alura-logo.svg'

# %% [markdown]
# ---
# # <font color=green>4. PESQUISANDO COM O BEAUTIFULSOUP

# %% [markdown]
# # 4.1. Os métodos *find()* e *findAll()*

# %% [markdown]
# - ### *find(tag, attributes, recursive, text, **kwargs)*
#
# - ### *findAll(tag, attributes, recursive, text, limit, **kwargs)*
#
# #### https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find
# #### https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-all
#
# > **Observação:**
# > - *findAll()* também pode ser utilizado como *find_all()*

# %% [markdown]
# ### Método *find()*

# %%
soup.find('img')
# Out:
# <img alt="Alura" class="d-inline-block align-top" src="img/alura-logo.svg"/>

# %%
soup.img
# Out:
# <img alt="Alura" class="d-inline-block align-top" src="img/alura-logo.svg"/>

# %% [markdown]
# ### Método *findAll()*

# %%
soup.findAll('img')
# Out:
# [<img alt="Alura" class="d-inline-block align-top" src="img/alura-logo.svg"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/bmw-m2/bmw-m2-2970882__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/alfa/alfa-1823056__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/puech/puech-4055386__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-murcielago/lamborghini-murcielago-2872974__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/aston-martin/aston-martin-2977916__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/tvr/tvr-2943925__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/excalibur/excalibur-2916730__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/mclaren/mclaren-2855240__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/toyota/toyota-3245397__340.jpg" width="220"/>,
#  <img alt="Alura" class="d-inline-block align-top" src="img/alura-logo.svg"/>]

# %% [markdown]
# ### Comando equivalente ao método *find()*

# %%
soup.findAll('img', limit = 1)[0]
# Out:
# <img alt="Alura" class="d-inline-block align-top" src="img/alura-logo.svg"/>

# %% [markdown]
# ### Atalho para o método *findAll()*

# %%
soup('img')
# Out:
# [<img alt="Alura" class="d-inline-block align-top" src="img/alura-logo.svg"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/bmw-m2/bmw-m2-2970882__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/alfa/alfa-1823056__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/puech/puech-4055386__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-murcielago/lamborghini-murcielago-2872974__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/aston-martin/aston-martin-2977916__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/tvr/tvr-2943925__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/excalibur/excalibur-2916730__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/mclaren/mclaren-2855240__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/toyota/toyota-3245397__340.jpg" width="220"/>,
#  <img alt="Alura" class="d-inline-block align-top" src="img/alura-logo.svg"/>]

# %% [markdown]
# ### Passando listas de TAGs

# %%
soup.findAll(['h1', 'h2', 'h3', 'h4', 'h5', 'h6'])
# Out:
# [<h5 class="modal-title" id="loadingModal_label"><span class="glyphicon glyphicon-refresh"></span>Aguarde... </h5>,
#  <h4><b id="loadingModal_content"></b></h4>,
#  <h1 class="sub-header">Veículos de Luxo Novos e Usados - Todas as Marcas</h1>]

# %% [markdown]
# ### Utilizando o argumento *attributes*

# %%
soup.findAll('p', {"class": "txt-value"})
# Out:
# [<p class="txt-value">R$ 338.000</p>,
#  <p class="txt-value">R$ 346.000</p>,
#  <p class="txt-value">R$ 480.000</p>,
#  <p class="txt-value">R$ 133.000</p>,
#  <p class="txt-value">R$ 175.000</p>,
#  <p class="txt-value">R$ 239.000</p>,
#  <p class="txt-value">R$ 115.000</p>,
#  <p class="txt-value">R$ 114.000</p>,
#  <p class="txt-value">R$ 75.000</p>,
#  <p class="txt-value">R$ 117.000</p>]

# %% [markdown]
# ### Buscando por conteúdo de uma TAG

# %%
soup.findAll('p', text = "Belo Horizonte - MG")
# Out:
# [<p class="txt-location">Belo Horizonte - MG</p>,
#  <p class="txt-location">Belo Horizonte - MG</p>,
#  <p class="txt-location">Belo Horizonte - MG</p>,
#  <p class="txt-location">Belo Horizonte - MG</p>,
#  <p class="txt-location">Belo Horizonte - MG</p>]

# %% [markdown]
# ### Utilizando diretamente os atributos

# %%
soup.findAll('img', alt="Foto")
# Out:
# [<img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/bmw-m2/bmw-m2-2970882__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/alfa/alfa-1823056__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/puech/puech-4055386__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-murcielago/lamborghini-murcielago-2872974__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/aston-martin/aston-martin-2977916__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/tvr/tvr-2943925__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/excalibur/excalibur-2916730__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/mclaren/mclaren-2855240__340.jpg" width="220"/>,
#  <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/toyota/toyota-3245397__340.jpg" width="220"/>]

# %%
for item in soup.findAll('img', alt="Foto"):
    print(item.get('src'))
# Out:
# https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg
# https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/bmw-m2/bmw-m2-2970882__340.jpg
# https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/alfa/alfa-1823056__340.jpg
# https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/puech/puech-4055386__340.jpg
# https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-murcielago/lamborghini-murcielago-2872974__340.jpg
# https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/aston-martin/aston-martin-2977916__340.jpg
# https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/tvr/tvr-2943925__340.jpg
# https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/excalibur/excalibur-2916730__340.jpg
# https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/mclaren/mclaren-2855240__340.jpg
# https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/toyota/toyota-3245397__340.jpg

# %% [markdown]
# ### Cuidado com o atributo "class"

# %%
soup.findAll('p', class_="txt-value")
# Out:
# [<p class="txt-value">R$ 338.000</p>,
#  <p class="txt-value">R$ 346.000</p>,
#  <p class="txt-value">R$ 480.000</p>,
#  <p class="txt-value">R$ 133.000</p>,
#  <p class="txt-value">R$ 175.000</p>,
#  <p class="txt-value">R$ 239.000</p>,
#  <p class="txt-value">R$ 115.000</p>,
#  <p class="txt-value">R$ 114.000</p>,
#  <p class="txt-value">R$ 75.000</p>,
#  <p class="txt-value">R$ 117.000</p>]

# %% [markdown]
# ### Obtendo todo o conteúdo de texto de uma página

# %%
soup.findAll(text = True)
# Out:
# ['html',
#  'Alura Motors',
#  " /*Regra para a animacao*/ @keyframes spin { 0% { transform: rotate(0deg); } 100% { transform: rotate(360deg); } } /*Mudando o tamanho do icone de resposta*/ div.glyphicon { color:#6B8E23; font-size: 38px; } /*Classe que mostra a animacao 'spin'*/ .loader { border: 16px solid #f3f3f3; border-radius: 50%; border-top: 16px solid #3498db; width: 80px; height: 80px; -webkit-animation: spin 2s linear infinite; animation: spin 2s linear infinite; } ",
#  ' requisitar("https://alura-scraping.herokuapp.com/produtos?_page="+1+"&_limit=10") ',
#  'You need to enable JavaScript to run this app.',
#  'Aguarde... ',
#  'Motors ',
#  'Hello World',
#  'Anúncios',
#  'Veículos de Luxo Novos e Usados - Todas as Marcas',
#  '246 veículos encontrados',
#  'Página 1 de 25',
#  'LAMBORGHINI AVENTADOR',
#  'USADO',
#  'Motor 1.8 16v',
#  'Ano 1993 - 55.286 km',
#  '► 4 X 4',
#  '► Câmera de estacionamento',
#  '► Controle de tração',
#  '► Sensor de estacionamento',
#  '...',
#  'Belo Horizonte - MG',
#  'R$ 338.000',
#  'BMW M2',
#  'USADO',
#  'Motor 3.0 32v',
#  'Ano 2018 - 83.447 km',
#  '► Câmera de estacionamento',
#  '► Controle de estabilidade',
#  '► Travas elétricas',
#  '► Freios ABS',
#  '...',
#  'Belo Horizonte - MG',
#  'R$ 346.000',
#  'ALFA',
#  'USADO',
#  'Motor 1.8 16v',
#  'Ano 2004 - 19.722 km',
#  '► Central multimídia',
#  '► Bancos de couro',
#  '► Rodas de liga',
#  '► Câmera de estacionamento',
#  '...',
#  'Rio de Janeiro - RJ',
#  'R$ 480.000',
#  'PUECH',
#  'USADO',
#  'Motor Diesel V8',
#  'Ano 1992 - 34.335 km',
#  '► Bancos de couro',
#  '► Freios ABS',
#  '► Rodas de liga',
#  '► Câmbio automático',
#  '...',
#  'São Paulo - SP',
#  'R$ 133.000',
#  'LAMBORGHINI MURCIELAGO',
#  'USADO',
#  'Motor 1.0 8v',
#  'Ano 1991 - 464 km',
#  '► Central multimídia',
#  '► Teto panorâmico',
#  '► Sensor crepuscular',
#  '► Piloto automático',
#  '...',
#  'Belo Horizonte - MG',
#  'R$ 175.000',
#  'ASTON MARTIN',
#  'USADO',
#  'OPORTUNIDADE',
#  'Motor Diesel V6',
#  'Ano 2004 - 50.189 km',
#  '► Painel digital',
#  '► Controle de tração',
#  '► Teto panorâmico',
#  '► Central multimídia',
#  '...',
#  'Belo Horizonte - MG',
#  'R$ 239.000',
#  'TVR',
#  'USADO',
#  'Motor 4.0 Turbo',
#  'Ano 2014 - 17.778 km',
#  '► 4 X 4',
#  '► Teto panorâmico',
#  '► Central multimídia',
#  '► Controle de estabilidade',
#  '...',
#  'Belo Horizonte - MG',
#  'R$ 115.000',
#  'EXCALIBUR',
#  'USADO',
#  'Motor 3.0 32v',
#  'Ano 2009 - 81.251 km',
#  '► Painel digital',
#  '► Câmbio automático',
#  '► Sensor de chuva',
#  '► Travas elétricas',
#  '...',
#  'Rio de Janeiro - RJ',
#  'R$ 114.000',
#  'MCLAREN',
#  'NOVO',
#  'Motor Diesel',
#  'Ano 2019 - 0 km',
#  '► Central multimídia',
#  '► Câmera de estacionamento',
#  '► Câmbio automático',
#  '► Ar condicionado',
#  '...',
#  'São Paulo - SP',
#  'R$ 75.000',
#  'TOYOTA',
#  'USADO',
#  'OPORTUNIDADE',
#  'Motor 4.0 Turbo',
#  'Ano 1999 - 12.536 km',
#  '► Bancos de couro',
#  '► Freios ABS',
#  '► Piloto automático',
#  '► Controle de estabilidade',
#  '...',
#  'São Paulo - SP',
#  'R$ 117.000',
#  '246 veículos encontrados',
#  'Página 1 de 25',
#  'Motors ',
#  'Aplicação para treinamento de web scraping']

# %% [markdown]
# # 4.2. Outros métodos de pesquisa

# %% [markdown]
# - ### *findParent(tag, attributes, text, **kwargs)*
#
# - ### *findParents(tag, attributes, text, limit, **kwargs)*
#
# #### https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-parents-and-find-parent
#
# > **Observação:**
# > - *findParent()* e *findParents()* também podem ser utilizados como *find_parent()* e *find_parents()*, respectivamente.
# ---
# - ### *findNextSibling(tag, attributes, text, **kwargs)*
#
# - ### *findNextSiblings(tag, attributes, text, limit, **kwargs)*
#
# - ### *findPreviousSibling(tag, attributes, text, **kwargs)*
#
# - ### *findPreviousSiblings(tag, attributes, text, limit, **kwargs)*
#
# #### https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-next-siblings-and-find-next-sibling
# #### https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-previous-siblings-and-find-previous-sibling
#
# > **Observação:**
# > - *findNextSibling()*, *findNextSiblings()*, *findPreviousSibling()* e *findPreviousSiblings()* também podem ser utilizados como *find_next_sibling()*, *find_next_siblings()*, *find_previous_sibling()* e *find_previous_siblings()*, respectivamente.
# ---
# - ### *findNext(tag, attributes, text, **kwargs)*
#
# - ### *findAllNext(tag, attributes, text, limit, **kwargs)*
#
# - ### *findPrevious(tag, attributes, text, **kwargs)*
#
# - ### *findAllPrevious(tag, attributes, text, limit, **kwargs)*
#
# #### https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-all-next-and-find-next
# #### https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-all-previous-and-find-previous
#
# > **Observação:**
# > - *findNext()*, *findAllNext()*, *findPrevious* e *findAllPrevious* também podem ser utilizados como *find_next()*, *find_all_next()*, *find_previous()* e *find_all_previous()*, respectivamente.

# %% [markdown]
# ## HTML de exemplo para ilustrar a utilização dos métodos de pesquisa do BeautifulSoup

# %% [markdown]
# <img src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/BeautifulSoup-method.png" width=80%>

# %% [markdown]
# ---
# ## Resultado

# %% [markdown]
# <html>
#     <body>
#         <div id=“container-a”>
#             <h1>Título A</h1>
#             <h2 class="ref-a">Sub título A</h2>
#             <p>Texto de conteúdo A</p>
#         </div>
#         <div id=“container-b”>
#             <h1>Título B</h1>
#             <h2 class="ref-b">Sub título B</h2>
#             <p>Texto de conteúdo B</p>
#         </div>
#     </body>
# </html>

# %%
html_teste = """
    <html>
        <body>
            <div id="container-a">
                <h1>Título A</h1>
                <h2 class="ref-a">Sub título A</h2>
                <p>Texto de conteúdo A</p>
            </div>
            <div id="container-b">
                <h1>Título B</h1>
                <h2 class="ref-b">Sub título B</h2>
                <p>Texto de conteúdo B</p>
            </div>
        </body>
    </html>
"""

# %% [markdown]
# ### Tratamentos para a string HTML

# %%
html_teste
# Out:
# '\n    <html>\n        <body>\n            <div id="container-a">\n                <h1>Título A</h1>\n                <h2 class="ref-a">Sub título A</h2>\n                <p>Texto de conteúdo A</p>\n            </div>\n            <div id="container-b">\n                <h1>Título B</h1>\n                <h2 class="ref-b">Sub título B</h2>\n                <p>Texto de conteúdo B</p>\n            </div>\n        </body>\n    </html>\n'

# %%
html_teste = trata_html(html_teste)
html_teste
# Out:
# '<html><body><div id="container-a"><h1>Título A</h1><h2 class="ref-a">Sub título A</h2><p>Texto de conteúdo A</p></div><div id="container-b"><h1>Título B</h1><h2 class="ref-b">Sub título B</h2><p>Texto de conteúdo B</p></div></body></html>'

# %% [markdown]
# ### Criando o objeto BeautifulSoup

# %%
soup = BeautifulSoup(html_teste, 'html.parser')
soup
# Out:
# <html><body><div id="container-a"><h1>Título A</h1><h2 class="ref-a">Sub título A</h2><p>Texto de conteúdo A</p></div><div id="container-b"><h1>Título B</h1><h2 class="ref-b">Sub título B</h2><p>Texto de conteúdo B</p></div></body></html>

# %% [markdown]
# ### Parents

# %%
soup.find('h2')
# Out:
# <h2 class="ref-a">Sub título A</h2>

# %%
soup.find('h2').find_parent('div')
# Out:
# <div id="container-a"><h1>Título A</h1><h2 class="ref-a">Sub título A</h2><p>Texto de conteúdo A</p></div>

# %%
soup.find('h2').find_parents()
# Out:
# [<div id="container-a"><h1>Título A</h1><h2 class="ref-a">Sub título A</h2><p>Texto de conteúdo A</p></div>,
#  <body><div id="container-a"><h1>Título A</h1><h2 class="ref-a">Sub título A</h2><p>Texto de conteúdo A</p></div><div id="container-b"><h1>Título B</h1><h2 class="ref-b">Sub título B</h2><p>Texto de conteúdo B</p></div></body>,
#  <html><body><div id="container-a"><h1>Título A</h1><h2 class="ref-a">Sub título A</h2><p>Texto de conteúdo A</p></div><div id="container-b"><h1>Título B</h1><h2 class="ref-b">Sub título B</h2><p>Texto de conteúdo B</p></div></body></html>,
#  <html><body><div id="container-a"><h1>Título A</h1><h2 class="ref-a">Sub título A</h2><p>Texto de conteúdo A</p></div><div id="container-b"><h1>Título B</h1><h2 class="ref-b">Sub título B</h2><p>Texto de conteúdo B</p></div></body></html>]

# %%
soup.findAll('h2')
# Out:
# [<h2 class="ref-a">Sub título A</h2>, <h2 class="ref-b">Sub título B</h2>]

# %%
for item in soup.findAll('h2'):
    print(item.find_parent('div'))
# Out:
# <div id="container-a"><h1>Título A</h1><h2 class="ref-a">Sub título A</h2><p>Texto de conteúdo A</p></div>
# <div id="container-b"><h1>Título B</h1><h2 class="ref-b">Sub título B</h2><p>Texto de conteúdo B</p></div>

# %% [markdown]
# ## Siblings

# %%
soup.find('h2').findNextSibling()
# Out:
# <p>Texto de conteúdo A</p>

# %%
soup.find('h2').findPreviousSibling()
# Out:
# <h1>Título A</h1>

# %%
soup.find('p').findPreviousSiblings()
# Out:
# [<h2 class="ref-a">Sub título A</h2>, <h1>Título A</h1>]

# %% [markdown]
# ## Next e Previous

# %%
soup.find('h2').findNext()
# Out:
# <p>Texto de conteúdo A</p>

# %%
soup.find('h2').findPrevious()
# Out:
# <h1>Título A</h1>

# %%
soup.find('h2').findAllNext()
# Out:
# [<p>Texto de conteúdo A</p>,
#  <div id="container-b"><h1>Título B</h1><h2 class="ref-b">Sub título B</h2><p>Texto de conteúdo B</p></div>,
#  <h1>Título B</h1>,
#  <h2 class="ref-b">Sub título B</h2>,
#  <p>Texto de conteúdo B</p>]

# %% [markdown]
# # <font color=green>5. WEB SCRAPING DO SITE ALURA MOTORS - OBTENDO OS DADOS DE UM ANÚNCIO

# %% [markdown]
# # 5.1. Identificando e selecionando os dados no HTML

# %% [markdown]
# ### Obtendo o HTML e criando o objeto BeautifulSoup

# %%
response = urlopen('https://alura-site-scraping.herokuapp.com/index.php')
html = response.read().decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="pt-br">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <title>Alura Motors</title>
# <style>
# 		/*Regra para a animacao*/
# 		@keyframes spin {
# 			0% { transform: rotate(0deg); }
# 			100% { transform: rotate(360deg); }
# 		}
# 		/*Mudando o tamanho do icone de resposta*/
# 		div.glyphicon {
# 			color:#6B8E23;
# 			font-size: 38px;
# 		}
# 		/*Classe que mostra a animacao 'spin'*/
# 		.loader {
# 			border: 16px solid #f3f3f3;
# 			border-radius: 50%;
# 			border-top: 16px solid #3498db;
# 			width: 80px;
# 			height: 80px;
# 			-webkit-animation: spin 2s linear infinite;
# 			animation: spin 2s linear infinite;
# 		}
# 	</style>
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" rel="stylesheet"/>
# <link href="css/styles.css" media="all" rel="stylesheet"/>
# <script src="https://code.jquery.com/jquery-1.12.4.js"></script>
# <script crossorigin="anonymous" integrity="sha384-Tc5IQib027qvyjSMfHjOMaLkfuWVxZxUPnCJA7l2mCWNIpG9mGCD8wGNIcPD7Txa" src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js"></script>
# <script src="js/index.js" type="text/javascript"></script>
# <script>
# 		requisitar("https://alura-scraping.herokuapp.com/produtos?_page="+1+"&_limit=10")
# 	</script>
# </head>
# <body cz-shortcut-listen="true">
# <noscript>You need to enable JavaScript to run this app.</noscript>
# <div aria-labelledby="loadingModal_label" class="modal fade" data-backdrop="static" id="loadingModal" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <h5 class="modal-title" id="loadingModal_label">
# <span class="glyphicon glyphicon-refresh"></span>Aguarde...
# 					</h5>
# </div>
# <div class="modal-body">
# <div class="alert" role="alert">
# <center>
# <div class="loader" id="loader"></div><br/>
# <h4><b id="loadingModal_content"></b></h4>
# </center>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div id="root">
# <header>
# <nav class="navbar navbar-inverse" style="margin-bottom: 0;">
# <div class="container" style="margin-bottom: -20px;">
# <div class="navbar">
# <a class="navbar-brand" href="./index.php" title="Alura Motors">
# <img alt="Alura" class="d-inline-block align-top" src="img/alura-logo.svg"/>Motors
# 						</a>
# <ul class="nav navbar-nav" style="margin-top: 35px;">
# <li><a href="./hello-world.php">Hello World</a></li>
# <li><a href="./index.php">Anúncios</a></li>
# </ul>
# </div>
# </div>
# </nav>
# </header>
# <div class="container">
# <h1 class="sub-header">Veículos de Luxo Novos e Usados - Todas as Marcas</h1>
# <div class="row">
# <div class="col-md-12">
# <div class="container" style="width: 100%">
# <div class="type-select">246 veículos encontrados</div>
# <div class="container-pagination" style="float: right">
# <span class="info-pages">Página 1 de 25</span>
# </div>
# </div>
# <div id="container-cards" style="height: 100%">
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">LAMBORGHINI AVENTADOR</p>
# <p class="txt-category badge badge-secondary inline">USADO</p>
# <p class="txt-motor">Motor 1.8 16v</p>
# <p class="txt-description">Ano 1993 - 55.286 km</p>
# <ul class="lst-items">
# <li class="txt-items">► 4 X 4</li>
# <li class="txt-items">► Câmera de estacionamento</li>
# <li class="txt-items">► Controle de tração</li>
# <li class="txt-items">► Sensor de estacionamento</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">Belo Horizonte - MG</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 338.000</p>
# </div>
# </div>
# </div>
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/bmw-m2/bmw-m2-2970882__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">BMW M2</p>
# <p class="txt-category badge badge-secondary inline">USADO</p>
# <p class="txt-motor">Motor 3.0 32v</p>
# <p class="txt-description">Ano 2018 - 83.447 km</p>
# <ul class="lst-items">
# <li class="txt-items">► Câmera de estacionamento</li>
# <li class="txt-items">► Controle de estabilidade</li>
# <li class="txt-items">► Travas elétricas</li>
# <li class="txt-items">► Freios ABS</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">Belo Horizonte - MG</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 346.000</p>
# </div>
# </div>
# </div>
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/alfa/alfa-1823056__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">ALFA</p>
# <p class="txt-category badge badge-secondary inline">USADO</p>
# <p class="txt-motor">Motor 1.8 16v</p>
# <p class="txt-description">Ano 2004 - 19.722 km</p>
# <ul class="lst-items">
# <li class="txt-items">► Central multimídia</li>
# <li class="txt-items">► Bancos de couro</li>
# <li class="txt-items">► Rodas de liga</li>
# <li class="txt-items">► Câmera de estacionamento</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">Rio de Janeiro - RJ</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 480.000</p>
# </div>
# </div>
# </div>
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/puech/puech-4055386__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">PUECH</p>
# <p class="txt-category badge badge-secondary inline">USADO</p>
# <p class="txt-motor">Motor Diesel V8</p>
# <p class="txt-description">Ano 1992 - 34.335 km</p>
# <ul class="lst-items">
# <li class="txt-items">► Bancos de couro</li>
# <li class="txt-items">► Freios ABS</li>
# <li class="txt-items">► Rodas de liga</li>
# <li class="txt-items">► Câmbio automático</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">São Paulo - SP</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 133.000</p>
# </div>
# </div>
# </div>
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-murcielago/lamborghini-murcielago-2872974__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">LAMBORGHINI MURCIELAGO</p>
# <p class="txt-category badge badge-secondary inline">USADO</p>
# <p class="txt-motor">Motor 1.0 8v</p>
# <p class="txt-description">Ano 1991 - 464 km</p>
# <ul class="lst-items">
# <li class="txt-items">► Central multimídia</li>
# <li class="txt-items">► Teto panorâmico</li>
# <li class="txt-items">► Sensor crepuscular</li>
# <li class="txt-items">► Piloto automático</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">Belo Horizonte - MG</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 175.000</p>
# </div>
# </div>
# </div>
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/aston-martin/aston-martin-2977916__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">ASTON MARTIN</p>
# <p class="txt-category badge badge-secondary inline">USADO</p>
# <p class="txt-opportunity badge badge-danger inline">OPORTUNIDADE</p>
# <p class="txt-motor">Motor Diesel V6</p>
# <p class="txt-description">Ano 2004 - 50.189 km</p>
# <ul class="lst-items">
# <li class="txt-items">► Painel digital</li>
# <li class="txt-items">► Controle de tração</li>
# <li class="txt-items">► Teto panorâmico</li>
# <li class="txt-items">► Central multimídia</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">Belo Horizonte - MG</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 239.000</p>
# </div>
# </div>
# </div>
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/tvr/tvr-2943925__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">TVR</p>
# <p class="txt-category badge badge-secondary inline">USADO</p>
# <p class="txt-motor">Motor 4.0 Turbo</p>
# <p class="txt-description">Ano 2014 - 17.778 km</p>
# <ul class="lst-items">
# <li class="txt-items">► 4 X 4</li>
# <li class="txt-items">► Teto panorâmico</li>
# <li class="txt-items">► Central multimídia</li>
# <li class="txt-items">► Controle de estabilidade</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">Belo Horizonte - MG</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 115.000</p>
# </div>
# </div>
# </div>
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/excalibur/excalibur-2916730__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">EXCALIBUR</p>
# <p class="txt-category badge badge-secondary inline">USADO</p>
# <p class="txt-motor">Motor 3.0 32v</p>
# <p class="txt-description">Ano 2009 - 81.251 km</p>
# <ul class="lst-items">
# <li class="txt-items">► Painel digital</li>
# <li class="txt-items">► Câmbio automático</li>
# <li class="txt-items">► Sensor de chuva</li>
# <li class="txt-items">► Travas elétricas</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">Rio de Janeiro - RJ</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 114.000</p>
# </div>
# </div>
# </div>
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/mclaren/mclaren-2855240__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">MCLAREN</p>
# <p class="txt-category badge badge-secondary inline">NOVO</p>
# <p class="txt-motor">Motor Diesel</p>
# <p class="txt-description">Ano 2019 - 0 km</p>
# <ul class="lst-items">
# <li class="txt-items">► Central multimídia</li>
# <li class="txt-items">► Câmera de estacionamento</li>
# <li class="txt-items">► Câmbio automático</li>
# <li class="txt-items">► Ar condicionado</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">São Paulo - SP</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 75.000</p>
# </div>
# </div>
# </div>
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/toyota/toyota-3245397__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">TOYOTA</p>
# <p class="txt-category badge badge-secondary inline">USADO</p>
# <p class="txt-opportunity badge badge-danger inline">OPORTUNIDADE</p>
# <p class="txt-motor">Motor 4.0 Turbo</p>
# <p class="txt-description">Ano 1999 - 12.536 km</p>
# <ul class="lst-items">
# <li class="txt-items">► Bancos de couro</li>
# <li class="txt-items">► Freios ABS</li>
# <li class="txt-items">► Piloto automático</li>
# <li class="txt-items">► Controle de estabilidade</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">São Paulo - SP</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 117.000</p>
# </div>
# </div>
# </div> </div>
# <div class="type-select">246 veículos encontrados</div>
# <div class="container-pagination" style="float: right">
# <span class="info-pages">Página 1 de 25</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </body></html>
# <footer>
# <nav class="navbar navbar-inverse">
# <div class="container" style="margin-bottom: 10px;">
# <div class="navbar">
# <a class="navbar-brand" href="./index.php" title="Alura Motors">
# <img alt="Alura" class="d-inline-block align-top" src="img/alura-logo.svg"/>Motors
# 						</a>
# <p style="color: #fff; text-align: center; margin-top: 40px;">Aplicação para treinamento de web scraping</p>
# </div>
# </div>
# </nav>
# </footer>

# %% [markdown]
# ### Criando variávels para armazenar informações

# %%
cards = []
card = {}

# %% [markdown]
# ### Obtendo os dados do primeiro CARD

# %%
anuncio = soup.find('div', {'class': 'well card'})
anuncio
# Out:
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">LAMBORGHINI AVENTADOR</p>
# <p class="txt-category badge badge-secondary inline">USADO</p>
# <p class="txt-motor">Motor 1.8 16v</p>
# <p class="txt-description">Ano 1993 - 55.286 km</p>
# <ul class="lst-items">
# <li class="txt-items">► 4 X 4</li>
# <li class="txt-items">► Câmera de estacionamento</li>
# <li class="txt-items">► Controle de tração</li>
# <li class="txt-items">► Sensor de estacionamento</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">Belo Horizonte - MG</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 338.000</p>
# </div>
# </div>
# </div>

# %% [markdown]
# # 5.2. Obtendo o VALOR do veículo anunciado

# %%
anuncio
# Out:
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">LAMBORGHINI AVENTADOR</p>
# <p class="txt-category badge badge-secondary inline">USADO</p>
# <p class="txt-motor">Motor 1.8 16v</p>
# <p class="txt-description">Ano 1993 - 55.286 km</p>
# <ul class="lst-items">
# <li class="txt-items">► 4 X 4</li>
# <li class="txt-items">► Câmera de estacionamento</li>
# <li class="txt-items">► Controle de tração</li>
# <li class="txt-items">► Sensor de estacionamento</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">Belo Horizonte - MG</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 338.000</p>
# </div>
# </div>
# </div>

# %%
anuncio.find('div', {'class': 'value-card'})
# Out:
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 338.000</p>
# </div>
# </div>

# %%
anuncio.find('p', {'class': 'txt-value'}).getText()
# Out:
# 'R$ 338.000'

# %%
card['value'] = anuncio.find('p', {'class': 'txt-value'}).getText()

# %%
card
# Out:
# {'value': 'R$ 338.000'}

# %% [markdown]
# ### <font color=red>Resumo

# %%
# Valor
card['value'] = anuncio.find('p', {'class': 'txt-value'}).getText()

# %% [markdown]
# # 5.3. Obtendo as INFORMAÇÕES sobre o veículo anunciado

# %%
anuncio.find('div', {'class': 'body-card'}).findAll('p')
# Out:
# [<p class="txt-name inline">LAMBORGHINI AVENTADOR</p>,
#  <p class="txt-category badge badge-secondary inline">USADO</p>,
#  <p class="txt-motor">Motor 1.8 16v</p>,
#  <p class="txt-description">Ano 1993 - 55.286 km</p>,
#  <p class="txt-location">Belo Horizonte - MG</p>]

# %%
infos = anuncio.find('div', {'class': 'body-card'}).findAll('p')

# %%
for info in infos:
    print(info.get('class'), ' - ', info.get_text())
# Out:
# ['txt-name', 'inline']  -  LAMBORGHINI AVENTADOR
# ['txt-category', 'badge', 'badge-secondary', 'inline']  -  USADO
# ['txt-motor']  -  Motor 1.8 16v
# ['txt-description']  -  Ano 1993 - 55.286 km
# ['txt-location']  -  Belo Horizonte - MG

# %%
for info in infos:
    print(info.get('class')[0], ' - ', info.get_text())
# Out:
# txt-name  -  LAMBORGHINI AVENTADOR
# txt-category  -  USADO
# txt-motor  -  Motor 1.8 16v
# txt-description  -  Ano 1993 - 55.286 km
# txt-location  -  Belo Horizonte - MG

# %%
for info in infos:
    print(info.get('class')[0].split('-'), ' - ', info.get_text())
# Out:
# ['txt', 'name']  -  LAMBORGHINI AVENTADOR
# ['txt', 'category']  -  USADO
# ['txt', 'motor']  -  Motor 1.8 16v
# ['txt', 'description']  -  Ano 1993 - 55.286 km
# ['txt', 'location']  -  Belo Horizonte - MG

# %%
for info in infos:
    print(info.get('class')[0].split('-')[-1], ' - ', info.get_text())
# Out:
# name  -  LAMBORGHINI AVENTADOR
# category  -  USADO
# motor  -  Motor 1.8 16v
# description  -  Ano 1993 - 55.286 km
# location  -  Belo Horizonte - MG

# %%
for info in infos:
    card[info.get('class')[0].split('-')[-1]] = info.get_text()

# %%
card
# Out:
# {'value': 'R$ 338.000',
#  'name': 'LAMBORGHINI AVENTADOR',
#  'category': 'USADO',
#  'motor': 'Motor 1.8 16v',
#  'description': 'Ano 1993 - 55.286 km',
#  'location': 'Belo Horizonte - MG'}

# %% [markdown]
# ### <font color=red>Resumo

# %%
# Informações
infos = anuncio.find('div', {'class': 'body-card'}).findAll('p')
for info in infos:
    card[info.get('class')[0].split('-')[-1]] = info.get_text()

# %% [markdown]
# # 5.4. Obtendo os ACESSÓRIOS do veículo anunciado

# %%
anuncio.find('div', {'class': 'body-card'}).ul.findAll('li')
# Out:
# [<li class="txt-items">► 4 X 4</li>,
#  <li class="txt-items">► Câmera de estacionamento</li>,
#  <li class="txt-items">► Controle de tração</li>,
#  <li class="txt-items">► Sensor de estacionamento</li>,
#  <li class="txt-items">...</li>]

# %%
items = anuncio.find('div', {'class': 'body-card'}).ul.findAll('li')
items
# Out:
# [<li class="txt-items">► 4 X 4</li>,
#  <li class="txt-items">► Câmera de estacionamento</li>,
#  <li class="txt-items">► Controle de tração</li>,
#  <li class="txt-items">► Sensor de estacionamento</li>,
#  <li class="txt-items">...</li>]

# %%
items.pop()
# Out:
# <li class="txt-items">...</li>

# %%
items
# Out:
# [<li class="txt-items">► 4 X 4</li>,
#  <li class="txt-items">► Câmera de estacionamento</li>,
#  <li class="txt-items">► Controle de tração</li>,
#  <li class="txt-items">► Sensor de estacionamento</li>]

# %%
for item in items:
    print(item.getText().replace('► ', ''))
# Out:
# 4 X 4
# Câmera de estacionamento
# Controle de tração
# Sensor de estacionamento

# %%
acessorios = []
for item in items:
    acessorios.append(item.getText().replace('► ', ''))
    
acessorios
# Out:
# ['4 X 4',
#  'Câmera de estacionamento',
#  'Controle de tração',
#  'Sensor de estacionamento']

# %%
card['items'] = acessorios

# %%
card
# Out:
# {'value': 'R$ 338.000',
#  'name': 'LAMBORGHINI AVENTADOR',
#  'category': 'USADO',
#  'motor': 'Motor 1.8 16v',
#  'description': 'Ano 1993 - 55.286 km',
#  'location': 'Belo Horizonte - MG',
#  'items': ['4 X 4',
#   'Câmera de estacionamento',
#   'Controle de tração',
#   'Sensor de estacionamento']}

# %% [markdown]
# ### <font color=red>Resumo

# %%
# Acessórios
items = anuncio.find('div', {'class': 'body-card'}).ul.findAll('li')
items.pop()
acessorios = []
for item in items:
    acessorios.append(item.getText().replace('► ', ''))
card['items'] = acessorios

# %% [markdown]
# # 5.5 Criando um DataFrame com os dados coletados do Alura Motors

# %%
card
# Out:
# {'value': 'R$ 338.000',
#  'name': 'LAMBORGHINI AVENTADOR',
#  'category': 'USADO',
#  'motor': 'Motor 1.8 16v',
#  'description': 'Ano 1993 - 55.286 km',
#  'location': 'Belo Horizonte - MG',
#  'items': ['4 X 4',
#   'Câmera de estacionamento',
#   'Controle de tração',
#   'Sensor de estacionamento']}

# %%
import pandas as pd

# %%
dataset = pd.DataFrame(card)

# %%
dataset
# Out:
#         value                   name category          motor  \
# 0  R$ 338.000  LAMBORGHINI AVENTADOR    USADO  Motor 1.8 16v
# 1  R$ 338.000  LAMBORGHINI AVENTADOR    USADO  Motor 1.8 16v
# 2  R$ 338.000  LAMBORGHINI AVENTADOR    USADO  Motor 1.8 16v
# 3  R$ 338.000  LAMBORGHINI AVENTADOR    USADO  Motor 1.8 16v
#
#             description             location                     items
# 0  Ano 1993 - 55.286 km  Belo Horizonte - MG                     4 X 4
# 1  Ano 1993 - 55.286 km  Belo Horizonte - MG  Câmera de estacionamento
# 2  Ano 1993 - 55.286 km  Belo Horizonte - MG        Controle de tração
# 3  Ano 1993 - 55.286 km  Belo Horizonte - MG  Sensor de estacionamento

# %%
dataset = pd.DataFrame.from_dict(card, orient = 'index')
dataset
# Out:
#                                                              0
# value                                               R$ 338.000
# name                                     LAMBORGHINI AVENTADOR
# category                                                 USADO
# motor                                            Motor 1.8 16v
# description                               Ano 1993 - 55.286 km
# location                                   Belo Horizonte - MG
# items        [4 X 4, Câmera de estacionamento, Controle de ...

# %%
dataset = pd.DataFrame.from_dict(card, orient = 'index').T
dataset
# Out:
#         value                   name category          motor  \
# 0  R$ 338.000  LAMBORGHINI AVENTADOR    USADO  Motor 1.8 16v
#
#             description             location  \
# 0  Ano 1993 - 55.286 km  Belo Horizonte - MG
#
#                                                items
# 0  [4 X 4, Câmera de estacionamento, Controle de ...

# %%
dataset.to_csv('./output/data/dataset.csv', sep=';', index = False, encoding = 'utf-8-sig')

# %% [markdown]
# # 5.6. Obtendo a FOTO do anúncio

# %%
image = anuncio.find('div', {'class': 'image-card'}).img
image
# Out:
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg" width="220"/>

# %%
image.get('src')
# Out:
# 'https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg'

# %%
print(image.get('src'))
# Out:
# https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg

# %% [markdown]
# ### Visualizando a FOTO no notebook (extra)

# %%
from IPython.core.display import display, HTML

display(HTML(str(anuncio.find('div', {'class': 'image-card'}).img)))
# Out:
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg" width="220"/>

# %%
display(HTML("<img src=" + anuncio.find('div', {'class': 'image-card'}).img.get('src') + ">"))
# Out:
# <img src=https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg>

# %% [markdown]
# ### Rotina para acessar e salvar a FOTO do anúncio

# %% [markdown]
# ## https://docs.python.org/3/library/urllib.request.html#urllib.request.urlretrieve

# %%
image.get('src').split('/')[-1]
# Out:
# 'lamborghini-aventador-2932196__340.jpg'

# %%
from urllib.request import urlretrieve

urlretrieve(image.get('src'), './output/img/' + image.get('src').split('/')[-1])
# Out:
# ('./output/img/lamborghini-aventador-2932196__340.jpg',
#  <http.client.HTTPMessage at 0x231b2211c50>)

# %% [markdown]
# ### <font color=red>Resumo

# %%
# Imagens
image = anuncio.find('div', {'class': 'image-card'}).img
urlretrieve(image.get('src'), './output/img/' + image.get('src').split('/')[-1])
# Out:
# ('./output/img/lamborghini-aventador-2932196__340.jpg',
#  <http.client.HTTPMessage at 0x231b221c240>)

# %% [markdown]
# # <font color=green>6. WEB SCRAPING DO SITE ALURA MOTORS - OBTENDO OS DADOS DE TODOS OS ANÚNCIOS DE UMA PÁGINA

# %% [markdown]
# # 6.1. Identificando as informações no HTML

# %%
len(soup.find('div', {"id": "container-cards"}).findAll('div', class_="card"))
# Out:
# 10

# %%
anuncios = soup.find('div', {"id": "container-cards"}).findAll('div', class_="card")

# %%
for anuncio in anuncios:
    print(str(anuncio) + "\n\n")
# Out:
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">LAMBORGHINI AVENTADOR</p>
# <p class="txt-category badge badge-secondary inline">USADO</p>
# <p class="txt-motor">Motor 1.8 16v</p>
# <p class="txt-description">Ano 1993 - 55.286 km</p>
# <ul class="lst-items">
# <li class="txt-items">► 4 X 4</li>
# <li class="txt-items">► Câmera de estacionamento</li>
# <li class="txt-items">► Controle de tração</li>
# <li class="txt-items">► Sensor de estacionamento</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">Belo Horizonte - MG</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 338.000</p>
# </div>
# </div>
# </div>
#
#
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/bmw-m2/bmw-m2-2970882__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">BMW M2</p>
# <p class="txt-category badge badge-secondary inline">USADO</p>
# <p class="txt-motor">Motor 3.0 32v</p>
# <p class="txt-description">Ano 2018 - 83.447 km</p>
# <ul class="lst-items">
# <li class="txt-items">► Câmera de estacionamento</li>
# <li class="txt-items">► Controle de estabilidade</li>
# <li class="txt-items">► Travas elétricas</li>
# <li class="txt-items">► Freios ABS</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">Belo Horizonte - MG</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 346.000</p>
# </div>
# </div>
# </div>
#
#
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/alfa/alfa-1823056__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">ALFA</p>
# <p class="txt-category badge badge-secondary inline">USADO</p>
# <p class="txt-motor">Motor 1.8 16v</p>
# <p class="txt-description">Ano 2004 - 19.722 km</p>
# <ul class="lst-items">
# <li class="txt-items">► Central multimídia</li>
# <li class="txt-items">► Bancos de couro</li>
# <li class="txt-items">► Rodas de liga</li>
# <li class="txt-items">► Câmera de estacionamento</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">Rio de Janeiro - RJ</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 480.000</p>
# </div>
# </div>
# </div>
#
#
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/puech/puech-4055386__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">PUECH</p>
# <p class="txt-category badge badge-secondary inline">USADO</p>
# <p class="txt-motor">Motor Diesel V8</p>
# <p class="txt-description">Ano 1992 - 34.335 km</p>
# <ul class="lst-items">
# <li class="txt-items">► Bancos de couro</li>
# <li class="txt-items">► Freios ABS</li>
# <li class="txt-items">► Rodas de liga</li>
# <li class="txt-items">► Câmbio automático</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">São Paulo - SP</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 133.000</p>
# </div>
# </div>
# </div>
#
#
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-murcielago/lamborghini-murcielago-2872974__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">LAMBORGHINI MURCIELAGO</p>
# <p class="txt-category badge badge-secondary inline">USADO</p>
# <p class="txt-motor">Motor 1.0 8v</p>
# <p class="txt-description">Ano 1991 - 464 km</p>
# <ul class="lst-items">
# <li class="txt-items">► Central multimídia</li>
# <li class="txt-items">► Teto panorâmico</li>
# <li class="txt-items">► Sensor crepuscular</li>
# <li class="txt-items">► Piloto automático</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">Belo Horizonte - MG</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 175.000</p>
# </div>
# </div>
# </div>
#
#
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/aston-martin/aston-martin-2977916__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">ASTON MARTIN</p>
# <p class="txt-category badge badge-secondary inline">USADO</p>
# <p class="txt-opportunity badge badge-danger inline">OPORTUNIDADE</p>
# <p class="txt-motor">Motor Diesel V6</p>
# <p class="txt-description">Ano 2004 - 50.189 km</p>
# <ul class="lst-items">
# <li class="txt-items">► Painel digital</li>
# <li class="txt-items">► Controle de tração</li>
# <li class="txt-items">► Teto panorâmico</li>
# <li class="txt-items">► Central multimídia</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">Belo Horizonte - MG</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 239.000</p>
# </div>
# </div>
# </div>
#
#
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/tvr/tvr-2943925__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">TVR</p>
# <p class="txt-category badge badge-secondary inline">USADO</p>
# <p class="txt-motor">Motor 4.0 Turbo</p>
# <p class="txt-description">Ano 2014 - 17.778 km</p>
# <ul class="lst-items">
# <li class="txt-items">► 4 X 4</li>
# <li class="txt-items">► Teto panorâmico</li>
# <li class="txt-items">► Central multimídia</li>
# <li class="txt-items">► Controle de estabilidade</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">Belo Horizonte - MG</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 115.000</p>
# </div>
# </div>
# </div>
#
#
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/excalibur/excalibur-2916730__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">EXCALIBUR</p>
# <p class="txt-category badge badge-secondary inline">USADO</p>
# <p class="txt-motor">Motor 3.0 32v</p>
# <p class="txt-description">Ano 2009 - 81.251 km</p>
# <ul class="lst-items">
# <li class="txt-items">► Painel digital</li>
# <li class="txt-items">► Câmbio automático</li>
# <li class="txt-items">► Sensor de chuva</li>
# <li class="txt-items">► Travas elétricas</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">Rio de Janeiro - RJ</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 114.000</p>
# </div>
# </div>
# </div>
#
#
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/mclaren/mclaren-2855240__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">MCLAREN</p>
# <p class="txt-category badge badge-secondary inline">NOVO</p>
# <p class="txt-motor">Motor Diesel</p>
# <p class="txt-description">Ano 2019 - 0 km</p>
# <ul class="lst-items">
# <li class="txt-items">► Central multimídia</li>
# <li class="txt-items">► Câmera de estacionamento</li>
# <li class="txt-items">► Câmbio automático</li>
# <li class="txt-items">► Ar condicionado</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">São Paulo - SP</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 75.000</p>
# </div>
# </div>
# </div>
#
#
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/toyota/toyota-3245397__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">TOYOTA</p>
# <p class="txt-category badge badge-secondary inline">USADO</p>
# <p class="txt-opportunity badge badge-danger inline">OPORTUNIDADE</p>
# <p class="txt-motor">Motor 4.0 Turbo</p>
# <p class="txt-description">Ano 1999 - 12.536 km</p>
# <ul class="lst-items">
# <li class="txt-items">► Bancos de couro</li>
# <li class="txt-items">► Freios ABS</li>
# <li class="txt-items">► Piloto automático</li>
# <li class="txt-items">► Controle de estabilidade</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">São Paulo - SP</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 117.000</p>
# </div>
# </div>
# </div>

# %% [markdown]
# # 6.2. Criando uma rotina de scraping

# %%
# Importando bibliotecas
from urllib.request import urlopen, urlretrieve
from bs4 import BeautifulSoup
import pandas as pd

# Declarando variável cards
cards = []

# Obtendo o HTML
response = urlopen('https://alura-site-scraping.herokuapp.com/index.php')
html = response.read().decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')

# Obtendo as TAGs de interesse
anuncios = soup.find('div', {"id": "container-cards"}).findAll('div', class_="card")

# Coletando as informações dos CARDS
for anuncio in anuncios:
    card = {}
    
    # Valor
    card['value'] = anuncio.find('p', {'class': 'txt-value'}).getText()

    # Informações
    infos = anuncio.find('div', {'class': 'body-card'}).findAll('p')
    for info in infos:
        card[info.get('class')[0].split('-')[-1]] = info.get_text()

    # Acessórios
    items = anuncio.find('div', {'class': 'body-card'}).ul.findAll('li')
    items.pop()
    acessorios = []
    for item in items:
        acessorios.append(item.get_text().replace('► ', ''))
    card['items'] = acessorios
    
    # Adicionando resultado a lista cards
    cards.append(card)

    # Imagens
    image = anuncio.find('div', {'class': 'image-card'}).img
    urlretrieve(image.get('src'), './output/img/' + image.get('src').split('/')[-1])     

# Criando um DataFrame com os resultados
dataset = pd.DataFrame(cards)
dataset.to_csv('./output/data/dataset.csv', sep=';', index = False, encoding = 'utf-8-sig')
dataset
# Out:
#   category           description  \
# 0    USADO  Ano 1993 - 55.286 km
# 1    USADO  Ano 2018 - 83.447 km
# 2    USADO  Ano 2004 - 19.722 km
# 3    USADO  Ano 1992 - 34.335 km
# 4    USADO     Ano 1991 - 464 km
# 5    USADO  Ano 2004 - 50.189 km
# 6    USADO  Ano 2014 - 17.778 km
# 7    USADO  Ano 2009 - 81.251 km
# 8     NOVO       Ano 2019 - 0 km
# 9    USADO  Ano 1999 - 12.536 km
#
#                                                items             location  \
# 0  [4 X 4, Câmera de estacionamento, Controle de ...  Belo Horizonte - MG
# 1  [Câmera de estacionamento, Controle de estabil...  Belo Horizonte - MG
# 2  [Central multimídia, Bancos de couro, Rodas de...  Rio de Janeiro - RJ
# 3  [Bancos de couro, Freios ABS, Rodas de liga, C...       São Paulo - SP
# 4  [Central multimídia, Teto panorâmico, Sensor c...  Belo Horizonte - MG
# 5  [Painel digital, Controle de tração, Teto pano...  Belo Horizonte - MG
# 6  [4 X 4, Teto panorâmico, Central multimídia, C...  Belo Horizonte - MG
# 7  [Painel digital, Câmbio automático, Sensor de ...  Rio de Janeiro - RJ
# 8  [Central multimídia, Câmera de estacionamento,...       São Paulo - SP
# 9  [Bancos de couro, Freios ABS, Piloto automátic...       São Paulo - SP
#
#              motor                    name   opportunity       value
# 0    Motor 1.8 16v   LAMBORGHINI AVENTADOR           NaN  R$ 338.000
# 1    Motor 3.0 32v                  BMW M2           NaN  R$ 346.000
# 2    Motor 1.8 16v                    ALFA           NaN  R$ 480.000
# 3  Motor Diesel V8                   PUECH           NaN  R$ 133.000
# 4     Motor 1.0 8v  LAMBORGHINI MURCIELAGO           NaN  R$ 175.000
# 5  Motor Diesel V6            ASTON MARTIN  OPORTUNIDADE  R$ 239.000
# 6  Motor 4.0 Turbo                     TVR           NaN  R$ 115.000
# 7    Motor 3.0 32v               EXCALIBUR           NaN  R$ 114.000
# 8     Motor Diesel                 MCLAREN           NaN   R$ 75.000
# 9  Motor 4.0 Turbo                  TOYOTA  OPORTUNIDADE  R$ 117.000

# %%
cards

# %% [markdown]
# # <font color=green>7. WEB SCRAPING DO SITE ALURA MOTORS - OBTENDO OS DADOS DE TODOS OS ANÚNCIOS DO SITE

# %% [markdown]
# # 7.1. Identificando as informações no HTML

# %%
soup.find('span', class_="info-pages")
# Out:
# <span class="info-pages">Página 1 de 25</span>

# %%
soup.find('span', class_="info-pages").get_text()
# Out:
# 'Página 1 de 25'

# %%
soup.find('span', class_="info-pages").get_text().split()
# Out:
# ['Página', '1', 'de', '25']

# %%
soup.find('span', class_="info-pages").get_text().split()[-1]
# Out:
# '25'

# %%
int(soup.find('span', class_="info-pages").get_text().split()[-1])
# Out:
# 25

# %% [markdown]
# # 7.2. Criando uma rotina de scraping

# %%
# Importando bibliotecas
from urllib.request import urlopen, urlretrieve
from bs4 import BeautifulSoup
import pandas as pd

# Declarando variável cards
cards = []

## Obtendo o HTML e o total de páginas
response = urlopen('https://alura-site-scraping.herokuapp.com/index.php')
html = response.read().decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
pages = int(soup.find('span', class_="info-pages").get_text().split()[-1])

## Iterando por todas as páginas do site
for i in range(pages):
    ## Obtendo o HTML
    response = urlopen('https://alura-site-scraping.herokuapp.com/index.php?page=' + str(i + 1))
    html = response.read().decode('utf-8')
    soup = BeautifulSoup(html, 'html.parser')

    # Obtendo as TAGs de interesse
    anuncios = soup.find('div', {"id": "container-cards"}).findAll('div', class_="card")

    # Coletando as informações dos CARDS
    for anuncio in anuncios:
        card = {}

        # Valor
        card['value'] = anuncio.find('p', {'class': 'txt-value'}).getText()

        # Informações
        infos = anuncio.find('div', {'class': 'body-card'}).findAll('p')
        for info in infos:
            card[info.get('class')[0].split('-')[-1]] = info.get_text()

        # Acessórios
        items = anuncio.find('div', {'class': 'body-card'}).ul.findAll('li')
        items.pop()
        acessorios = []
        for item in items:
            acessorios.append(item.get_text().replace('► ', ''))
        card['items'] = acessorios

        # Adicionando resultado a lista cards
        cards.append(card)

        # Imagens
        image = anuncio.find('div', {'class': 'image-card'}).img
        urlretrieve(image.get('src'), './output/img/' + image.get('src').split('/')[-1])     


# Criando um DataFrame com os resultados
dataset = pd.DataFrame(cards)
dataset.to_csv('./output/data/dataset.csv', sep=';', index = False, encoding = 'utf-8-sig')
dataset
# Out:
#     category            description  \
# 0      USADO   Ano 1993 - 55.286 km
# 1      USADO   Ano 2018 - 83.447 km
# 2      USADO   Ano 2004 - 19.722 km
# 3      USADO   Ano 1992 - 34.335 km
# 4      USADO      Ano 1991 - 464 km
# 5      USADO   Ano 2004 - 50.189 km
# 6      USADO   Ano 2014 - 17.778 km
# 7      USADO   Ano 2009 - 81.251 km
# 8       NOVO        Ano 2019 - 0 km
# 9      USADO   Ano 1999 - 12.536 km
# 10      NOVO        Ano 2019 - 0 km
# 11     USADO  Ano 2011 - 107.484 km
# 12     USADO      Ano 1992 - 908 km
# 13     USADO   Ano 2015 - 22.485 km
# 14     USADO   Ano 1996 - 23.007 km
# 15     USADO  Ano 2002 - 106.389 km
# 16     USADO   Ano 1990 - 78.181 km
# 17     USADO   Ano 1998 - 86.001 km
# 18      NOVO        Ano 2019 - 0 km
# 19     USADO   Ano 2017 - 10.747 km
# 20     USADO   Ano 1991 - 28.617 km
# 21      NOVO        Ano 2019 - 0 km
# 22      NOVO        Ano 2019 - 0 km
# 23     USADO   Ano 2009 - 67.480 km
# 24      NOVO        Ano 2019 - 0 km
# 25     USADO   Ano 1999 - 85.451 km
# 26      NOVO        Ano 2019 - 0 km
# 27     USADO  Ano 1996 - 107.305 km
# 28     USADO  Ano 1997 - 119.942 km
# 29     USADO   Ano 1993 - 86.338 km
# ..       ...                    ...
# 216     NOVO        Ano 2019 - 0 km
# 217    USADO   Ano 2009 - 64.735 km
# 218    USADO   Ano 2009 - 59.305 km
# 219    USADO   Ano 1990 - 92.448 km
# 220    USADO   Ano 2015 - 21.275 km
# 221    USADO   Ano 1994 - 86.170 km
# 222    USADO  Ano 2014 - 117.197 km
# 223    USADO   Ano 1995 - 30.961 km
# 224    USADO   Ano 1991 - 97.949 km
# 225    USADO   Ano 2016 - 18.870 km
# 226    USADO  Ano 2014 - 114.136 km
# 227     NOVO        Ano 2019 - 0 km
# 228     NOVO        Ano 2019 - 0 km
# 229    USADO  Ano 1991 - 117.377 km
# 230     NOVO        Ano 2019 - 0 km
# 231     NOVO        Ano 2019 - 0 km
# 232    USADO  Ano 2010 - 112.389 km
# 233    USADO   Ano 2010 - 15.193 km
# 234     NOVO        Ano 2019 - 0 km
# 235     NOVO        Ano 2019 - 0 km
# 236     NOVO        Ano 2019 - 0 km
# 237     NOVO        Ano 2019 - 0 km
# 238     NOVO        Ano 2019 - 0 km
# 239    USADO   Ano 2008 - 42.427 km
# 240    USADO   Ano 2006 - 15.128 km
# 241    USADO   Ano 1998 - 74.292 km
# 242     NOVO        Ano 2019 - 0 km
# 243    USADO  Ano 2001 - 102.776 km
# 244    USADO  Ano 2011 - 101.787 km
# 245    USADO   Ano 2001 - 88.564 km
#
#                                                  items             location  \
# 0    [4 X 4, Câmera de estacionamento, Controle de ...  Belo Horizonte - MG
# 1    [Câmera de estacionamento, Controle de estabil...  Belo Horizonte - MG
# 2    [Central multimídia, Bancos de couro, Rodas de...  Rio de Janeiro - RJ
# 3    [Bancos de couro, Freios ABS, Rodas de liga, C...       São Paulo - SP
# 4    [Central multimídia, Teto panorâmico, Sensor c...  Belo Horizonte - MG
# 5    [Painel digital, Controle de tração, Teto pano...  Belo Horizonte - MG
# 6    [4 X 4, Teto panorâmico, Central multimídia, C...  Belo Horizonte - MG
# 7    [Painel digital, Câmbio automático, Sensor de ...  Rio de Janeiro - RJ
# 8    [Central multimídia, Câmera de estacionamento,...       São Paulo - SP
# 9    [Bancos de couro, Freios ABS, Piloto automátic...       São Paulo - SP
# 10   [Teto panorâmico, Controle de tração, Sensor c...  Rio de Janeiro - RJ
# 11   [Ar condicionado, Travas elétricas, Rodas de l...  Belo Horizonte - MG
# 12   [Piloto automático, Painel digital, Ar condici...  Rio de Janeiro - RJ
# 13   [Sensor crepuscular, Painel digital, Teto pano...       São Paulo - SP
# 14   [4 X 4, Câmera de estacionamento, Painel digit...  Belo Horizonte - MG
# 15   [Rodas de liga, Bancos de couro, Freios ABS, T...  Belo Horizonte - MG
# 16   [Freios ABS, Piloto automático, Controle de es...  Rio de Janeiro - RJ
# 17   [Sensor de estacionamento, Ar condicionado, Ce...       São Paulo - SP
# 18   [Rodas de liga, Controle de tração, Freios ABS...  Rio de Janeiro - RJ
# 19   [Painel digital, Central multimídia, Vidros el...  Rio de Janeiro - RJ
# 20   [Painel digital, Controle de estabilidade, 4 X...  Belo Horizonte - MG
# 21   [Ar condicionado, Travas elétricas, Sensor de ...  Belo Horizonte - MG
# 22   [Sensor de estacionamento, Teto panorâmico, Se...  Belo Horizonte - MG
# 23   [Rodas de liga, Câmera de estacionamento, Sens...  Rio de Janeiro - RJ
# 24   [Painel digital, Teto panorâmico, Travas elétr...  Rio de Janeiro - RJ
# 25   [Freios ABS, 4 X 4, Sensor de chuva, Rodas de ...  Belo Horizonte - MG
# 26   [Travas elétricas, Câmbio automático, Bancos d...       São Paulo - SP
# 27   [Piloto automático, Controle de estabilidade, ...  Belo Horizonte - MG
# 28   [Central multimídia, Piloto automático, Sensor...  Rio de Janeiro - RJ
# 29   [Painel digital, Travas elétricas, Vidros elét...  Belo Horizonte - MG
# ..                                                 ...                  ...
# 216  [Freios ABS, Controle de estabilidade, Travas ...       São Paulo - SP
# 217  [Câmbio automático, Vidros elétricos, Sensor d...       São Paulo - SP
# 218  [Freios ABS, Sensor de estacionamento, Rodas d...  Belo Horizonte - MG
# 219  [Controle de estabilidade, Câmbio automático, ...  Belo Horizonte - MG
# 220  [Controle de tração, Travas elétricas, Rodas d...  Belo Horizonte - MG
# 221  [Piloto automático, Sensor de estacionamento, ...  Rio de Janeiro - RJ
# 222  [Piloto automático, Controle de estabilidade, ...       São Paulo - SP
# 223  [Sensor de chuva, Câmbio automático, Freios AB...  Belo Horizonte - MG
# 224  [Freios ABS, Rodas de liga, Câmbio automático,...  Rio de Janeiro - RJ
# 225  [Câmera de estacionamento, Rodas de liga, Pain...  Rio de Janeiro - RJ
# 226  [Central multimídia, Sensor de estacionamento,...  Belo Horizonte - MG
# 227  [Câmera de estacionamento, Sensor de chuva, Vi...  Rio de Janeiro - RJ
# 228  [Sensor crepuscular, Controle de estabilidade,...       São Paulo - SP
# 229  [Teto panorâmico, Ar condicionado, Vidros elét...  Belo Horizonte - MG
# 230  [Controle de tração, Câmbio automático, Câmera...       São Paulo - SP
# 231  [Bancos de couro, Rodas de liga, Sensor de chu...       São Paulo - SP
# 232  [Ar condicionado, Travas elétricas, Controle d...  Rio de Janeiro - RJ
# 233  [Ar condicionado, Vidros elétricos, Câmbio aut...  Belo Horizonte - MG
# 234  [Freios ABS, Piloto automático, Sensor crepusc...       São Paulo - SP
# 235  [Ar condicionado, Sensor de estacionamento, Co...       São Paulo - SP
# 236  [Sensor de chuva, Ar condicionado, Teto panorâ...  Rio de Janeiro - RJ
# 237  [Freios ABS, Ar condicionado, Travas elétricas...       São Paulo - SP
# 238  [Piloto automático, Controle de estabilidade, ...  Rio de Janeiro - RJ
# 239  [Rodas de liga, Freios ABS, Câmera de estacion...  Rio de Janeiro - RJ
# 240  [Painel digital, Câmbio automático, Sensor cre...       São Paulo - SP
# 241  [Câmera de estacionamento, Rodas de liga, Sens...       São Paulo - SP
# 242  [Bancos de couro, Freios ABS, Sensor de estaci...  Belo Horizonte - MG
# 243  [Sensor crepuscular, Sensor de chuva, Vidros e...  Belo Horizonte - MG
# 244  [Painel digital, Travas elétricas, Sensor de c...  Belo Horizonte - MG
# 245  [Sensor crepuscular, Bancos de couro, Sensor d...  Belo Horizonte - MG
#
#                      motor                     name   opportunity       value
# 0            Motor 1.8 16v    LAMBORGHINI AVENTADOR           NaN  R$ 338.000
# 1            Motor 3.0 32v                   BMW M2           NaN  R$ 346.000
# 2            Motor 1.8 16v                     ALFA           NaN  R$ 480.000
# 3          Motor Diesel V8                    PUECH           NaN  R$ 133.000
# 4             Motor 1.0 8v   LAMBORGHINI MURCIELAGO           NaN  R$ 175.000
# 5          Motor Diesel V6             ASTON MARTIN  OPORTUNIDADE  R$ 239.000
# 6          Motor 4.0 Turbo                      TVR           NaN  R$ 115.000
# 7            Motor 3.0 32v                EXCALIBUR           NaN  R$ 114.000
# 8             Motor Diesel                  MCLAREN           NaN   R$ 75.000
# 9          Motor 4.0 Turbo                   TOYOTA  OPORTUNIDADE  R$ 117.000
# 10            Motor 1.0 8v        VOLKSWAGEN BEETLE           NaN  R$ 177.000
# 11           Motor 3.0 32v        SPIRIT OF ECSTASY           NaN  R$ 322.000
# 12           Motor 3.0 32v        PORSCHE 911 GT2RS           NaN  R$ 194.000
# 13         Motor 2.4 Turbo               KOENIGSEGG           NaN  R$ 469.000
# 14         Motor Diesel V6                LIMOUSINE  OPORTUNIDADE  R$ 424.000
# 15         Motor 4.0 Turbo               FERRARI FF           NaN  R$ 291.000
# 16   Motor 5.0 V8 Bi-Turbo                OFFENBURG           NaN   R$ 96.000
# 17         Motor Diesel V8                  MUSTANG           NaN  R$ 271.000
# 18         Motor 2.4 Turbo                   LUXURY           NaN  R$ 387.000
# 19           Motor 3.0 32v                   BMW M5           NaN  R$ 483.000
# 20            Motor Diesel        PORSCHE 911 GT3RS           NaN  R$ 285.000
# 21                Motor V8                     GOLD           NaN  R$ 357.000
# 22         Motor Diesel V6                CABRIOLET  OPORTUNIDADE  R$ 106.000
# 23           Motor 2.0 16v             CHRYSLER 300           NaN  R$ 439.000
# 24         Motor 4.0 Turbo                  CLASSIC           NaN  R$ 143.000
# 25           Motor 2.0 16v                    DODGE           NaN  R$ 155.000
# 26   Motor 5.0 V8 Bi-Turbo       VINTAGE AUTOMOBILE           NaN  R$ 337.000
# 27           Motor 1.8 16v                 CORVETTE           NaN   R$ 89.000
# 28         Motor 4.0 Turbo                     OPEL           NaN  R$ 193.000
# 29           Motor 1.8 16v                  AUDI R8           NaN  R$ 356.000
# ..                     ...                      ...           ...         ...
# 216           Motor Diesel                  PANTERA           NaN   R$ 63.000
# 217        Motor Diesel V8                    HONDA           NaN  R$ 448.000
# 218        Motor Diesel V6         MERCEDES AMG GTS           NaN  R$ 376.000
# 219               Motor V6                     LIMO           NaN  R$ 353.000
# 220        Motor Diesel V6                      BMW           NaN   R$ 90.000
# 221               Motor V6          FERRARI 288 GTO           NaN  R$ 468.000
# 222          Motor 3.0 32v                 AUDI RS7           NaN  R$ 415.000
# 223          Motor 2.0 16v                SEAT LEON  OPORTUNIDADE  R$ 331.000
# 224        Motor Diesel V8        MERCEDES BENZ SLS  OPORTUNIDADE  R$ 237.000
# 225          Motor 2.0 16v                  LAGONDA           NaN   R$ 88.000
# 226           Motor Diesel              ANTIQUE CAR           NaN  R$ 312.000
# 227               Motor V6                  AUDI A5           NaN  R$ 240.000
# 228          Motor 1.8 16v                COUGAR XR  OPORTUNIDADE  R$ 215.000
# 229               Motor V6                   JAGUAR           NaN  R$ 492.000
# 230           Motor Diesel        WHITE LAMBORGHINI  OPORTUNIDADE  R$ 172.000
# 231  Motor 5.0 V8 Bi-Turbo          CORVETTE YELLOW           NaN  R$ 496.000
# 232  Motor 5.0 V8 Bi-Turbo  HOUSTON FIRE DEPARTMENT           NaN  R$ 334.000
# 233               Motor V8         ASTON MARTIN DBS           NaN  R$ 331.000
# 234        Motor 4.0 Turbo                      AMG           NaN  R$ 381.000
# 235        Motor 2.4 Turbo       LAMBORGHINI DIABLO           NaN  R$ 362.000
# 236          Motor 2.0 16v             TRIPPELWAGEN           NaN  R$ 281.000
# 237        Motor 2.4 Turbo                    BENTZ           NaN  R$ 308.000
# 238          Motor 3.0 32v        LUXURY SPORTS CAR           NaN  R$ 268.000
# 239               Motor V8              CONVERTIBLE  OPORTUNIDADE  R$ 192.000
# 240          Motor 1.8 16v           ROLLAND PILAIN           NaN  R$ 432.000
# 241          Motor 3.0 32v            SUV REAR TIRE           NaN  R$ 489.000
# 242          Motor 2.0 16v                  ANTIQUE           NaN  R$ 427.000
# 243          Motor 2.0 16v                    SPORT           NaN  R$ 203.000
# 244          Motor 1.8 16v                 IMPERIAL  OPORTUNIDADE  R$ 474.000
# 245          Motor 3.0 32v           KIA SPORTS CAR           NaN  R$ 366.000
#
# [246 rows x 8 columns]

# %%
cards
# Out:
# [{'value': 'R$ 338.000',
#   'name': 'LAMBORGHINI AVENTADOR',
#   'category': 'USADO',
#   'motor': 'Motor 1.8 16v',
#   'description': 'Ano 1993 - 55.286 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['4 X 4',
#    'Câmera de estacionamento',
#    'Controle de tração',
#    'Sensor de estacionamento']},
#  {'value': 'R$ 346.000',
#   'name': 'BMW M2',
#   'category': 'USADO',
#   'motor': 'Motor 3.0 32v',
#   'description': 'Ano 2018 - 83.447 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Câmera de estacionamento',
#    'Controle de estabilidade',
#    'Travas elétricas',
#    'Freios ABS']},
#  {'value': 'R$ 480.000',
#   'name': 'ALFA',
#   'category': 'USADO',
#   'motor': 'Motor 1.8 16v',
#   'description': 'Ano 2004 - 19.722 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Central multimídia',
#    'Bancos de couro',
#    'Rodas de liga',
#    'Câmera de estacionamento']},
#  {'value': 'R$ 133.000',
#   'name': 'PUECH',
#   'category': 'USADO',
#   'motor': 'Motor Diesel V8',
#   'description': 'Ano 1992 - 34.335 km',
#   'location': 'São Paulo - SP',
#   'items': ['Bancos de couro',
#    'Freios ABS',
#    'Rodas de liga',
#    'Câmbio automático']},
#  {'value': 'R$ 175.000',
#   'name': 'LAMBORGHINI MURCIELAGO',
#   'category': 'USADO',
#   'motor': 'Motor 1.0 8v',
#   'description': 'Ano 1991 - 464 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Central multimídia',
#    'Teto panorâmico',
#    'Sensor crepuscular',
#    'Piloto automático']},
#  {'value': 'R$ 239.000',
#   'name': 'ASTON MARTIN',
#   'category': 'USADO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor Diesel V6',
#   'description': 'Ano 2004 - 50.189 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Painel digital',
#    'Controle de tração',
#    'Teto panorâmico',
#    'Central multimídia']},
#  {'value': 'R$ 115.000',
#   'name': 'TVR',
#   'category': 'USADO',
#   'motor': 'Motor 4.0 Turbo',
#   'description': 'Ano 2014 - 17.778 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['4 X 4',
#    'Teto panorâmico',
#    'Central multimídia',
#    'Controle de estabilidade']},
#  {'value': 'R$ 114.000',
#   'name': 'EXCALIBUR',
#   'category': 'USADO',
#   'motor': 'Motor 3.0 32v',
#   'description': 'Ano 2009 - 81.251 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Painel digital',
#    'Câmbio automático',
#    'Sensor de chuva',
#    'Travas elétricas']},
#  {'value': 'R$ 75.000',
#   'name': 'MCLAREN',
#   'category': 'NOVO',
#   'motor': 'Motor Diesel',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['Central multimídia',
#    'Câmera de estacionamento',
#    'Câmbio automático',
#    'Ar condicionado']},
#  {'value': 'R$ 117.000',
#   'name': 'TOYOTA',
#   'category': 'USADO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor 4.0 Turbo',
#   'description': 'Ano 1999 - 12.536 km',
#   'location': 'São Paulo - SP',
#   'items': ['Bancos de couro',
#    'Freios ABS',
#    'Piloto automático',
#    'Controle de estabilidade']},
#  {'value': 'R$ 177.000',
#   'name': 'VOLKSWAGEN BEETLE',
#   'category': 'NOVO',
#   'motor': 'Motor 1.0 8v',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Teto panorâmico',
#    'Controle de tração',
#    'Sensor crepuscular',
#    '4 X 4']},
#  {'value': 'R$ 322.000',
#   'name': 'SPIRIT OF ECSTASY',
#   'category': 'USADO',
#   'motor': 'Motor 3.0 32v',
#   'description': 'Ano 2011 - 107.484 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Ar condicionado',
#    'Travas elétricas',
#    'Rodas de liga',
#    'Bancos de couro']},
#  {'value': 'R$ 194.000',
#   'name': 'PORSCHE 911 GT2RS',
#   'category': 'USADO',
#   'motor': 'Motor 3.0 32v',
#   'description': 'Ano 1992 - 908 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Piloto automático',
#    'Painel digital',
#    'Ar condicionado',
#    'Vidros elétricos']},
#  {'value': 'R$ 469.000',
#   'name': 'KOENIGSEGG',
#   'category': 'USADO',
#   'motor': 'Motor 2.4 Turbo',
#   'description': 'Ano 2015 - 22.485 km',
#   'location': 'São Paulo - SP',
#   'items': ['Sensor crepuscular',
#    'Painel digital',
#    'Teto panorâmico',
#    'Vidros elétricos']},
#  {'value': 'R$ 424.000',
#   'name': 'LIMOUSINE',
#   'category': 'USADO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor Diesel V6',
#   'description': 'Ano 1996 - 23.007 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['4 X 4',
#    'Câmera de estacionamento',
#    'Painel digital',
#    'Controle de tração']},
#  {'value': 'R$ 291.000',
#   'name': 'FERRARI FF',
#   'category': 'USADO',
#   'motor': 'Motor 4.0 Turbo',
#   'description': 'Ano 2002 - 106.389 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Rodas de liga',
#    'Bancos de couro',
#    'Freios ABS',
#    'Travas elétricas']},
#  {'value': 'R$ 96.000',
#   'name': 'OFFENBURG',
#   'category': 'USADO',
#   'motor': 'Motor 5.0 V8 Bi-Turbo',
#   'description': 'Ano 1990 - 78.181 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Freios ABS',
#    'Piloto automático',
#    'Controle de estabilidade',
#    'Vidros elétricos']},
#  {'value': 'R$ 271.000',
#   'name': 'MUSTANG',
#   'category': 'USADO',
#   'motor': 'Motor Diesel V8',
#   'description': 'Ano 1998 - 86.001 km',
#   'location': 'São Paulo - SP',
#   'items': ['Sensor de estacionamento',
#    'Ar condicionado',
#    'Central multimídia',
#    'Travas elétricas']},
#  {'value': 'R$ 387.000',
#   'name': 'LUXURY',
#   'category': 'NOVO',
#   'motor': 'Motor 2.4 Turbo',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Rodas de liga',
#    'Controle de tração',
#    'Freios ABS',
#    'Sensor de estacionamento']},
#  {'value': 'R$ 483.000',
#   'name': 'BMW M5',
#   'category': 'USADO',
#   'motor': 'Motor 3.0 32v',
#   'description': 'Ano 2017 - 10.747 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Painel digital',
#    'Central multimídia',
#    'Vidros elétricos',
#    'Ar condicionado']},
#  {'value': 'R$ 285.000',
#   'name': 'PORSCHE 911 GT3RS',
#   'category': 'USADO',
#   'motor': 'Motor Diesel',
#   'description': 'Ano 1991 - 28.617 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Painel digital',
#    'Controle de estabilidade',
#    '4 X 4',
#    'Sensor de chuva']},
#  {'value': 'R$ 357.000',
#   'name': 'GOLD',
#   'category': 'NOVO',
#   'motor': 'Motor V8',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Ar condicionado',
#    'Travas elétricas',
#    'Sensor de chuva',
#    'Bancos de couro']},
#  {'value': 'R$ 106.000',
#   'name': 'CABRIOLET',
#   'category': 'NOVO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor Diesel V6',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Sensor de estacionamento',
#    'Teto panorâmico',
#    'Sensor crepuscular',
#    'Ar condicionado']},
#  {'value': 'R$ 439.000',
#   'name': 'CHRYSLER 300',
#   'category': 'USADO',
#   'motor': 'Motor 2.0 16v',
#   'description': 'Ano 2009 - 67.480 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Rodas de liga',
#    'Câmera de estacionamento',
#    'Sensor crepuscular',
#    'Travas elétricas']},
#  {'value': 'R$ 143.000',
#   'name': 'CLASSIC',
#   'category': 'NOVO',
#   'motor': 'Motor 4.0 Turbo',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Painel digital',
#    'Teto panorâmico',
#    'Travas elétricas',
#    'Sensor de estacionamento']},
#  {'value': 'R$ 155.000',
#   'name': 'DODGE',
#   'category': 'USADO',
#   'motor': 'Motor 2.0 16v',
#   'description': 'Ano 1999 - 85.451 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Freios ABS', '4 X 4', 'Sensor de chuva', 'Rodas de liga']},
#  {'value': 'R$ 337.000',
#   'name': 'VINTAGE AUTOMOBILE',
#   'category': 'NOVO',
#   'motor': 'Motor 5.0 V8 Bi-Turbo',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['Travas elétricas',
#    'Câmbio automático',
#    'Bancos de couro',
#    'Teto panorâmico']},
#  {'value': 'R$ 89.000',
#   'name': 'CORVETTE',
#   'category': 'USADO',
#   'motor': 'Motor 1.8 16v',
#   'description': 'Ano 1996 - 107.305 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Piloto automático',
#    'Controle de estabilidade',
#    'Freios ABS',
#    'Ar condicionado']},
#  {'value': 'R$ 193.000',
#   'name': 'OPEL',
#   'category': 'USADO',
#   'motor': 'Motor 4.0 Turbo',
#   'description': 'Ano 1997 - 119.942 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Central multimídia',
#    'Piloto automático',
#    'Sensor de estacionamento',
#    'Ar condicionado']},
#  {'value': 'R$ 356.000',
#   'name': 'AUDI R8',
#   'category': 'USADO',
#   'motor': 'Motor 1.8 16v',
#   'description': 'Ano 1993 - 86.338 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Painel digital',
#    'Travas elétricas',
#    'Vidros elétricos',
#    '4 X 4']},
#  {'value': 'R$ 141.000',
#   'name': 'ASTON MARTIN VULCAN',
#   'category': 'NOVO',
#   'motor': 'Motor Diesel',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Câmbio automático',
#    'Sensor de chuva',
#    'Controle de tração',
#    'Teto panorâmico']},
#  {'value': 'R$ 176.000',
#   'name': 'TRIUMPH MOTOR COMPANY',
#   'category': 'NOVO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor V6',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Central multimídia',
#    'Ar condicionado',
#    'Bancos de couro',
#    'Câmera de estacionamento']},
#  {'value': 'R$ 65.000',
#   'name': 'VINTAGE CAR',
#   'category': 'USADO',
#   'motor': 'Motor V8',
#   'description': 'Ano 2003 - 59.288 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Freios ABS',
#    'Piloto automático',
#    'Sensor de chuva',
#    'Vidros elétricos']},
#  {'value': 'R$ 449.000',
#   'name': 'ACURA HEADLAMP',
#   'category': 'NOVO',
#   'motor': 'Motor V6',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Câmera de estacionamento',
#    'Câmbio automático',
#    'Piloto automático',
#    'Central multimídia']},
#  {'value': 'R$ 379.000',
#   'name': 'LUXURY CARS',
#   'category': 'USADO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor Diesel V8',
#   'description': 'Ano 2014 - 37.738 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Rodas de liga',
#    'Painel digital',
#    'Sensor de estacionamento',
#    'Teto panorâmico']},
#  {'value': 'R$ 262.000',
#   'name': 'FERRARI 458 SPIDER',
#   'category': 'USADO',
#   'motor': 'Motor V6',
#   'description': 'Ano 1993 - 24.316 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Central multimídia',
#    'Controle de estabilidade',
#    'Piloto automático',
#    'Sensor de chuva']},
#  {'value': 'R$ 356.000',
#   'name': 'CLASSIC AUTOMOBILE',
#   'category': 'USADO',
#   'motor': 'Motor 3.0 32v',
#   'description': 'Ano 2016 - 35.762 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Câmbio automático',
#    'Sensor de estacionamento',
#    'Bancos de couro',
#    'Câmera de estacionamento']},
#  {'value': 'R$ 459.000',
#   'name': 'INFINITY',
#   'category': 'USADO',
#   'motor': 'Motor 2.4 Turbo',
#   'description': 'Ano 1990 - 51.693 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Câmera de estacionamento',
#    'Piloto automático',
#    'Ar condicionado',
#    'Painel digital']},
#  {'value': 'R$ 183.000',
#   'name': 'ASTON MARTIN VANQUISH',
#   'category': 'NOVO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor 4.0 Turbo',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['Painel digital',
#    'Piloto automático',
#    'Sensor de estacionamento',
#    'Sensor crepuscular']},
#  {'value': 'R$ 61.000',
#   'name': 'MERCEDES BENZ 190 SL',
#   'category': 'USADO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor 3.0 32v',
#   'description': 'Ano 1994 - 111.906 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Câmbio automático',
#    'Freios ABS',
#    'Sensor crepuscular',
#    'Controle de estabilidade']},
#  {'value': 'R$ 225.000',
#   'name': 'AUDI TT',
#   'category': 'USADO',
#   'motor': 'Motor Diesel V6',
#   'description': 'Ano 2008 - 82.711 km',
#   'location': 'São Paulo - SP',
#   'items': ['Sensor de chuva',
#    'Rodas de liga',
#    'Câmera de estacionamento',
#    'Travas elétricas']},
#  {'value': 'R$ 181.000',
#   'name': 'DISTRICT',
#   'category': 'USADO',
#   'motor': 'Motor Diesel V6',
#   'description': 'Ano 1995 - 36.215 km',
#   'location': 'São Paulo - SP',
#   'items': ['Sensor de chuva', 'Rodas de liga', 'Piloto automático', '4 X 4']},
#  {'value': 'R$ 460.000',
#   'name': 'VINTAGE',
#   'category': 'USADO',
#   'motor': 'Motor 4.0 Turbo',
#   'description': 'Ano 2005 - 63.879 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['4 X 4',
#    'Ar condicionado',
#    'Câmbio automático',
#    'Controle de estabilidade']},
#  {'value': 'R$ 161.000',
#   'name': 'AUDI',
#   'category': 'NOVO',
#   'motor': 'Motor Diesel V6',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['Piloto automático',
#    'Bancos de couro',
#    'Painel digital',
#    'Controle de tração']},
#  {'value': 'R$ 188.000',
#   'name': 'AUDI RS6',
#   'category': 'USADO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor Diesel V6',
#   'description': 'Ano 1999 - 26.215 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Travas elétricas',
#    'Central multimídia',
#    'Vidros elétricos',
#    'Ar condicionado']},
#  {'value': 'R$ 97.000',
#   'name': 'FERRARI 458 SPECIALE',
#   'category': 'USADO',
#   'motor': 'Motor Diesel V6',
#   'description': 'Ano 2018 - 1 km',
#   'location': 'São Paulo - SP',
#   'items': ['Freios ABS',
#    'Controle de estabilidade',
#    'Painel digital',
#    'Ar condicionado']},
#  {'value': 'R$ 415.000',
#   'name': 'TRUCK',
#   'category': 'USADO',
#   'motor': 'Motor 4.0 Turbo',
#   'description': 'Ano 2001 - 68.038 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Rodas de liga',
#    'Sensor de estacionamento',
#    'Vidros elétricos',
#    'Câmbio automático']},
#  {'value': 'R$ 172.000',
#   'name': 'CORVETTE STINGRAY',
#   'category': 'USADO',
#   'motor': 'Motor 1.8 16v',
#   'description': 'Ano 1996 - 86.477 km',
#   'location': 'São Paulo - SP',
#   'items': ['Câmbio automático',
#    'Controle de estabilidade',
#    'Sensor de estacionamento',
#    'Ar condicionado']},
#  {'value': 'R$ 281.000',
#   'name': 'LAMBORGHINI',
#   'category': 'USADO',
#   'motor': 'Motor 3.0 32v',
#   'description': 'Ano 2004 - 103.570 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Vidros elétricos',
#    'Câmbio automático',
#    'Piloto automático',
#    'Teto panorâmico']},
#  {'value': 'R$ 396.000',
#   'name': 'CHRYSLER',
#   'category': 'NOVO',
#   'motor': 'Motor 3.0 32v',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['4 X 4',
#    'Ar condicionado',
#    'Câmera de estacionamento',
#    'Sensor de estacionamento']},
#  {'value': 'R$ 450.000',
#   'name': 'RANGE ROVER',
#   'category': 'USADO',
#   'motor': 'Motor V6',
#   'description': 'Ano 2014 - 85.686 km',
#   'location': 'São Paulo - SP',
#   'items': ['Sensor de chuva',
#    'Ar condicionado',
#    'Painel digital',
#    'Teto panorâmico']},
#  {'value': 'R$ 470.000',
#   'name': 'HAMMER',
#   'category': 'NOVO',
#   'motor': 'Motor Diesel V8',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Bancos de couro',
#    'Travas elétricas',
#    'Sensor de estacionamento',
#    'Controle de tração']},
#  {'value': 'R$ 64.000',
#   'name': 'FELICIA',
#   'category': 'USADO',
#   'motor': 'Motor 2.0 16v',
#   'description': 'Ano 1990 - 68.513 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Central multimídia',
#    'Painel digital',
#    'Ar condicionado',
#    '4 X 4']},
#  {'value': 'R$ 343.000',
#   'name': 'MASERATI GRANTURISMO',
#   'category': 'USADO',
#   'motor': 'Motor 5.0 V8 Bi-Turbo',
#   'description': 'Ano 2011 - 71.783 km',
#   'location': 'São Paulo - SP',
#   'items': ['Piloto automático',
#    'Bancos de couro',
#    '4 X 4',
#    'Sensor crepuscular']},
#  {'value': 'R$ 106.000',
#   'name': 'LAMBORGHINI AVENTADOR S',
#   'category': 'USADO',
#   'motor': 'Motor Diesel V8',
#   'description': 'Ano 2017 - 115.844 km',
#   'location': 'São Paulo - SP',
#   'items': ['Câmera de estacionamento',
#    'Sensor de estacionamento',
#    'Central multimídia',
#    'Teto panorâmico']},
#  {'value': 'R$ 493.000',
#   'name': 'BENTLEY',
#   'category': 'USADO',
#   'motor': 'Motor V6',
#   'description': 'Ano 1994 - 46.442 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Vidros elétricos',
#    'Piloto automático',
#    'Sensor crepuscular',
#    '4 X 4']},
#  {'value': 'R$ 370.000',
#   'name': 'ASTON',
#   'category': 'NOVO',
#   'motor': 'Motor 2.4 Turbo',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['Painel digital',
#    'Piloto automático',
#    'Freios ABS',
#    'Controle de estabilidade']},
#  {'value': 'R$ 474.000',
#   'name': 'LAMBORGHINI GALLARDO',
#   'category': 'USADO',
#   'motor': 'Motor 5.0 V8 Bi-Turbo',
#   'description': 'Ano 1993 - 77.846 km',
#   'location': 'São Paulo - SP',
#   'items': ['4 X 4',
#    'Painel digital',
#    'Travas elétricas',
#    'Sensor crepuscular']},
#  {'value': 'R$ 420.000',
#   'name': 'BMW 1M',
#   'category': 'USADO',
#   'motor': 'Motor 1.0 8v',
#   'description': 'Ano 2014 - 28.833 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Sensor crepuscular',
#    'Sensor de chuva',
#    'Piloto automático',
#    'Câmera de estacionamento']},
#  {'value': 'R$ 215.000',
#   'name': 'MERCEDES S CLASS',
#   'category': 'NOVO',
#   'motor': 'Motor 2.4 Turbo',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['Central multimídia',
#    'Câmera de estacionamento',
#    'Sensor de estacionamento',
#    'Painel digital']},
#  {'value': 'R$ 236.000',
#   'name': 'VINTAGE AUTO',
#   'category': 'USADO',
#   'motor': 'Motor 5.0 V8 Bi-Turbo',
#   'description': 'Ano 2014 - 59.723 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Freios ABS',
#    'Piloto automático',
#    'Controle de estabilidade',
#    'Sensor crepuscular']},
#  {'value': 'R$ 124.000',
#   'name': 'LEATHER STEERING WHEEL',
#   'category': 'USADO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor V6',
#   'description': 'Ano 2001 - 74.365 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Controle de tração',
#    '4 X 4',
#    'Câmera de estacionamento',
#    'Controle de estabilidade']},
#  {'value': 'R$ 125.000',
#   'name': 'DKW',
#   'category': 'USADO',
#   'motor': 'Motor 2.0 16v',
#   'description': 'Ano 1994 - 112.727 km',
#   'location': 'São Paulo - SP',
#   'items': ['Controle de tração',
#    'Travas elétricas',
#    'Controle de estabilidade',
#    'Sensor crepuscular']},
#  {'value': 'R$ 151.000',
#   'name': 'FERRARI',
#   'category': 'USADO',
#   'motor': 'Motor 1.8 16v',
#   'description': 'Ano 2011 - 111.255 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['4 X 4',
#    'Controle de tração',
#    'Travas elétricas',
#    'Teto panorâmico']},
#  {'value': 'R$ 351.000',
#   'name': 'BMW M3',
#   'category': 'USADO',
#   'motor': 'Motor Diesel V8',
#   'description': 'Ano 2000 - 21.968 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Teto panorâmico',
#    'Sensor de chuva',
#    'Ar condicionado',
#    'Câmera de estacionamento']},
#  {'value': 'R$ 223.000',
#   'name': 'TUNING',
#   'category': 'NOVO',
#   'motor': 'Motor Diesel V6',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['Câmbio automático',
#    'Ar condicionado',
#    'Bancos de couro',
#    'Controle de tração']},
#  {'value': 'R$ 79.000',
#   'name': 'LINCOLN MKZ',
#   'category': 'NOVO',
#   'motor': 'Motor Diesel V6',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['Bancos de couro',
#    'Sensor de chuva',
#    'Sensor de estacionamento',
#    'Freios ABS']},
#  {'value': 'R$ 252.000',
#   'name': 'MASERATI LEVANTE',
#   'category': 'NOVO',
#   'motor': 'Motor V8',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['Controle de tração',
#    'Sensor de estacionamento',
#    'Freios ABS',
#    'Painel digital']},
#  {'value': 'R$ 357.000',
#   'name': 'ROLLSROYCE',
#   'category': 'USADO',
#   'motor': 'Motor 4.0 Turbo',
#   'description': 'Ano 1991 - 5.947 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Central multimídia',
#    'Piloto automático',
#    'Controle de estabilidade',
#    'Câmbio automático']},
#  {'value': 'R$ 396.000',
#   'name': 'MERCEDES BENZ',
#   'category': 'NOVO',
#   'motor': 'Motor Diesel V6',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['Vidros elétricos',
#    'Controle de tração',
#    'Painel digital',
#    'Rodas de liga']},
#  {'value': 'R$ 460.000',
#   'name': 'MORGAN ROADSTER',
#   'category': 'USADO',
#   'motor': 'Motor 2.0 16v',
#   'description': 'Ano 1999 - 102.662 km',
#   'location': 'São Paulo - SP',
#   'items': ['Ar condicionado',
#    'Travas elétricas',
#    'Controle de tração',
#    'Freios ABS']},
#  {'value': 'R$ 72.000',
#   'name': 'TOYOTA LAND CRUISER',
#   'category': 'USADO',
#   'motor': 'Motor 2.0 16v',
#   'description': 'Ano 1990 - 46.571 km',
#   'location': 'São Paulo - SP',
#   'items': ['Rodas de liga',
#    '4 X 4',
#    'Travas elétricas',
#    'Câmera de estacionamento']},
#  {'value': 'R$ 422.000',
#   'name': 'MERCEDES BENZ 300 SL',
#   'category': 'NOVO',
#   'motor': 'Motor V8',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Painel digital',
#    'Vidros elétricos',
#    'Teto panorâmico',
#    'Sensor crepuscular']},
#  {'value': 'R$ 399.000',
#   'name': 'CASABLANCA',
#   'category': 'USADO',
#   'motor': 'Motor 5.0 V8 Bi-Turbo',
#   'description': 'Ano 2003 - 9.912 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Ar condicionado',
#    'Freios ABS',
#    'Câmera de estacionamento',
#    'Vidros elétricos']},
#  {'value': 'R$ 455.000',
#   'name': 'BUGATTI',
#   'category': 'USADO',
#   'motor': 'Motor 1.0 8v',
#   'description': 'Ano 1993 - 81.154 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Freios ABS',
#    'Painel digital',
#    'Controle de estabilidade',
#    'Controle de tração']},
#  {'value': 'R$ 173.000',
#   'name': 'PORSCHE CARRERA GT',
#   'category': 'NOVO',
#   'motor': 'Motor 3.0 32v',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Sensor de estacionamento',
#    'Vidros elétricos',
#    'Piloto automático',
#    'Painel digital']},
#  {'value': 'R$ 340.000',
#   'name': 'BLACK AND WHITE',
#   'category': 'USADO',
#   'motor': 'Motor 2.0 16v',
#   'description': 'Ano 2005 - 86.899 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Painel digital',
#    'Teto panorâmico',
#    'Sensor crepuscular',
#    'Rodas de liga']},
#  {'value': 'R$ 443.000',
#   'name': 'BMW I8',
#   'category': 'USADO',
#   'motor': 'Motor 3.0 32v',
#   'description': 'Ano 1994 - 112.579 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Freios ABS', 'Ar condicionado', '4 X 4', 'Teto panorâmico']},
#  {'value': 'R$ 383.000',
#   'name': 'SUBARU',
#   'category': 'USADO',
#   'motor': 'Motor Diesel',
#   'description': 'Ano 1995 - 48.416 km',
#   'location': 'São Paulo - SP',
#   'items': ['Sensor de chuva', 'Freios ABS', '4 X 4', 'Teto panorâmico']},
#  {'value': 'R$ 287.000',
#   'name': 'AMAZING',
#   'category': 'USADO',
#   'motor': 'Motor 4.0 Turbo',
#   'description': 'Ano 2015 - 111.613 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Controle de estabilidade',
#    'Central multimídia',
#    'Câmera de estacionamento',
#    'Câmbio automático']},
#  {'value': 'R$ 350.000',
#   'name': 'AUSTIN HEALEY',
#   'category': 'USADO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor Diesel',
#   'description': 'Ano 2003 - 15.810 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Sensor de estacionamento',
#    'Teto panorâmico',
#    'Controle de estabilidade',
#    'Câmbio automático']},
#  {'value': 'R$ 276.000',
#   'name': 'FORD',
#   'category': 'USADO',
#   'motor': 'Motor V8',
#   'description': 'Ano 1995 - 115.874 km',
#   'location': 'São Paulo - SP',
#   'items': ['Travas elétricas',
#    'Câmbio automático',
#    'Central multimídia',
#    '4 X 4']},
#  {'value': 'R$ 163.000',
#   'name': 'ROLLS ROYCE WRAITH',
#   'category': 'USADO',
#   'motor': 'Motor Diesel',
#   'description': 'Ano 2010 - 99.918 km',
#   'location': 'São Paulo - SP',
#   'items': ['Freios ABS',
#    'Controle de estabilidade',
#    'Painel digital',
#    'Câmbio automático']},
#  {'value': 'R$ 107.000',
#   'name': 'MERCEDES E63',
#   'category': 'NOVO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor 5.0 V8 Bi-Turbo',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Sensor de chuva',
#    'Central multimídia',
#    'Ar condicionado',
#    'Controle de estabilidade']},
#  {'value': 'R$ 173.000',
#   'name': 'MCLAREN MP4 12C',
#   'category': 'NOVO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor Diesel V6',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Sensor de estacionamento',
#    'Central multimídia',
#    'Sensor crepuscular',
#    'Piloto automático']},
#  {'value': 'R$ 150.000',
#   'name': 'VWBEETLE',
#   'category': 'USADO',
#   'motor': 'Motor Diesel V8',
#   'description': 'Ano 1992 - 108.055 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['4 X 4',
#    'Teto panorâmico',
#    'Travas elétricas',
#    'Câmbio automático']},
#  {'value': 'R$ 305.000',
#   'name': 'FERRARI 360',
#   'category': 'USADO',
#   'motor': 'Motor 5.0 V8 Bi-Turbo',
#   'description': 'Ano 1991 - 106.251 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Vidros elétricos',
#    'Rodas de liga',
#    'Travas elétricas',
#    'Sensor de chuva']},
#  {'value': 'R$ 220.000',
#   'name': 'CITROEN',
#   'category': 'USADO',
#   'motor': 'Motor 1.8 16v',
#   'description': 'Ano 1995 - 13.433 km',
#   'location': 'São Paulo - SP',
#   'items': ['Piloto automático',
#    'Central multimídia',
#    'Câmera de estacionamento',
#    'Travas elétricas']},
#  {'value': 'R$ 176.000',
#   'name': 'FERRARI 458',
#   'category': 'USADO',
#   'motor': 'Motor 3.0 32v',
#   'description': 'Ano 2000 - 75.458 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Controle de estabilidade',
#    'Câmbio automático',
#    'Painel digital',
#    'Bancos de couro']},
#  {'value': 'R$ 201.000',
#   'name': 'OLDTIMERS',
#   'category': 'USADO',
#   'motor': 'Motor Diesel',
#   'description': 'Ano 2015 - 41.735 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Vidros elétricos',
#    'Ar condicionado',
#    'Controle de estabilidade',
#    'Sensor crepuscular']},
#  {'value': 'R$ 384.000',
#   'name': 'CAR PARTS WHITE',
#   'category': 'USADO',
#   'motor': 'Motor 1.8 16v',
#   'description': 'Ano 2003 - 51.348 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Controle de estabilidade',
#    'Câmera de estacionamento',
#    'Câmbio automático',
#    'Ar condicionado']},
#  {'value': 'R$ 111.000',
#   'name': 'GOODYEAR',
#   'category': 'NOVO',
#   'motor': 'Motor 5.0 V8 Bi-Turbo',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Freios ABS',
#    'Controle de tração',
#    'Teto panorâmico',
#    'Controle de estabilidade']},
#  {'value': 'R$ 146.000',
#   'name': 'AFTERFX CUSTOM JEEP',
#   'category': 'USADO',
#   'motor': 'Motor Diesel',
#   'description': 'Ano 2017 - 68.014 km',
#   'location': 'São Paulo - SP',
#   'items': ['Controle de tração',
#    'Travas elétricas',
#    '4 X 4',
#    'Vidros elétricos']},
#  {'value': 'R$ 319.000',
#   'name': 'WHITE LUXURY CAR',
#   'category': 'USADO',
#   'motor': 'Motor 2.4 Turbo',
#   'description': 'Ano 1993 - 52.282 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Controle de tração',
#    'Ar condicionado',
#    'Freios ABS',
#    'Câmbio automático']},
#  {'value': 'R$ 86.000',
#   'name': 'LEXUS BREAK LIGHT',
#   'category': 'USADO',
#   'motor': 'Motor 2.4 Turbo',
#   'description': 'Ano 2016 - 100.617 km',
#   'location': 'São Paulo - SP',
#   'items': ['Rodas de liga',
#    'Freios ABS',
#    'Câmera de estacionamento',
#    '4 X 4']},
#  {'value': 'R$ 188.000',
#   'name': 'FERRARI CALIFORNIA',
#   'category': 'NOVO',
#   'motor': 'Motor V6',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Câmera de estacionamento',
#    'Rodas de liga',
#    'Controle de estabilidade',
#    'Sensor de estacionamento']},
#  {'value': 'R$ 467.000',
#   'name': 'MERC',
#   'category': 'NOVO',
#   'motor': 'Motor V6',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Ar condicionado',
#    '4 X 4',
#    'Painel digital',
#    'Piloto automático']},
#  {'value': 'R$ 69.000',
#   'name': 'LEXUS IS F',
#   'category': 'USADO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor V8',
#   'description': 'Ano 2013 - 79.881 km',
#   'location': 'São Paulo - SP',
#   'items': ['Teto panorâmico',
#    '4 X 4',
#    'Travas elétricas',
#    'Sensor de chuva']},
#  {'value': 'R$ 230.000',
#   'name': 'FORD MUSTANG',
#   'category': 'NOVO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor 1.0 8v',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Controle de tração',
#    '4 X 4',
#    'Vidros elétricos',
#    'Ar condicionado']},
#  {'value': 'R$ 463.000',
#   'name': 'PAGANI HUAYRA',
#   'category': 'NOVO',
#   'motor': 'Motor Diesel V8',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['Câmbio automático',
#    'Freios ABS',
#    'Sensor de chuva',
#    'Sensor crepuscular']},
#  {'value': 'R$ 440.000',
#   'name': 'FIAT',
#   'category': 'USADO',
#   'motor': 'Motor V6',
#   'description': 'Ano 2003 - 90.354 km',
#   'location': 'São Paulo - SP',
#   'items': ['Sensor crepuscular',
#    'Piloto automático',
#    'Câmera de estacionamento',
#    'Painel digital']},
#  {'value': 'R$ 58.000',
#   'name': 'HOUSTON',
#   'category': 'USADO',
#   'motor': 'Motor V8',
#   'description': 'Ano 1995 - 48.876 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['4 X 4',
#    'Rodas de liga',
#    'Teto panorâmico',
#    'Controle de tração']},
#  {'value': 'R$ 475.000',
#   'name': 'LEXUS',
#   'category': 'USADO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor Diesel V6',
#   'description': 'Ano 2006 - 43.186 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Sensor crepuscular',
#    'Bancos de couro',
#    'Piloto automático',
#    'Freios ABS']},
#  {'value': 'R$ 133.000',
#   'name': 'SPAIN',
#   'category': 'USADO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor 1.0 8v',
#   'description': 'Ano 2007 - 66.296 km',
#   'location': 'São Paulo - SP',
#   'items': ['Central multimídia',
#    'Freios ABS',
#    'Sensor de chuva',
#    'Controle de estabilidade']},
#  {'value': 'R$ 322.000',
#   'name': 'BORGWARD',
#   'category': 'NOVO',
#   'motor': 'Motor 5.0 V8 Bi-Turbo',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['Vidros elétricos',
#    'Controle de estabilidade',
#    'Piloto automático',
#    'Sensor crepuscular']},
#  {'value': 'R$ 138.000',
#   'name': 'SPOKES',
#   'category': 'USADO',
#   'motor': 'Motor 4.0 Turbo',
#   'description': 'Ano 2016 - 72.469 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Câmbio automático',
#    'Freios ABS',
#    'Travas elétricas',
#    'Controle de tração']},
#  {'value': 'R$ 413.000',
#   'name': 'MUSCLE CAR',
#   'category': 'USADO',
#   'motor': 'Motor Diesel V8',
#   'description': 'Ano 1991 - 107.498 km',
#   'location': 'São Paulo - SP',
#   'items': ['Sensor de chuva',
#    'Teto panorâmico',
#    'Freios ABS',
#    'Controle de estabilidade']},
#  {'value': 'R$ 483.000',
#   'name': 'MCLAREN 650S',
#   'category': 'USADO',
#   'motor': 'Motor 4.0 Turbo',
#   'description': 'Ano 1996 - 76.244 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Rodas de liga',
#    'Freios ABS',
#    'Controle de tração',
#    'Sensor de estacionamento']},
#  {'value': 'R$ 223.000',
#   'name': 'SPYKER C8',
#   'category': 'USADO',
#   'motor': 'Motor 2.4 Turbo',
#   'description': 'Ano 2001 - 22.527 km',
#   'location': 'São Paulo - SP',
#   'items': ['Bancos de couro',
#    'Câmbio automático',
#    'Travas elétricas',
#    'Teto panorâmico']},
#  {'value': 'R$ 126.000',
#   'name': 'BOXSTER',
#   'category': 'USADO',
#   'motor': 'Motor Diesel V6',
#   'description': 'Ano 2005 - 66.836 km',
#   'location': 'São Paulo - SP',
#   'items': ['4 X 4',
#    'Câmbio automático',
#    'Painel digital',
#    'Piloto automático']},
#  {'value': 'R$ 354.000',
#   'name': 'ASTON MARTIN SHOOTING BRAKE ZAGATO',
#   'category': 'USADO',
#   'motor': 'Motor Diesel V8',
#   'description': 'Ano 2007 - 22.225 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Teto panorâmico',
#    'Controle de estabilidade',
#    'Sensor de chuva',
#    'Sensor crepuscular']},
#  {'value': 'R$ 132.000',
#   'name': 'PORSCHE 911',
#   'category': 'USADO',
#   'motor': 'Motor V8',
#   'description': 'Ano 2007 - 97.778 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Central multimídia',
#    '4 X 4',
#    'Bancos de couro',
#    'Controle de estabilidade']},
#  {'value': 'R$ 201.000',
#   'name': 'ASTON MARTIN DB11',
#   'category': 'USADO',
#   'motor': 'Motor 1.0 8v',
#   'description': 'Ano 1995 - 95.124 km',
#   'location': 'São Paulo - SP',
#   'items': ['Central multimídia',
#    'Bancos de couro',
#    'Sensor crepuscular',
#    'Sensor de estacionamento']},
#  {'value': 'R$ 58.000',
#   'name': 'KAHULUI',
#   'category': 'NOVO',
#   'motor': 'Motor V8',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['Rodas de liga',
#    'Teto panorâmico',
#    'Sensor de chuva',
#    'Painel digital']},
#  {'value': 'R$ 159.000',
#   'name': 'DAIMLER',
#   'category': 'USADO',
#   'motor': 'Motor Diesel',
#   'description': 'Ano 1997 - 76.354 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Piloto automático',
#    'Câmera de estacionamento',
#    'Câmbio automático',
#    'Sensor crepuscular']},
#  {'value': 'R$ 167.000',
#   'name': 'RED CAR',
#   'category': 'USADO',
#   'motor': 'Motor 1.0 8v',
#   'description': 'Ano 1993 - 11.015 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Sensor de estacionamento',
#    'Bancos de couro',
#    'Sensor de chuva',
#    'Teto panorâmico']},
#  {'value': 'R$ 249.000',
#   'name': 'PORSCHE',
#   'category': 'USADO',
#   'motor': 'Motor 3.0 32v',
#   'description': 'Ano 1990 - 9.856 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Controle de estabilidade',
#    'Teto panorâmico',
#    'Freios ABS',
#    '4 X 4']},
#  {'value': 'R$ 402.000',
#   'name': 'ASPHALT',
#   'category': 'NOVO',
#   'motor': 'Motor 2.0 16v',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Rodas de liga',
#    'Freios ABS',
#    'Controle de tração',
#    'Bancos de couro']},
#  {'value': 'R$ 393.000',
#   'name': 'ASTON MARTIN VANTAGE',
#   'category': 'USADO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor 1.8 16v',
#   'description': 'Ano 2018 - 76.558 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Painel digital',
#    'Freios ABS',
#    'Controle de estabilidade',
#    'Sensor de chuva']},
#  {'value': 'R$ 332.000',
#   'name': 'PORSCHE TURBO',
#   'category': 'USADO',
#   'motor': 'Motor 1.0 8v',
#   'description': 'Ano 1993 - 23.418 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Travas elétricas',
#    'Sensor de chuva',
#    'Piloto automático',
#    '4 X 4']},
#  {'value': 'R$ 472.000',
#   'name': 'REO',
#   'category': 'NOVO',
#   'motor': 'Motor 1.8 16v',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Sensor de estacionamento',
#    'Painel digital',
#    'Bancos de couro',
#    'Sensor de chuva']},
#  {'value': 'R$ 442.000',
#   'name': 'COBRA',
#   'category': 'NOVO',
#   'motor': 'Motor 2.4 Turbo',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['Teto panorâmico',
#    'Sensor de chuva',
#    'Câmbio automático',
#    'Piloto automático']},
#  {'value': 'R$ 108.000',
#   'name': 'SUV',
#   'category': 'NOVO',
#   'motor': 'Motor 1.0 8v',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Freios ABS',
#    'Bancos de couro',
#    'Sensor de estacionamento',
#    'Controle de tração']},
#  {'value': 'R$ 471.000',
#   'name': 'JEEP',
#   'category': 'USADO',
#   'motor': 'Motor 2.4 Turbo',
#   'description': 'Ano 1990 - 68.534 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Controle de estabilidade',
#    '4 X 4',
#    'Central multimídia',
#    'Controle de tração']},
#  {'value': 'R$ 210.000',
#   'name': 'CLASSIC CAR',
#   'category': 'NOVO',
#   'motor': 'Motor Diesel V8',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Câmbio automático',
#    '4 X 4',
#    'Sensor de estacionamento',
#    'Ar condicionado']},
#  {'value': 'R$ 332.000',
#   'name': 'TEA',
#   'category': 'USADO',
#   'motor': 'Motor 2.4 Turbo',
#   'description': 'Ano 2014 - 115.936 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Câmera de estacionamento',
#    'Vidros elétricos',
#    'Painel digital',
#    'Central multimídia']},
#  {'value': 'R$ 113.000',
#   'name': 'TRAFFIC',
#   'category': 'NOVO',
#   'motor': 'Motor 3.0 32v',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Controle de tração',
#    'Vidros elétricos',
#    'Bancos de couro',
#    'Painel digital']},
#  {'value': 'R$ 172.000',
#   'name': 'MERCEDES BENZ 600SE LUXURY SEDAN',
#   'category': 'USADO',
#   'motor': 'Motor 2.0 16v',
#   'description': 'Ano 1997 - 80.168 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Sensor de estacionamento',
#    'Freios ABS',
#    'Teto panorâmico',
#    'Sensor de chuva']},
#  {'value': 'R$ 180.000',
#   'name': 'PKW',
#   'category': 'NOVO',
#   'motor': 'Motor Diesel',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['Travas elétricas',
#    'Teto panorâmico',
#    'Rodas de liga',
#    'Ar condicionado']},
#  {'value': 'R$ 498.000',
#   'name': 'MERCEDES SLK55',
#   'category': 'NOVO',
#   'motor': 'Motor Diesel V6',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Rodas de liga',
#    'Câmera de estacionamento',
#    '4 X 4',
#    'Piloto automático']},
#  {'value': 'R$ 142.000',
#   'name': 'LUXURY CAR',
#   'category': 'USADO',
#   'motor': 'Motor Diesel',
#   'description': 'Ano 2015 - 72.680 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['4 X 4',
#    'Sensor de estacionamento',
#    'Vidros elétricos',
#    'Teto panorâmico']},
#  {'value': 'R$ 121.000',
#   'name': 'MERCEDES SL300',
#   'category': 'USADO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor 2.4 Turbo',
#   'description': 'Ano 1994 - 16.192 km',
#   'location': 'São Paulo - SP',
#   'items': ['Freios ABS',
#    'Câmbio automático',
#    'Sensor de chuva',
#    'Câmera de estacionamento']},
#  {'value': 'R$ 432.000',
#   'name': 'REDJAWA',
#   'category': 'USADO',
#   'motor': 'Motor 2.0 16v',
#   'description': 'Ano 1992 - 85.309 km',
#   'location': 'São Paulo - SP',
#   'items': ['Piloto automático',
#    'Controle de tração',
#    'Central multimídia',
#    'Ar condicionado']},
#  {'value': 'R$ 297.000',
#   'name': 'MINI',
#   'category': 'USADO',
#   'motor': 'Motor V8',
#   'description': 'Ano 2000 - 86.019 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Rodas de liga',
#    'Câmera de estacionamento',
#    'Central multimídia',
#    'Controle de estabilidade']},
#  {'value': 'R$ 160.000',
#   'name': 'HUMMER',
#   'category': 'USADO',
#   'motor': 'Motor 1.0 8v',
#   'description': 'Ano 2010 - 64.634 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Ar condicionado',
#    'Sensor de chuva',
#    'Sensor de estacionamento',
#    'Câmbio automático']},
#  {'value': 'R$ 191.000',
#   'name': 'FIRE',
#   'category': 'NOVO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor Diesel V6',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['Travas elétricas',
#    'Vidros elétricos',
#    'Rodas de liga',
#    'Sensor crepuscular']},
#  {'value': 'R$ 321.000',
#   'name': 'FERRARI 348',
#   'category': 'USADO',
#   'motor': 'Motor 5.0 V8 Bi-Turbo',
#   'description': 'Ano 2013 - 44.072 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Teto panorâmico',
#    'Sensor de estacionamento',
#    '4 X 4',
#    'Rodas de liga']},
#  {'value': 'R$ 342.000',
#   'name': 'FERRARI ENZO',
#   'category': 'USADO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor V8',
#   'description': 'Ano 1994 - 111.311 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Sensor crepuscular',
#    'Câmbio automático',
#    'Sensor de estacionamento',
#    'Freios ABS']},
#  {'value': 'R$ 131.000',
#   'name': 'ALLOY',
#   'category': 'USADO',
#   'motor': 'Motor 1.8 16v',
#   'description': 'Ano 1995 - 58.944 km',
#   'location': 'São Paulo - SP',
#   'items': ['Rodas de liga',
#    'Painel digital',
#    'Central multimídia',
#    'Freios ABS']},
#  {'value': 'R$ 102.000',
#   'name': 'SPORT CAR',
#   'category': 'NOVO',
#   'motor': 'Motor V8',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['Ar condicionado',
#    'Central multimídia',
#    'Sensor de chuva',
#    'Teto panorâmico']},
#  {'value': 'R$ 422.000',
#   'name': 'CUBA',
#   'category': 'USADO',
#   'motor': 'Motor Diesel',
#   'description': 'Ano 1992 - 62.255 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Vidros elétricos',
#    'Controle de tração',
#    'Piloto automático',
#    'Teto panorâmico']},
#  {'value': 'R$ 482.000',
#   'name': 'FERRARI F12',
#   'category': 'USADO',
#   'motor': 'Motor Diesel V6',
#   'description': 'Ano 2008 - 65.143 km',
#   'location': 'São Paulo - SP',
#   'items': ['Freios ABS',
#    'Rodas de liga',
#    'Travas elétricas',
#    'Sensor de chuva']},
#  {'value': 'R$ 229.000',
#   'name': 'ACURA REAR',
#   'category': 'USADO',
#   'motor': 'Motor 2.0 16v',
#   'description': 'Ano 2007 - 33.343 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Teto panorâmico',
#    'Painel digital',
#    'Travas elétricas',
#    'Controle de estabilidade']},
#  {'value': 'R$ 61.000',
#   'name': 'MERCEDES BENZ SLR',
#   'category': 'USADO',
#   'motor': 'Motor Diesel V8',
#   'description': 'Ano 1998 - 66.074 km',
#   'location': 'São Paulo - SP',
#   'items': ['Controle de tração',
#    'Câmera de estacionamento',
#    'Central multimídia',
#    'Travas elétricas']},
#  {'value': 'R$ 491.000',
#   'name': 'CADILLAC',
#   'category': 'USADO',
#   'motor': 'Motor V8',
#   'description': 'Ano 2001 - 90.123 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Central multimídia',
#    '4 X 4',
#    'Piloto automático',
#    'Vidros elétricos']},
#  {'value': 'R$ 340.000',
#   'name': 'FORD GT40',
#   'category': 'USADO',
#   'motor': 'Motor 2.4 Turbo',
#   'description': 'Ano 2009 - 118.844 km',
#   'location': 'São Paulo - SP',
#   'items': ['Central multimídia',
#    'Teto panorâmico',
#    'Painel digital',
#    'Bancos de couro']},
#  {'value': 'R$ 384.000',
#   'name': 'HOTROD TRUCK',
#   'category': 'USADO',
#   'motor': 'Motor V6',
#   'description': 'Ano 2018 - 73.321 km',
#   'location': 'São Paulo - SP',
#   'items': ['Ar condicionado',
#    'Rodas de liga',
#    'Painel digital',
#    'Controle de estabilidade']},
#  {'value': 'R$ 81.000',
#   'name': 'CLASSIC CARS',
#   'category': 'USADO',
#   'motor': 'Motor 1.0 8v',
#   'description': 'Ano 2006 - 7.306 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Travas elétricas',
#    'Central multimídia',
#    '4 X 4',
#    'Rodas de liga']},
#  {'value': 'R$ 429.000',
#   'name': 'BMW GLAS V8 COUPE',
#   'category': 'USADO',
#   'motor': 'Motor Diesel',
#   'description': 'Ano 1991 - 85.498 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Travas elétricas',
#    'Ar condicionado',
#    'Piloto automático',
#    'Central multimídia']},
#  {'value': 'R$ 384.000',
#   'name': 'PEUGEOT',
#   'category': 'USADO',
#   'motor': 'Motor 2.0 16v',
#   'description': 'Ano 2017 - 17.022 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Rodas de liga',
#    'Teto panorâmico',
#    'Câmera de estacionamento',
#    'Painel digital']},
#  {'value': 'R$ 318.000',
#   'name': 'JAGUAR CAR',
#   'category': 'NOVO',
#   'motor': 'Motor 3.0 32v',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Piloto automático', '4 X 4', 'Freios ABS', 'Travas elétricas']},
#  {'value': 'R$ 326.000',
#   'name': 'COBRA SPORTS CAR',
#   'category': 'USADO',
#   'motor': 'Motor 2.4 Turbo',
#   'description': 'Ano 2008 - 112.215 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Travas elétricas',
#    'Painel digital',
#    'Teto panorâmico',
#    'Central multimídia']},
#  {'value': 'R$ 447.000',
#   'name': 'STRETCH LIMOUSINE',
#   'category': 'USADO',
#   'motor': 'Motor Diesel',
#   'description': 'Ano 2009 - 53.225 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Controle de estabilidade',
#    'Teto panorâmico',
#    'Bancos de couro',
#    'Ar condicionado']},
#  {'value': 'R$ 87.000',
#   'name': 'FERRARI CAR',
#   'category': 'USADO',
#   'motor': 'Motor Diesel',
#   'description': 'Ano 2002 - 86.124 km',
#   'location': 'São Paulo - SP',
#   'items': ['Teto panorâmico',
#    'Câmbio automático',
#    'Central multimídia',
#    'Travas elétricas']},
#  {'value': 'R$ 182.000',
#   'name': 'MERCURYDL',
#   'category': 'USADO',
#   'motor': 'Motor Diesel V8',
#   'description': 'Ano 1997 - 108.631 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Sensor de estacionamento',
#    'Freios ABS',
#    'Controle de tração',
#    'Câmera de estacionamento']},
#  {'value': 'R$ 212.000',
#   'name': 'MASERATI',
#   'category': 'NOVO',
#   'motor': 'Motor 1.0 8v',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Câmbio automático',
#    'Sensor crepuscular',
#    'Central multimídia',
#    'Vidros elétricos']},
#  {'value': 'R$ 253.000',
#   'name': 'MERCEDES C63 ENGINE',
#   'category': 'USADO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor V6',
#   'description': 'Ano 1995 - 89.724 km',
#   'location': 'São Paulo - SP',
#   'items': ['Vidros elétricos',
#    'Câmera de estacionamento',
#    'Sensor de chuva',
#    'Teto panorâmico']},
#  {'value': 'R$ 246.000',
#   'name': 'COUPE',
#   'category': 'USADO',
#   'motor': 'Motor 3.0 32v',
#   'description': 'Ano 2001 - 116.767 km',
#   'location': 'São Paulo - SP',
#   'items': ['Sensor de chuva',
#    'Câmera de estacionamento',
#    'Teto panorâmico',
#    'Vidros elétricos']},
#  {'value': 'R$ 364.000',
#   'name': 'GT',
#   'category': 'USADO',
#   'motor': 'Motor 4.0 Turbo',
#   'description': 'Ano 2016 - 38.803 km',
#   'location': 'São Paulo - SP',
#   'items': ['Vidros elétricos',
#    'Sensor crepuscular',
#    'Freios ABS',
#    'Ar condicionado']},
#  {'value': 'R$ 434.000',
#   'name': 'RENAULT',
#   'category': 'USADO',
#   'motor': 'Motor 5.0 V8 Bi-Turbo',
#   'description': 'Ano 1991 - 101.983 km',
#   'location': 'São Paulo - SP',
#   'items': ['Câmbio automático',
#    'Sensor crepuscular',
#    'Rodas de liga',
#    'Sensor de chuva']},
#  {'value': 'R$ 493.000',
#   'name': 'FIAT 130',
#   'category': 'USADO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor 5.0 V8 Bi-Turbo',
#   'description': 'Ano 2010 - 11.257 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Sensor crepuscular',
#    'Travas elétricas',
#    'Central multimídia',
#    '4 X 4']},
#  {'value': 'R$ 303.000',
#   'name': 'VINTAGE CARS',
#   'category': 'USADO',
#   'motor': 'Motor 1.8 16v',
#   'description': 'Ano 2004 - 47.972 km',
#   'location': 'São Paulo - SP',
#   'items': ['Câmera de estacionamento',
#    'Ar condicionado',
#    'Freios ABS',
#    'Piloto automático']},
#  {'value': 'R$ 363.000',
#   'name': 'NISSAN GTR',
#   'category': 'USADO',
#   'motor': 'Motor Diesel',
#   'description': 'Ano 1995 - 61.740 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Freios ABS',
#    'Sensor de estacionamento',
#    'Sensor de chuva',
#    'Piloto automático']},
#  {'value': 'R$ 180.000',
#   'name': 'MERCEDES SLS',
#   'category': 'USADO',
#   'motor': 'Motor 3.0 32v',
#   'description': 'Ano 2004 - 41.278 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Freios ABS',
#    'Sensor de estacionamento',
#    'Controle de tração',
#    'Sensor de chuva']},
#  {'value': 'R$ 175.000',
#   'name': 'LUXURY AUTOMOBILE',
#   'category': 'NOVO',
#   'motor': 'Motor V8',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Teto panorâmico',
#    'Central multimídia',
#    'Ar condicionado',
#    'Sensor de estacionamento']},
#  {'value': 'R$ 455.000',
#   'name': 'KIA CAR',
#   'category': 'USADO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor 4.0 Turbo',
#   'description': 'Ano 2017 - 95.496 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Controle de tração',
#    'Painel digital',
#    'Teto panorâmico',
#    'Freios ABS']},
#  {'value': 'R$ 296.000',
#   'name': 'TANGERINE LAMBORGHINI',
#   'category': 'USADO',
#   'motor': 'Motor V8',
#   'description': 'Ano 2003 - 100.107 km',
#   'location': 'São Paulo - SP',
#   'items': ['Câmera de estacionamento',
#    'Freios ABS',
#    'Painel digital',
#    'Câmbio automático']},
#  {'value': 'R$ 363.000',
#   'name': 'CLASSIC TAILLIGHT',
#   'category': 'USADO',
#   'motor': 'Motor 4.0 Turbo',
#   'description': 'Ano 2015 - 39.240 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Vidros elétricos',
#    'Painel digital',
#    'Freios ABS',
#    'Sensor crepuscular']},
#  {'value': 'R$ 217.000',
#   'name': 'WIESMANN GT MF4',
#   'category': 'USADO',
#   'motor': 'Motor 2.0 16v',
#   'description': 'Ano 1994 - 82.228 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Câmera de estacionamento',
#    'Freios ABS',
#    'Controle de estabilidade',
#    'Painel digital']},
# ...
#   'description': 'Ano 1994 - 59.885 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Sensor de chuva',
#    'Controle de tração',
#    'Sensor de estacionamento',
#    'Câmbio automático']},
#  {'value': 'R$ 490.000',
#   'name': 'CUSTOM RIMS',
#   'category': 'USADO',
#   'motor': 'Motor 4.0 Turbo',
#   'description': 'Ano 1994 - 15.292 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Controle de tração',
#    '4 X 4',
#    'Vidros elétricos',
#    'Sensor de chuva']},
#  {'value': 'R$ 152.000',
#   'name': 'MERCEDES BENZ S CLASS',
#   'category': 'USADO',
#   'motor': 'Motor 2.0 16v',
#   'description': 'Ano 2003 - 23.426 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Controle de tração',
#    'Sensor crepuscular',
#    'Piloto automático',
#    'Sensor de estacionamento']},
#  {'value': 'R$ 480.000',
#   'name': 'ADAM OPEL AG',
#   'category': 'NOVO',
#   'motor': 'Motor 1.0 8v',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['Sensor crepuscular',
#    'Sensor de estacionamento',
#    'Travas elétricas',
#    'Sensor de chuva']},
#  {'value': 'R$ 381.000',
#   'name': 'SPOTLIGHT',
#   'category': 'USADO',
#   'motor': 'Motor 4.0 Turbo',
#   'description': 'Ano 2000 - 81.779 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Rodas de liga',
#    'Controle de tração',
#    'Bancos de couro',
#    'Vidros elétricos']},
#  {'value': 'R$ 468.000',
#   'name': 'LOTUS',
#   'category': 'USADO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor Diesel V6',
#   'description': 'Ano 1995 - 45.004 km',
#   'location': 'São Paulo - SP',
#   'items': ['Travas elétricas',
#    'Freios ABS',
#    'Bancos de couro',
#    'Câmbio automático']},
#  {'value': 'R$ 54.000',
#   'name': 'SPORTS CAR',
#   'category': 'NOVO',
#   'motor': 'Motor 1.8 16v',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Travas elétricas',
#    'Rodas de liga',
#    'Bancos de couro',
#    'Central multimídia']},
#  {'value': 'R$ 304.000',
#   'name': 'RESTORED',
#   'category': 'USADO',
#   'motor': 'Motor 5.0 V8 Bi-Turbo',
#   'description': 'Ano 2002 - 84.771 km',
#   'location': 'São Paulo - SP',
#   'items': ['Teto panorâmico',
#    'Câmbio automático',
#    'Controle de estabilidade',
#    'Vidros elétricos']},
#  {'value': 'R$ 372.000',
#   'name': 'FERRARI F430',
#   'category': 'USADO',
#   'motor': 'Motor 1.0 8v',
#   'description': 'Ano 2005 - 57.973 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Sensor de chuva',
#    'Rodas de liga',
#    'Controle de tração',
#    'Ar condicionado']},
#  {'value': 'R$ 357.000',
#   'name': 'CLASSIC MERCEDES',
#   'category': 'USADO',
#   'motor': 'Motor 1.0 8v',
#   'description': 'Ano 2014 - 86.577 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Vidros elétricos',
#    'Bancos de couro',
#    'Controle de estabilidade',
#    'Freios ABS']},
#  {'value': 'R$ 333.000',
#   'name': 'MERCEDES',
#   'category': 'USADO',
#   'motor': 'Motor V6',
#   'description': 'Ano 2002 - 25.150 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Central multimídia',
#    'Ar condicionado',
#    'Vidros elétricos',
#    'Painel digital']},
#  {'value': 'R$ 153.000',
#   'name': 'SPEEDO',
#   'category': 'USADO',
#   'motor': 'Motor 1.0 8v',
#   'description': 'Ano 2010 - 44.165 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Vidros elétricos',
#    'Sensor de chuva',
#    'Sensor crepuscular',
#    'Ar condicionado']},
#  {'value': 'R$ 318.000',
#   'name': 'PORSCHE TARGA',
#   'category': 'USADO',
#   'motor': 'Motor 1.8 16v',
#   'description': 'Ano 2005 - 102.500 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Teto panorâmico',
#    'Câmbio automático',
#    'Sensor crepuscular',
#    'Controle de estabilidade']},
#  {'value': 'R$ 125.000',
#   'name': 'FERRARI 308 GT4',
#   'category': 'USADO',
#   'motor': 'Motor 4.0 Turbo',
#   'description': 'Ano 1999 - 90.403 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Bancos de couro',
#    'Ar condicionado',
#    'Travas elétricas',
#    'Controle de tração']},
#  {'value': 'R$ 373.000',
#   'name': 'MERCEDES BENZ 600',
#   'category': 'USADO',
#   'motor': 'Motor Diesel',
#   'description': 'Ano 2015 - 69.171 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Piloto automático',
#    'Central multimídia',
#    'Painel digital',
#    'Rodas de liga']},
#  {'value': 'R$ 81.000',
#   'name': 'PACKARD SUPER 8',
#   'category': 'USADO',
#   'motor': 'Motor Diesel V6',
#   'description': 'Ano 2004 - 4.476 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Rodas de liga',
#    'Teto panorâmico',
#    'Câmbio automático',
#    'Bancos de couro']},
#  {'value': 'R$ 464.000',
#   'name': 'BENTLEY MULSANNE',
#   'category': 'USADO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor Diesel V6',
#   'description': 'Ano 2004 - 61.712 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['4 X 4',
#    'Central multimídia',
#    'Travas elétricas',
#    'Painel digital']},
#  {'value': 'R$ 201.000',
#   'name': 'JAGUAR XK',
#   'category': 'NOVO',
#   'motor': 'Motor 5.0 V8 Bi-Turbo',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['4 X 4',
#    'Teto panorâmico',
#    'Sensor de chuva',
#    'Controle de tração']},
#  {'value': 'R$ 222.000',
#   'name': 'PLYMOUTH',
#   'category': 'USADO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor V6',
#   'description': 'Ano 1999 - 2.388 km',
#   'location': 'São Paulo - SP',
#   'items': ['4 X 4',
#    'Controle de estabilidade',
#    'Freios ABS',
#    'Sensor de estacionamento']},
#  {'value': 'R$ 376.000',
#   'name': 'PORSCHE 911 GT3',
#   'category': 'USADO',
#   'motor': 'Motor Diesel V6',
#   'description': 'Ano 2009 - 86.538 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['4 X 4',
#    'Sensor de chuva',
#    'Rodas de liga',
#    'Central multimídia']},
#  {'value': 'R$ 112.000',
#   'name': 'MERCES',
#   'category': 'USADO',
#   'motor': 'Motor V8',
#   'description': 'Ano 2014 - 11.328 km',
#   'location': 'São Paulo - SP',
#   'items': ['Travas elétricas',
#    'Freios ABS',
#    'Controle de tração',
#    'Controle de estabilidade']},
#  {'value': 'R$ 338.000',
#   'name': 'THIRTIES',
#   'category': 'USADO',
#   'motor': 'Motor Diesel',
#   'description': 'Ano 2006 - 93.564 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Sensor de estacionamento',
#    'Câmbio automático',
#    'Piloto automático',
#    'Ar condicionado']},
#  {'value': 'R$ 338.000',
#   'name': 'PORSCHE 911 TURBO',
#   'category': 'USADO',
#   'motor': 'Motor 1.8 16v',
#   'description': 'Ano 1996 - 106.598 km',
#   'location': 'São Paulo - SP',
#   'items': ['Controle de tração',
#    'Sensor crepuscular',
#    'Vidros elétricos',
#    'Painel digital']},
#  {'value': 'R$ 198.000',
#   'name': 'SKODA',
#   'category': 'USADO',
#   'motor': 'Motor V8',
#   'description': 'Ano 1994 - 77.208 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Controle de estabilidade',
#    'Rodas de liga',
#    'Ar condicionado',
#    'Câmbio automático']},
#  {'value': 'R$ 155.000',
#   'name': 'VOLKSWAGEN',
#   'category': 'USADO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor Diesel V8',
#   'description': 'Ano 2017 - 64.852 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Câmera de estacionamento',
#    'Central multimídia',
#    'Travas elétricas',
#    'Câmbio automático']},
#  {'value': 'R$ 273.000',
#   'name': 'GMC YUKON TRUCK WHEEL',
#   'category': 'USADO',
#   'motor': 'Motor 1.0 8v',
#   'description': 'Ano 2001 - 70.878 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Sensor de estacionamento',
#    'Ar condicionado',
#    'Vidros elétricos',
#    'Câmbio automático']},
#  {'value': 'R$ 63.000',
#   'name': 'PANTERA',
#   'category': 'NOVO',
#   'motor': 'Motor Diesel',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['Freios ABS',
#    'Controle de estabilidade',
#    'Travas elétricas',
#    'Câmera de estacionamento']},
#  {'value': 'R$ 448.000',
#   'name': 'HONDA',
#   'category': 'USADO',
#   'motor': 'Motor Diesel V8',
#   'description': 'Ano 2009 - 64.735 km',
#   'location': 'São Paulo - SP',
#   'items': ['Câmbio automático',
#    'Vidros elétricos',
#    'Sensor de estacionamento',
#    '4 X 4']},
#  {'value': 'R$ 376.000',
#   'name': 'MERCEDES AMG GTS',
#   'category': 'USADO',
#   'motor': 'Motor Diesel V6',
#   'description': 'Ano 2009 - 59.305 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Freios ABS',
#    'Sensor de estacionamento',
#    'Rodas de liga',
#    'Câmera de estacionamento']},
#  {'value': 'R$ 353.000',
#   'name': 'LIMO',
#   'category': 'USADO',
#   'motor': 'Motor V6',
#   'description': 'Ano 1990 - 92.448 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Controle de estabilidade',
#    'Câmbio automático',
#    'Ar condicionado',
#    'Central multimídia']},
#  {'value': 'R$ 90.000',
#   'name': 'BMW',
#   'category': 'USADO',
#   'motor': 'Motor Diesel V6',
#   'description': 'Ano 2015 - 21.275 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Controle de tração',
#    'Travas elétricas',
#    'Rodas de liga',
#    'Central multimídia']},
#  {'value': 'R$ 468.000',
#   'name': 'FERRARI 288 GTO',
#   'category': 'USADO',
#   'motor': 'Motor V6',
#   'description': 'Ano 1994 - 86.170 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Piloto automático',
#    'Sensor de estacionamento',
#    'Sensor crepuscular',
#    'Rodas de liga']},
#  {'value': 'R$ 415.000',
#   'name': 'AUDI RS7',
#   'category': 'USADO',
#   'motor': 'Motor 3.0 32v',
#   'description': 'Ano 2014 - 117.197 km',
#   'location': 'São Paulo - SP',
#   'items': ['Piloto automático',
#    'Controle de estabilidade',
#    'Sensor de estacionamento',
#    'Sensor de chuva']},
#  {'value': 'R$ 331.000',
#   'name': 'SEAT LEON',
#   'category': 'USADO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor 2.0 16v',
#   'description': 'Ano 1995 - 30.961 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Sensor de chuva', 'Câmbio automático', 'Freios ABS', '4 X 4']},
#  {'value': 'R$ 237.000',
#   'name': 'MERCEDES BENZ SLS',
#   'category': 'USADO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor Diesel V8',
#   'description': 'Ano 1991 - 97.949 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Freios ABS',
#    'Rodas de liga',
#    'Câmbio automático',
#    'Painel digital']},
#  {'value': 'R$ 88.000',
#   'name': 'LAGONDA',
#   'category': 'USADO',
#   'motor': 'Motor 2.0 16v',
#   'description': 'Ano 2016 - 18.870 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Câmera de estacionamento',
#    'Rodas de liga',
#    'Painel digital',
#    'Sensor de estacionamento']},
#  {'value': 'R$ 312.000',
#   'name': 'ANTIQUE CAR',
#   'category': 'USADO',
#   'motor': 'Motor Diesel',
#   'description': 'Ano 2014 - 114.136 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Central multimídia',
#    'Sensor de estacionamento',
#    'Controle de tração',
#    'Câmbio automático']},
#  {'value': 'R$ 240.000',
#   'name': 'AUDI A5',
#   'category': 'NOVO',
#   'motor': 'Motor V6',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Câmera de estacionamento',
#    'Sensor de chuva',
#    'Vidros elétricos',
#    'Sensor de estacionamento']},
#  {'value': 'R$ 215.000',
#   'name': 'COUGAR XR',
#   'category': 'NOVO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor 1.8 16v',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['Sensor crepuscular',
#    'Controle de estabilidade',
#    'Rodas de liga',
#    'Teto panorâmico']},
#  {'value': 'R$ 492.000',
#   'name': 'JAGUAR',
#   'category': 'USADO',
#   'motor': 'Motor V6',
#   'description': 'Ano 1991 - 117.377 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Teto panorâmico',
#    'Ar condicionado',
#    'Vidros elétricos',
#    'Bancos de couro']},
#  {'value': 'R$ 172.000',
#   'name': 'WHITE LAMBORGHINI',
#   'category': 'NOVO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor Diesel',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['Controle de tração',
#    'Câmbio automático',
#    'Câmera de estacionamento',
#    'Sensor de estacionamento']},
#  {'value': 'R$ 496.000',
#   'name': 'CORVETTE YELLOW',
#   'category': 'NOVO',
#   'motor': 'Motor 5.0 V8 Bi-Turbo',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['Bancos de couro',
#    'Rodas de liga',
#    'Sensor de chuva',
#    'Central multimídia']},
#  {'value': 'R$ 334.000',
#   'name': 'HOUSTON FIRE DEPARTMENT',
#   'category': 'USADO',
#   'motor': 'Motor 5.0 V8 Bi-Turbo',
#   'description': 'Ano 2010 - 112.389 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Ar condicionado',
#    'Travas elétricas',
#    'Controle de tração',
#    '4 X 4']},
#  {'value': 'R$ 331.000',
#   'name': 'ASTON MARTIN DBS',
#   'category': 'USADO',
#   'motor': 'Motor V8',
#   'description': 'Ano 2010 - 15.193 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Ar condicionado',
#    'Vidros elétricos',
#    'Câmbio automático',
#    'Sensor de estacionamento']},
#  {'value': 'R$ 381.000',
#   'name': 'AMG',
#   'category': 'NOVO',
#   'motor': 'Motor 4.0 Turbo',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['Freios ABS',
#    'Piloto automático',
#    'Sensor crepuscular',
#    'Vidros elétricos']},
#  {'value': 'R$ 362.000',
#   'name': 'LAMBORGHINI DIABLO',
#   'category': 'NOVO',
#   'motor': 'Motor 2.4 Turbo',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['Ar condicionado',
#    'Sensor de estacionamento',
#    'Controle de estabilidade',
#    'Painel digital']},
#  {'value': 'R$ 281.000',
#   'name': 'TRIPPELWAGEN',
#   'category': 'NOVO',
#   'motor': 'Motor 2.0 16v',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Sensor de chuva',
#    'Ar condicionado',
#    'Teto panorâmico',
#    'Sensor de estacionamento']},
#  {'value': 'R$ 308.000',
#   'name': 'BENTZ',
#   'category': 'NOVO',
#   'motor': 'Motor 2.4 Turbo',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'São Paulo - SP',
#   'items': ['Freios ABS',
#    'Ar condicionado',
#    'Travas elétricas',
#    'Câmbio automático']},
#  {'value': 'R$ 268.000',
#   'name': 'LUXURY SPORTS CAR',
#   'category': 'NOVO',
#   'motor': 'Motor 3.0 32v',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Piloto automático',
#    'Controle de estabilidade',
#    'Câmera de estacionamento',
#    '4 X 4']},
#  {'value': 'R$ 192.000',
#   'name': 'CONVERTIBLE',
#   'category': 'USADO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor V8',
#   'description': 'Ano 2008 - 42.427 km',
#   'location': 'Rio de Janeiro - RJ',
#   'items': ['Rodas de liga',
#    'Freios ABS',
#    'Câmera de estacionamento',
#    'Travas elétricas']},
#  {'value': 'R$ 432.000',
#   'name': 'ROLLAND PILAIN',
#   'category': 'USADO',
#   'motor': 'Motor 1.8 16v',
#   'description': 'Ano 2006 - 15.128 km',
#   'location': 'São Paulo - SP',
#   'items': ['Painel digital',
#    'Câmbio automático',
#    'Sensor crepuscular',
#    'Rodas de liga']},
#  {'value': 'R$ 489.000',
#   'name': 'SUV REAR TIRE',
#   'category': 'USADO',
#   'motor': 'Motor 3.0 32v',
#   'description': 'Ano 1998 - 74.292 km',
#   'location': 'São Paulo - SP',
#   'items': ['Câmera de estacionamento',
#    'Rodas de liga',
#    'Sensor de estacionamento',
#    'Vidros elétricos']},
#  {'value': 'R$ 427.000',
#   'name': 'ANTIQUE',
#   'category': 'NOVO',
#   'motor': 'Motor 2.0 16v',
#   'description': 'Ano 2019 - 0 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Bancos de couro',
#    'Freios ABS',
#    'Sensor de estacionamento',
#    'Teto panorâmico']},
#  {'value': 'R$ 203.000',
#   'name': 'SPORT',
#   'category': 'USADO',
#   'motor': 'Motor 2.0 16v',
#   'description': 'Ano 2001 - 102.776 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Sensor crepuscular',
#    'Sensor de chuva',
#    'Vidros elétricos',
#    'Travas elétricas']},
#  {'value': 'R$ 474.000',
#   'name': 'IMPERIAL',
#   'category': 'USADO',
#   'opportunity': 'OPORTUNIDADE',
#   'motor': 'Motor 1.8 16v',
#   'description': 'Ano 2011 - 101.787 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Painel digital',
#    'Travas elétricas',
#    'Sensor de chuva',
#    'Ar condicionado']},
#  {'value': 'R$ 366.000',
#   'name': 'KIA SPORTS CAR',
#   'category': 'USADO',
#   'motor': 'Motor 3.0 32v',
#   'description': 'Ano 2001 - 88.564 km',
#   'location': 'Belo Horizonte - MG',
#   'items': ['Sensor crepuscular',
#    'Bancos de couro',
#    'Sensor de estacionamento',
#    'Travas elétricas']}]

# %%
for i in range(25):
    print('https://alura-site-scraping.herokuapp.com/index.php?page=' + str(i + 1))
# Out:
# https://alura-site-scraping.herokuapp.com/index.php?page=1
# https://alura-site-scraping.herokuapp.com/index.php?page=2
# https://alura-site-scraping.herokuapp.com/index.php?page=3
# https://alura-site-scraping.herokuapp.com/index.php?page=4
# https://alura-site-scraping.herokuapp.com/index.php?page=5
# https://alura-site-scraping.herokuapp.com/index.php?page=6
# https://alura-site-scraping.herokuapp.com/index.php?page=7
# https://alura-site-scraping.herokuapp.com/index.php?page=8
# https://alura-site-scraping.herokuapp.com/index.php?page=9
# https://alura-site-scraping.herokuapp.com/index.php?page=10
# https://alura-site-scraping.herokuapp.com/index.php?page=11
# https://alura-site-scraping.herokuapp.com/index.php?page=12
# https://alura-site-scraping.herokuapp.com/index.php?page=13
# https://alura-site-scraping.herokuapp.com/index.php?page=14
# https://alura-site-scraping.herokuapp.com/index.php?page=15
# https://alura-site-scraping.herokuapp.com/index.php?page=16
# https://alura-site-scraping.herokuapp.com/index.php?page=17
# https://alura-site-scraping.herokuapp.com/index.php?page=18
# https://alura-site-scraping.herokuapp.com/index.php?page=19
# https://alura-site-scraping.herokuapp.com/index.php?page=20
# https://alura-site-scraping.herokuapp.com/index.php?page=21
# https://alura-site-scraping.herokuapp.com/index.php?page=22
# https://alura-site-scraping.herokuapp.com/index.php?page=23
# https://alura-site-scraping.herokuapp.com/index.php?page=24
# https://alura-site-scraping.herokuapp.com/index.php?page=25
