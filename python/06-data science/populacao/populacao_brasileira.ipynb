# %%
import matplotlib.pyplot as plt

# %%
# importando dados de um .csv
dados = open('populacao_brasileira.csv').readlines()
x, y = [], []
for i in range(len(dados)):
    if i != 0:  # ignorando a primeira linha
        linha = dados[i].split(';')
        x.append(int(linha[0]))
        y.append(int(linha[1]))

# %%
plt.figure(figsize = (16, 8))
plt.title('Crescimento da População Brasileira 1980-2016')
plt.xlabel('Ano')
plt.ylabel('População (*100M)')
plt.bar(x, y, color='#e4e4e4')
plt.plot(x, y, color='k', linestyle='--', label='Crescimento')
plt.legend()
plt.show()

# %%
# plt.savefig('populacao_brasileira.pdf')
# plt.savefig('populacao_brasileira.png', dpi=300)
